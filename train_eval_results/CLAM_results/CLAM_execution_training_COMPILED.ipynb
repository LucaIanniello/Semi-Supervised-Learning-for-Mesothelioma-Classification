# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from oauth2client.client import GoogleCredentials
import os
import matplotlib.pyplot as plt
import torch
# Out:
# WARNING:root:pydrive is deprecated and no longer maintained. We recommend that you migrate your projects to pydrive2, the maintained fork of pydrive

# %%
# !git clone https://github.com/LucaIanniello/MLIAProject.git
# Out:
# Cloning into 'MLIAProject'...
# remote: Enumerating objects: 249, done.
# remote: Counting objects: 100% (116/116), done.
# remote: Compressing objects: 100% (80/80), done.
# remote: Total 249 (delta 54), reused 93 (delta 35), pack-reused 133 (from 1)
# Receiving objects: 100% (249/249), 49.28 MiB | 16.24 MiB/s, done.
# Resolving deltas: 100% (77/77), done.

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()

# !conda env create -f MLIAProject/CLAM/env.yml
# !conda install -n clam_latest -c conda-forge openslide
# !conda install -n clam_latest -c conda-forge openslide-tools libopenslide0 libtiff-dev libjpeg-dev
# !conda install -n clam_latest -c conda-forge future
# !conda run -n clam_latest python --version
# !conda run -n clam_latest pip list

# !apt-get update
# !apt-get install -y openslide-tools libopenslide0 libtiff-dev libjpeg-dev
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:09
# 🔁 Restarting kernel...
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.2
#     latest version: 25.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ...
# python-3.10.0        | 29.8 MB   | :   0% 0/1 [00:00<?, ?it/s]
# tk-8.6.13            | 3.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
# openssl-3.5.0        | 3.0 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# pip-25.1.1           | 1.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# libsqlite-3.50.0     | 897 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# sqlite-3.50.0        | 878 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# ...

# %%
# !conda --version
# !which conda
# !conda config --show-sources
# !conda env update -n base -f MLIAProject/CLAM/env.yml
# Out:
# conda 24.11.2
# /usr/local/bin/conda
# ==> /usr/local/.condarc <==
# channels:
#   - conda-forge
# always_yes: True
#
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# failed
#
# SpecsConfigurationConflictError: Requested specs conflict with configured specs.
#   requested specs:
#     - pip
#     - python==3.10
#   pinned specs:
#     - cuda-version=12
#     - python=3.11
#     - python_abi=3.11[build=*cp311*]
# Use 'conda config --show-sources' to look for 'pinned_specs' and 'track_features'
# configuration parameters.  Pinned specs may also be defined in the file
# /usr/local/conda-meta/pinned.

# %%
import os
import zipfile

# URL for the dataset
url = "https://zenodo.org/records/15547611/files/datasetUnified_PT.zip?download=1"

# Download the file using wget
# !wget -O /content/Train.zip "$url"

# Define the extraction path
extract_path = './'

# Create the extraction directory if it doesn't exist
os.makedirs(extract_path, exist_ok=True)

# Extract the ZIP file
with zipfile.ZipFile('./Train.zip', 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# List the contents of the extracted folder
extracted_files = os.listdir(extract_path)
print("Extracted files:", extracted_files)
# Out:
# --2025-05-30 10:49:45--  https://zenodo.org/records/15547611/files/datasetUnified_PT.zip?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.43.25, 188.185.45.92, 188.185.48.194, ...
# Connecting to zenodo.org (zenodo.org)|188.185.43.25|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2005901570 (1.9G) [application/octet-stream]
# Saving to: ‘/content/Train.zip’
#
# /content/Train.zip  100%[===================>]   1.87G  2.64MB/s    in 12m 46s
#
# 2025-05-30 11:02:32 (2.50 MB/s) - ‘/content/Train.zip’ saved [2005901570/2005901570]
#
# Extracted files: ['.config', 'MLIAProject', 'Train.zip', 'results_features', 'condacolab_install.log', 'sample_data']

# %%
# !MPLBACKEND=Agg conda run -n clam_latest python MLIAProject/CLAM/create_splits_seq.py --task MLIA_Project --seed 1 --k 10
# Out:
# label column: label
# label dictionary: {'B': 0, 'S': 1, 'E': 2}
# number of classes: 3
# slide-level counts:
#  label
# 0    9
# 1    5
# 2    8
# Name: count, dtype: int64
# Patient-LVL; Number of samples registered in class 0: 9
# Slide-LVL; Number of samples registered in class 0: 9
# Patient-LVL; Number of samples registered in class 1: 5
# Slide-LVL; Number of samples registered in class 1: 5
# Patient-LVL; Number of samples registered in class 2: 8
# Slide-LVL; Number of samples registered in class 2: 8
#
# number of training samples: 18
# number of samples in cls 0: 7
# number of samples in cls 1: 5
# number of samples in cls 2: 6
#
# number of val samples: 2
# number of samples in cls 0: 1
# number of samples in cls 2: 1
#
# number of test samples: 2
# number of samples in cls 0: 1
# number of samples in cls 2: 1
#
#
#
# number of training samples: 18
# number of samples in cls 0: 7
# number of samples in cls 1: 5
# number of samples in cls 2: 6
#
# number of val samples: 2
# ...

# %%
# !MPLBACKEND=Agg CUDA_VISIBLE_DEVICES=0 conda run -n clam_latest python MLIAProject/CLAM/main.py --drop_out 0.25 --early_stopping --lr 2e-4 --k 10 --exp_code MLIA_CLAM_50 --weighted_sample --bag_loss ce --inst_loss svm --task MLIA_Project --model_type clam_sb --log_data --subtyping --data_root_dir /content/results_features --embed_dim 1024
# Out:
# Load Dataset
# label column: label
# label dictionary: {'B': 0, 'S': 1, 'E': 2}
# number of classes: 3
# slide-level counts:
#  label
# 0    9
# 1    5
# 2    8
# Name: count, dtype: int64
# Patient-LVL; Number of samples registered in class 0: 9
# Slide-LVL; Number of samples registered in class 0: 9
# Patient-LVL; Number of samples registered in class 1: 5
# Slide-LVL; Number of samples registered in class 1: 5
# Patient-LVL; Number of samples registered in class 2: 8
# Slide-LVL; Number of samples registered in class 2: 8
# split_dir:  splits/MLIA_Project_100
# ################# Settings ###################
# num_splits:  10
# k_start:  -1
# k_end:  -1
# task:  MLIA_Project
# max_epochs:  200
# results_dir:  ./results
# lr:  0.0002
# experiment:  MLIA_CLAM_50
# reg:  1e-05
# label_frac:  1.0
# bag_loss:  ce
# seed:  1
# model_type:  clam_sb
# model_size:  small
# use_drop_out:  0.25
# weighted_sample:  True
# opt:  adam
# bag_weight:  0.7
# inst_loss:  svm
# B:  8
# ...

# %%
# !zip -r result_classifier.zip 'results/'
# Out:
#   adding: results/ (stored 0%)
#   adding: results/MLIA_CLAM_50_s1/ (stored 0%)
#   adding: results/MLIA_CLAM_50_s1/split_1_results.pkl (deflated 33%)
#   adding: results/MLIA_CLAM_50_s1/5/ (stored 0%)
#   adding: results/MLIA_CLAM_50_s1/5/events.out.tfevents.1748604763.3d8d2da3ec27 (deflated 73%)
#   adding: results/MLIA_CLAM_50_s1/4/ (stored 0%)
#   adding: results/MLIA_CLAM_50_s1/4/events.out.tfevents.1748604232.3d8d2da3ec27 (deflated 74%)
#   adding: results/MLIA_CLAM_50_s1/3/ (stored 0%)
#   adding: results/MLIA_CLAM_50_s1/3/events.out.tfevents.1748604084.3d8d2da3ec27 (deflated 73%)
#   adding: results/MLIA_CLAM_50_s1/7/ (stored 0%)
#   adding: results/MLIA_CLAM_50_s1/7/events.out.tfevents.1748605132.3d8d2da3ec27 (deflated 73%)
#   adding: results/MLIA_CLAM_50_s1/9/ (stored 0%)
#   adding: results/MLIA_CLAM_50_s1/9/events.out.tfevents.1748605530.3d8d2da3ec27 (deflated 73%)
#   adding: results/MLIA_CLAM_50_s1/s_7_checkpoint.pt (deflated 6%)
# ...

# %%
# !MPLBACKEND=Agg CUDA_VISIBLE_DEVICES=0 conda run -n clam_latest python MLIAProject/CLAM/eval.py --k 10 --models_exp_code MLIA_CLAM_50_s1 --save_exp_code MLIA_CLAM_eval --task MLIA_Project --model_type clam_sb --results_dir results --data_root_dir  /content/results_features --embed_dim 1024
# Out:
# Models directory: results/MLIA_CLAM_50_s1
# {'task': 'MLIA_Project', 'split': 'test', 'save_dir': './eval_results/EVAL_MLIA_CLAM_eval', 'models_dir': 'results/MLIA_CLAM_50_s1', 'model_type': 'clam_sb', 'drop_out': 0.25, 'model_size': 'small'}
# label column: label
# label dictionary: {'B': 0, 'S': 1, 'E': 2}
# number of classes: 3
# slide-level counts:
#  label
# 0    9
# 1    5
# 2    8
# Name: count, dtype: int64
# Patient-LVL; Number of samples registered in class 0: 9
# Slide-LVL; Number of samples registered in class 0: 9
# Patient-LVL; Number of samples registered in class 1: 5
# Slide-LVL; Number of samples registered in class 1: 5
# Patient-LVL; Number of samples registered in class 2: 8
# Slide-LVL; Number of samples registered in class 2: 8
# Init Model
# CLAM_SB(
#   (attention_net): Sequential(
#     (0): Linear(in_features=1024, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Attn_Net_Gated(
# ...

# %%
# !zip -r result_evaluation.zip 'eval_results/'
# Out:
#   adding: eval_results/ (stored 0%)
#   adding: eval_results/EVAL_MLIA_CLAM_eval/ (stored 0%)
#   adding: eval_results/EVAL_MLIA_CLAM_eval/fold_1.csv (deflated 32%)
#   adding: eval_results/EVAL_MLIA_CLAM_eval/fold_0.csv (deflated 32%)
#   adding: eval_results/EVAL_MLIA_CLAM_eval/fold_6.csv (deflated 30%)
#   adding: eval_results/EVAL_MLIA_CLAM_eval/fold_4.csv (deflated 31%)
#   adding: eval_results/EVAL_MLIA_CLAM_eval/fold_2.csv (deflated 30%)
#   adding: eval_results/EVAL_MLIA_CLAM_eval/fold_7.csv (deflated 31%)
#   adding: eval_results/EVAL_MLIA_CLAM_eval/eval_experiment_MLIA_CLAM_eval.txt (deflated 31%)
#   adding: eval_results/EVAL_MLIA_CLAM_eval/fold_3.csv (deflated 32%)
#   adding: eval_results/EVAL_MLIA_CLAM_eval/fold_8.csv (deflated 32%)
#   adding: eval_results/EVAL_MLIA_CLAM_eval/fold_5.csv (deflated 31%)
#   adding: eval_results/EVAL_MLIA_CLAM_eval/summary.csv (deflated 44%)
#   adding: eval_results/EVAL_MLIA_CLAM_eval/fold_9.csv (deflated 33%)
