# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from oauth2client.client import GoogleCredentials
import os
import matplotlib.pyplot as plt
import torch
# Out:
# WARNING:root:pydrive is deprecated and no longer maintained. We recommend that you migrate your projects to pydrive2, the maintained fork of pydrive

# %%
# !git clone https://github.com/LucaIanniello/MLIAProject.git
# Out:
# Cloning into 'MLIAProject'...
# remote: Enumerating objects: 404, done.
# remote: Counting objects: 100% (67/67), done.
# remote: Compressing objects: 100% (48/48), done.
# remote: Total 404 (delta 35), reused 47 (delta 19), pack-reused 337 (from 1)
# Receiving objects: 100% (404/404), 96.42 MiB | 45.17 MiB/s, done.
# Resolving deltas: 100% (179/179), done.

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()

# !conda env create -f MLIAProject/CLAM/env.yml
# !conda install -n clam_latest -c conda-forge openslide
# !conda install -n clam_latest -c conda-forge openslide-tools libopenslide0 libtiff-dev libjpeg-dev
# !conda install -n clam_latest -c conda-forge future
# !conda run -n clam_latest python --version
# !conda run -n clam_latest pip list

# !apt-get update
# !apt-get install -y openslide-tools libopenslide0 libtiff-dev libjpeg-dev
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:08
# 🔁 Restarting kernel...
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.2
#     latest version: 25.5.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# Downloading and Extracting Packages:
# python-3.10.0        | 29.8 MB   | :   0% 0/1 [00:00<?, ?it/s]
# tk-8.6.13            | 3.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
# openssl-3.5.0        | 3.0 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# pip-25.1.1           | 1.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# libsqlite-3.50.1     | 898 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# sqlite-3.50.1        | 878 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# ncurses-6.5          | 871 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# libgcc-15.1.0        | 810 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# setuptools-80.9.0    | 731 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 655 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# libgomp-15.1.0       | 442 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# liblzma-devel-5.8.1  | 430 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# readline-8.2         | 276 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 149 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2025b         | 120 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# liblzma-5.8.1        | 110 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xz-tools-5.8.1       | 94 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libffi-3.4.6         | 56 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-ng-15.1.0     | 34 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.0        | 29.8 MB   | :   3% 0.025140325676086286/1 [00:00<00:03,  3.99s/it]
# tk-8.6.13            | 3.1 MB    | :  42% 0.41892558270353986/1 [00:00<00:00,  4.19it/s]
#
# openssl-3.5.0        | 3.0 MB    | :   9% 0.08934596347609072/1 [00:00<00:01,  1.12s/it]
#
#
# pip-25.1.1           | 1.2 MB    | :  26% 0.26362133395548654/1 [00:00<00:00,  2.62it/s]
#
#
#
# libsqlite-3.50.1     | 898 KB    | :  80% 0.8015490004011658/1 [00:00<00:00,  8.01it/s]
#
#
#
# libsqlite-3.50.1     | 898 KB    | : 100% 1.0/1 [00:00<00:00,  8.01it/s]
#
#
# pip-25.1.1           | 1.2 MB    | : 100% 1.0/1 [00:00<00:00,  2.62it/s]
#
#
#
#
# sqlite-3.50.1        | 878 KB    | :   2% 0.0182203163644775/1 [00:00<00:08,  8.71s/it]
#
#
#
#
#
# python-3.10.0        | 29.8 MB   | :  13% 0.12989168265977916/1 [00:00<00:01,  1.40s/it]
#
#
#
#
# sqlite-3.50.1        | 878 KB    | : 100% 1.0/1 [00:00<00:00,  8.71s/it]
#
#
#
#
#
# ncurses-6.5          | 871 KB    | : 100% 1.0/1 [00:00<00:00, 10.37s/it]
#
#
#
#
#
#
# libgcc-15.1.0        | 810 KB    | :   2% 0.019760996154903825/1 [00:00<00:12, 12.34s/it]
#
# openssl-3.5.0        | 3.0 MB    | : 100% 1.0/1 [00:00<00:00,  4.33it/s]
#
# openssl-3.5.0        | 3.0 MB    | : 100% 1.0/1 [00:00<00:00,  4.33it/s]
# tk-8.6.13            | 3.1 MB    | : 100% 1.0/1 [00:00<00:00,  3.80it/s]
# tk-8.6.13            | 3.1 MB    | : 100% 1.0/1 [00:00<00:00,  3.80it/s]
#
#
#
# libsqlite-3.50.1     | 898 KB    | : 100% 1.0/1 [00:00<00:00,  8.01it/s]
#
#
#
#
#
#
# libgcc-15.1.0        | 810 KB    | : 100% 1.0/1 [00:00<00:00, 12.34s/it]
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 655 KB    | :   2% 0.02443057699046426/1 [00:00<00:11, 11.45s/it]
#
#
#
#
#
#
#
#
#
# libgomp-15.1.0       | 442 KB    | :   4% 0.03619693572083467/1 [00:00<00:07,  7.90s/it]
#
#
#
#
#
#
#
# python-3.10.0        | 29.8 MB   | :  26% 0.2566408246100475/1 [00:00<00:00,  1.04s/it]
#
#
#
#
#
#
#
#
#
# libgomp-15.1.0       | 442 KB    | : 100% 1.0/1 [00:00<00:00,  7.90s/it]
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 655 KB    | : 100% 1.0/1 [00:00<00:00, 11.45s/it]
#
#
#
#
#
#
#
#
#
#
# liblzma-devel-5.8.1  | 430 KB    | :   4% 0.037247537897732955/1 [00:00<00:08,  8.75s/it]
#
#
#
#
#
#
#
#
#
#
#
# readline-8.2         | 276 KB    | :   6% 0.05800056641178136/1 [00:00<00:05,  5.72s/it]
#
#
#
#
#
#
#
#
#
#
#
# readline-8.2         | 276 KB    | : 100% 1.0/1 [00:00<00:00,  5.72s/it]
#
#
#
#
#
#
#
# setuptools-80.9.0    | 731 KB    | : 100% 1.0/1 [00:00<00:00, 13.22s/it]
#
#
#
#
#
#
#
#
#
#
# liblzma-devel-5.8.1  | 430 KB    | : 100% 1.0/1 [00:00<00:00,  8.75s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 149 KB    | :  11% 0.10758915965669182/1 [00:00<00:02,  3.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 149 KB    | : 100% 1.0/1 [00:00<00:00,  3.22s/it]
#
#
#
#
# sqlite-3.50.1        | 878 KB    | : 100% 1.0/1 [00:00<00:00,  3.15it/s]
#
#
#
#
# sqlite-3.50.1        | 878 KB    | : 100% 1.0/1 [00:00<00:00,  3.15it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2025b         | 120 KB    | :  13% 0.1332379155552664/1 [00:00<00:02,  2.77s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2025b         | 120 KB    | : 100% 1.0/1 [00:00<00:00,  2.77s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# liblzma-5.8.1        | 110 KB    | :  15% 0.1451272875440679/1 [00:00<00:02,  2.59s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xz-tools-5.8.1       | 94 KB     | :  17% 0.1699003453174743/1 [00:00<00:01,  2.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# liblzma-5.8.1        | 110 KB    | : 100% 1.0/1 [00:00<00:00,  2.59s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.0        | 29.8 MB   | :  43% 0.4284330500633038/1 [00:00<00:00,  1.24it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libffi-3.4.6         | 56 KB     | :  29% 0.2852715337871955/1 [00:00<00:00,  1.40s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libffi-3.4.6         | 56 KB     | : 100% 1.0/1 [00:00<00:00,  1.40s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-ng-15.1.0     | 34 KB     | :  47% 0.47371768923842017/1 [00:00<00:00,  1.15it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-ng-15.1.0     | 34 KB     | : 100% 1.0/1 [00:00<00:00,  1.15it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.0        | 29.8 MB   | :  83% 0.8332970448052767/1 [00:00<00:00,  1.70it/s]
#
#
# pip-25.1.1           | 1.2 MB    | : 100% 1.0/1 [00:00<00:00,  1.17it/s]
#
#
# pip-25.1.1           | 1.2 MB    | : 100% 1.0/1 [00:00<00:00,  1.17it/s]
#
# python-3.10.0        | 29.8 MB   | : 100% 1.0/1 [00:01<00:00,  1.70it/s]
# tk-8.6.13            | 3.1 MB    | : 100% 1.0/1 [00:01<00:00,  3.80it/s]
#
#
#
#
#
#
# libgcc-15.1.0        | 810 KB    | : 100% 1.0/1 [00:01<00:00,  1.49s/it]
#
#
#
#
#
#
# libgcc-15.1.0        | 810 KB    | : 100% 1.0/1 [00:01<00:00,  1.49s/it]
#
#
#
#
#
#
#
#
#
# libgomp-15.1.0       | 442 KB    | : 100% 1.0/1 [00:01<00:00,  1.53s/it]
#
#
#
#
#
#
#
#
#
# libgomp-15.1.0       | 442 KB    | : 100% 1.0/1 [00:01<00:00,  1.53s/it]
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 655 KB    | : 100% 1.0/1 [00:01<00:00,  1.58s/it]
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 655 KB    | : 100% 1.0/1 [00:01<00:00,  1.58s/it]
#
#
#
#
#
#
#
# setuptools-80.9.0    | 731 KB    | : 100% 1.0/1 [00:02<00:00,  1.96s/it]
#
#
#
#
#
#
#
# setuptools-80.9.0    | 731 KB    | : 100% 1.0/1 [00:02<00:00,  1.96s/it]
#
#
#
#
#
#
#
#
#
#
#
# readline-8.2         | 276 KB    | : 100% 1.0/1 [00:02<00:00,  2.00s/it]
#
#
#
#
#
#
#
#
#
#
#
# readline-8.2         | 276 KB    | : 100% 1.0/1 [00:02<00:00,  2.00s/it]
#
#
#
#
#
# ncurses-6.5          | 871 KB    | : 100% 1.0/1 [00:02<00:00,  2.04s/it]
#
#
#
#
#
# ncurses-6.5          | 871 KB    | : 100% 1.0/1 [00:02<00:00,  2.04s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 149 KB    | : 100% 1.0/1 [00:02<00:00,  2.06s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 149 KB    | : 100% 1.0/1 [00:02<00:00,  2.06s/it]
#
#
#
#
#
#
#
#
#
#
# liblzma-devel-5.8.1  | 430 KB    | : 100% 1.0/1 [00:02<00:00,  2.14s/it]
#
#
#
#
#
#
#
#
#
#
# liblzma-devel-5.8.1  | 430 KB    | : 100% 1.0/1 [00:02<00:00,  2.14s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# liblzma-5.8.1        | 110 KB    | : 100% 1.0/1 [00:02<00:00,  2.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# liblzma-5.8.1        | 110 KB    | : 100% 1.0/1 [00:02<00:00,  2.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xz-tools-5.8.1       | 94 KB     | : 100% 1.0/1 [00:02<00:00,  2.27s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xz-tools-5.8.1       | 94 KB     | : 100% 1.0/1 [00:02<00:00,  2.27s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libffi-3.4.6         | 56 KB     | : 100% 1.0/1 [00:02<00:00,  2.37s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libffi-3.4.6         | 56 KB     | : 100% 1.0/1 [00:02<00:00,  2.37s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-ng-15.1.0     | 34 KB     | : 100% 1.0/1 [00:02<00:00,  2.56s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-ng-15.1.0     | 34 KB     | : 100% 1.0/1 [00:02<00:00,  2.56s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2025b         | 120 KB    | : 100% 1.0/1 [00:02<00:00,  2.41s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.0        | 29.8 MB   | : 100% 1.0/1 [00:07<00:00,  1.70it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done
# | Ran pip subprocess with arguments:
# ['/usr/local/envs/clam_latest/bin/python', '-m', 'pip', 'install', '-U', '-r', '/content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt', '--exists-action=b']
# Pip subprocess output:
# Collecting git+https://github.com/oval-group/smooth-topk.git (from -r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 13))
#   Cloning https://github.com/oval-group/smooth-topk.git to /tmp/pip-req-build-g23kl0e5
#   Resolved https://github.com/oval-group/smooth-topk.git to commit 12c1645f187e2fa0c05f47bf1fe48864d4bd2707
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting timm==0.9.8 (from -r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 1))
#   Downloading timm-0.9.8-py3-none-any.whl.metadata (59 kB)
# Collecting torch (from -r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 2))
#   Downloading torch-2.7.1-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Collecting torchvision (from -r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 3))
#   Downloading torchvision-0.22.1-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Collecting h5py (from -r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 4))
#   Downloading h5py-3.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Collecting pandas (from -r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 5))
#   Downloading pandas-2.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (91 kB)
# Collecting PyYAML (from -r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 6))
#   Downloading PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting opencv-python (from -r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 7))
#   Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting matplotlib (from -r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 8))
#   Downloading matplotlib-3.10.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting scikit-learn (from -r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 9))
#   Downloading scikit_learn-1.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (17 kB)
# Collecting scipy (from -r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 10))
#   Downloading scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting tqdm (from -r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 11))
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting openslide-python (from -r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 12))
#   Downloading openslide_python-1.4.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (4.9 kB)
# Collecting tensorboardX (from -r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 14))
#   Downloading tensorboardx-2.6.4-py3-none-any.whl.metadata (6.2 kB)
# Collecting numpy (from topk==1.0->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 13))
#   Downloading numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting huggingface-hub (from timm==0.9.8->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 1))
#   Downloading huggingface_hub-0.33.0-py3-none-any.whl.metadata (14 kB)
# Collecting safetensors (from timm==0.9.8->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 1))
#   Downloading safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting filelock (from torch->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 2))
#   Downloading filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting typing-extensions>=4.10.0 (from torch->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 2))
#   Downloading typing_extensions-4.14.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting sympy>=1.13.3 (from torch->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 2))
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 2))
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 2))
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec (from torch->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 2))
#   Downloading fsspec-2025.5.1-py3-none-any.whl.metadata (11 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77 (from torch->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 2))
#   Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.6.77 (from torch->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 2))
#   Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.6.80 (from torch->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 2))
#   Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.5.1.17 (from torch->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 2))
#   Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.6.4.1 (from torch->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 2))
#   Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.3.0.4 (from torch->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 2))
#   Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.7.77 (from torch->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 2))
#   Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.7.1.2 (from torch->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 2))
#   Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.5.4.2 (from torch->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 2))
#   Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.3 (from torch->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 2))
#   Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.26.2 (from torch->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 2))
#   Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvtx-cu12==12.6.77 (from torch->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 2))
#   Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nvjitlink-cu12==12.6.85 (from torch->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 2))
#   Downloading nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufile-cu12==1.11.1.6 (from torch->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 2))
#   Downloading nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.3.1 (from torch->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 2))
#   Downloading triton-3.3.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/envs/clam_latest/lib/python3.10/site-packages (from triton==3.3.1->torch->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 2)) (80.9.0)
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 3))
#   Downloading pillow-11.2.1-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (8.9 kB)
# Collecting python-dateutil>=2.8.2 (from pandas->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 5))
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 5))
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 5))
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 8))
#   Downloading contourpy-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 8))
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 8))
#   Downloading fonttools-4.58.4-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (106 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 8))
#   Downloading kiwisolver-1.4.8-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.2 kB)
# Collecting packaging>=20.0 (from matplotlib->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 8))
#   Downloading packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 8))
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Collecting joblib>=1.2.0 (from scikit-learn->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 9))
#   Downloading joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 9))
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting protobuf>=3.20 (from tensorboardX->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 14))
#   Downloading protobuf-6.31.1-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->pandas->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 5))
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 2))
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting requests (from huggingface-hub->timm==0.9.8->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 1))
#   Downloading requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Collecting hf-xet<2.0.0,>=1.1.2 (from huggingface-hub->timm==0.9.8->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 1))
#   Downloading hf_xet-1.1.3-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (879 bytes)
# Collecting MarkupSafe>=2.0 (from jinja2->torch->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 2))
#   Downloading MarkupSafe-3.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting charset_normalizer<4,>=2 (from requests->huggingface-hub->timm==0.9.8->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 1))
#   Downloading charset_normalizer-3.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# Collecting idna<4,>=2.5 (from requests->huggingface-hub->timm==0.9.8->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 1))
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->huggingface-hub->timm==0.9.8->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 1))
#   Downloading urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests->huggingface-hub->timm==0.9.8->-r /content/MLIAProject/CLAM/condaenv.t_2hj6gp.requirements.txt (line 1))
#   Downloading certifi-2025.4.26-py3-none-any.whl.metadata (2.5 kB)
# Downloading timm-0.9.8-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 65.7 MB/s eta 0:00:00
# Downloading torch-2.7.1-cp310-cp310-manylinux_2_28_x86_64.whl (821.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.2/821.2 MB 28.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (393.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 MB 31.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 79.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 81.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.7/897.7 kB 30.9 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl (571.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.0/571.0 MB 34.1 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (200.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.2/200.2 MB 66.5 MB/s eta 0:00:00
# Downloading nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 55.2 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 51.8 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (158.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 MB 58.2 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 MB 65.8 MB/s eta 0:00:00
# Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl (156.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 MB 59.5 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 MB 63.3 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 64.6 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Downloading triton-3.3.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 MB 64.3 MB/s eta 0:00:00
# Downloading torchvision-0.22.1-cp310-cp310-manylinux_2_28_x86_64.whl (7.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 107.3 MB/s eta 0:00:00
# Downloading h5py-3.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 102.2 MB/s eta 0:00:00
# Downloading pandas-2.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 123.1 MB/s eta 0:00:00
# Downloading PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (751 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 751.2/751.2 kB 42.7 MB/s eta 0:00:00
# Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (63.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 MB 53.5 MB/s eta 0:00:00
# Downloading matplotlib-3.10.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 116.6 MB/s eta 0:00:00
# Downloading scikit_learn-1.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 127.3 MB/s eta 0:00:00
# Downloading scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.7/37.7 MB 50.2 MB/s eta 0:00:00
# Downloading numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 100.9 MB/s eta 0:00:00
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading openslide_python-1.4.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.whl (40 kB)
# Downloading tensorboardx-2.6.4-py3-none-any.whl (87 kB)
# Downloading contourpy-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (325 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.58.4-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 86.0 MB/s eta 0:00:00
# Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
# Downloading kiwisolver-1.4.8-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 61.1 MB/s eta 0:00:00
# Downloading packaging-25.0-py3-none-any.whl (66 kB)
# Downloading pillow-11.2.1-cp310-cp310-manylinux_2_28_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 82.5 MB/s eta 0:00:00
# Downloading protobuf-6.31.1-cp39-abi3-manylinux2014_x86_64.whl (321 kB)
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 68.4 MB/s eta 0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 22.0 MB/s eta 0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading typing_extensions-4.14.0-py3-none-any.whl (43 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Downloading fsspec-2025.5.1-py3-none-any.whl (199 kB)
# Downloading huggingface_hub-0.33.0-py3-none-any.whl (514 kB)
# Downloading hf_xet-1.1.3-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 57.3 MB/s eta 0:00:00
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading MarkupSafe-3.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20 kB)
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 42.6 MB/s eta 0:00:00
# Downloading requests-2.32.4-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading urllib3-2.4.0-py3-none-any.whl (128 kB)
# Downloading certifi-2025.4.26-py3-none-any.whl (159 kB)
# Downloading safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (471 kB)
# Building wheels for collected packages: topk
#   Building wheel for topk (setup.py): started
#   Building wheel for topk (setup.py): finished with status 'done'
#   Created wheel for topk: filename=topk-1.0-py3-none-any.whl size=10041 sha256=49ca391a97edda4d7fe16a3835ce687bea9dff80fbd29ee41db5ce1fd35fc022
#   Stored in directory: /tmp/pip-ephem-wheel-cache-po62c_dc/wheels/b5/e1/65/94fdd820e9a24c2f8520b542ddea5a1d05e88fb34fd768d536
# Successfully built topk
# Installing collected packages: pytz, nvidia-cusparselt-cu12, mpmath, urllib3, tzdata, typing-extensions, triton, tqdm, threadpoolctl, sympy, six, safetensors, PyYAML, pyparsing, protobuf, pillow, packaging, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, kiwisolver, joblib, idna, hf-xet, fsspec, fonttools, filelock, cycler, charset_normalizer, certifi, tensorboardX, scipy, requests, python-dateutil, openslide-python, opencv-python, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, jinja2, h5py, contourpy, scikit-learn, pandas, nvidia-cusolver-cu12, matplotlib, huggingface-hub, torch, torchvision, topk, timm
#
# Successfully installed MarkupSafe-3.0.2 PyYAML-6.0.2 certifi-2025.4.26 charset_normalizer-3.4.2 contourpy-1.3.2 cycler-0.12.1 filelock-3.18.0 fonttools-4.58.4 fsspec-2025.5.1 h5py-3.14.0 hf-xet-1.1.3 huggingface-hub-0.33.0 idna-3.10 jinja2-3.1.6 joblib-1.5.1 kiwisolver-1.4.8 matplotlib-3.10.3 mpmath-1.3.0 networkx-3.4.2 numpy-2.2.6 nvidia-cublas-cu12-12.6.4.1 nvidia-cuda-cupti-cu12-12.6.80 nvidia-cuda-nvrtc-cu12-12.6.77 nvidia-cuda-runtime-cu12-12.6.77 nvidia-cudnn-cu12-9.5.1.17 nvidia-cufft-cu12-11.3.0.4 nvidia-cufile-cu12-1.11.1.6 nvidia-curand-cu12-10.3.7.77 nvidia-cusolver-cu12-11.7.1.2 nvidia-cusparse-cu12-12.5.4.2 nvidia-cusparselt-cu12-0.6.3 nvidia-nccl-cu12-2.26.2 nvidia-nvjitlink-cu12-12.6.85 nvidia-nvtx-cu12-12.6.77 opencv-python-4.11.0.86 openslide-python-1.4.2 packaging-25.0 pandas-2.3.0 pillow-11.2.1 protobuf-6.31.1 pyparsing-3.2.3 python-dateutil-2.9.0.post0 pytz-2025.2 requests-2.32.4 safetensors-0.5.3 scikit-learn-1.7.0 scipy-1.15.3 six-1.17.0 sympy-1.14.0 tensorboardX-2.6.4 threadpoolctl-3.6.0 timm-0.9.8 topk-1.0 torch-2.7.1 torchvision-0.22.1 tqdm-4.67.1 triton-3.3.1 typing-extensions-4.14.0 tzdata-2025.2 urllib3-2.4.0
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate clam_latest
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.2
#     latest version: 25.5.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/clam_latest
#
#   added / updated specs:
#     - openslide
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cairo-1.18.4               |       h3394656_0         955 KB  conda-forge
#     font-ttf-dejavu-sans-mono-2.37|       hab24e00_0         388 KB  conda-forge
#     font-ttf-inconsolata-3.000 |       h77eed37_0          94 KB  conda-forge
#     font-ttf-source-code-pro-2.038|       h77eed37_0         684 KB  conda-forge
#     font-ttf-ubuntu-0.83       |       h77eed37_3         1.5 MB  conda-forge
#     fontconfig-2.15.0          |       h7e30c49_1         259 KB  conda-forge
#     fonts-conda-ecosystem-1    |                0           4 KB  conda-forge
#     fonts-conda-forge-1        |                0           4 KB  conda-forge
#     freetype-2.13.3            |       ha770c72_1         168 KB  conda-forge
#     gdk-pixbuf-2.42.12         |       hb9ae30d_0         516 KB  conda-forge
#     icu-75.1                   |       he02047a_0        11.6 MB  conda-forge
#     lerc-4.0.0                 |       h0aef613_1         258 KB  conda-forge
#     libdeflate-1.24            |       h86f0d12_0          71 KB  conda-forge
#     libdicom-1.0.5             |       hd590300_1          99 KB  conda-forge
#     libexpat-2.7.0             |       h5888daf_0          73 KB  conda-forge
#     libfreetype-2.13.3         |       ha770c72_1           8 KB  conda-forge
#     libfreetype6-2.13.3        |       h48d6fc4_1         371 KB  conda-forge
#     libglib-2.84.2             |       h3618099_0         3.8 MB  conda-forge
#     libiconv-1.18              |       h4ce23a2_1         696 KB  conda-forge
#     libjpeg-turbo-3.1.0        |       hb9d3cd8_0         614 KB  conda-forge
#     libpng-1.6.47              |       h943b412_0         282 KB  conda-forge
#     libstdcxx-15.1.0           |       h8f9b012_2         3.7 MB  conda-forge
#     libstdcxx-ng-15.1.0        |       h4852527_2          34 KB  conda-forge
#     libtiff-4.7.0              |       hf01ce69_5         420 KB  conda-forge
#     libwebp-base-1.5.0         |       h851e524_0         420 KB  conda-forge
#     libxcb-1.17.0              |       h8a09558_0         387 KB  conda-forge
#     libxml2-2.13.8             |       h4bc477f_0         675 KB  conda-forge
#     openjpeg-2.5.3             |       h5fbd93e_0         335 KB  conda-forge
#     openslide-4.0.0            |       h58ba908_1         139 KB  conda-forge
#     pcre2-10.45                |       hc749103_0         1.1 MB  conda-forge
#     pixman-0.46.2              |       h29eaf8c_0         393 KB  conda-forge
#     pthread-stubs-0.4          |    hb9d3cd8_1002           8 KB  conda-forge
#     xorg-libice-1.1.2          |       hb9d3cd8_0          57 KB  conda-forge
#     xorg-libsm-1.2.6           |       he73a12e_0          27 KB  conda-forge
#     xorg-libx11-1.8.12         |       h4f16b4b_0         816 KB  conda-forge
#     xorg-libxau-1.0.12         |       hb9d3cd8_0          14 KB  conda-forge
#     xorg-libxdmcp-1.1.5        |       hb9d3cd8_0          19 KB  conda-forge
#     xorg-libxext-1.3.6         |       hb9d3cd8_0          49 KB  conda-forge
#     xorg-libxrender-0.9.12     |       hb9d3cd8_0          32 KB  conda-forge
#     zstd-1.5.7                 |       hb8e6e7a_2         554 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        31.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   cairo              conda-forge/linux-64::cairo-1.18.4-h3394656_0
#   font-ttf-dejavu-s~ conda-forge/noarch::font-ttf-dejavu-sans-mono-2.37-hab24e00_0
#   font-ttf-inconsol~ conda-forge/noarch::font-ttf-inconsolata-3.000-h77eed37_0
#   font-ttf-source-c~ conda-forge/noarch::font-ttf-source-code-pro-2.038-h77eed37_0
#   font-ttf-ubuntu    conda-forge/noarch::font-ttf-ubuntu-0.83-h77eed37_3
#   fontconfig         conda-forge/linux-64::fontconfig-2.15.0-h7e30c49_1
#   fonts-conda-ecosy~ conda-forge/noarch::fonts-conda-ecosystem-1-0
#   fonts-conda-forge  conda-forge/noarch::fonts-conda-forge-1-0
#   freetype           conda-forge/linux-64::freetype-2.13.3-ha770c72_1
#   gdk-pixbuf         conda-forge/linux-64::gdk-pixbuf-2.42.12-hb9ae30d_0
#   icu                conda-forge/linux-64::icu-75.1-he02047a_0
#   lerc               conda-forge/linux-64::lerc-4.0.0-h0aef613_1
#   libdeflate         conda-forge/linux-64::libdeflate-1.24-h86f0d12_0
#   libdicom           conda-forge/linux-64::libdicom-1.0.5-hd590300_1
#   libexpat           conda-forge/linux-64::libexpat-2.7.0-h5888daf_0
#   libfreetype        conda-forge/linux-64::libfreetype-2.13.3-ha770c72_1
#   libfreetype6       conda-forge/linux-64::libfreetype6-2.13.3-h48d6fc4_1
#   libglib            conda-forge/linux-64::libglib-2.84.2-h3618099_0
#   libiconv           conda-forge/linux-64::libiconv-1.18-h4ce23a2_1
#   libjpeg-turbo      conda-forge/linux-64::libjpeg-turbo-3.1.0-hb9d3cd8_0
#   libpng             conda-forge/linux-64::libpng-1.6.47-h943b412_0
#   libstdcxx          conda-forge/linux-64::libstdcxx-15.1.0-h8f9b012_2
#   libstdcxx-ng       conda-forge/linux-64::libstdcxx-ng-15.1.0-h4852527_2
#   libtiff            conda-forge/linux-64::libtiff-4.7.0-hf01ce69_5
#   libwebp-base       conda-forge/linux-64::libwebp-base-1.5.0-h851e524_0
#   libxcb             conda-forge/linux-64::libxcb-1.17.0-h8a09558_0
#   libxml2            conda-forge/linux-64::libxml2-2.13.8-h4bc477f_0
#   openjpeg           conda-forge/linux-64::openjpeg-2.5.3-h5fbd93e_0
#   openslide          conda-forge/linux-64::openslide-4.0.0-h58ba908_1
#   pcre2              conda-forge/linux-64::pcre2-10.45-hc749103_0
#   pixman             conda-forge/linux-64::pixman-0.46.2-h29eaf8c_0
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-hb9d3cd8_1002
#   xorg-libice        conda-forge/linux-64::xorg-libice-1.1.2-hb9d3cd8_0
#   xorg-libsm         conda-forge/linux-64::xorg-libsm-1.2.6-he73a12e_0
#   xorg-libx11        conda-forge/linux-64::xorg-libx11-1.8.12-h4f16b4b_0
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.12-hb9d3cd8_0
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.5-hb9d3cd8_0
#   xorg-libxext       conda-forge/linux-64::xorg-libxext-1.3.6-hb9d3cd8_0
#   xorg-libxrender    conda-forge/linux-64::xorg-libxrender-0.9.12-hb9d3cd8_0
#   zstd               conda-forge/linux-64::zstd-1.5.7-hb8e6e7a_2
#
#
#
# Downloading and Extracting Packages:
# icu-75.1             | 11.6 MB   | :   0% 0/1 [00:00<?, ?it/s]
# libglib-2.84.2       | 3.8 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
# libstdcxx-15.1.0     | 3.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# pcre2-10.45          | 1.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# cairo-1.18.4         | 955 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# xorg-libx11-1.8.12   | 816 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# libiconv-1.18        | 696 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# font-ttf-source-code | 684 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# libxml2-2.13.8       | 675 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# libjpeg-turbo-3.1.0  | 614 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# zstd-1.5.7           | 554 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# gdk-pixbuf-2.42.12   | 516 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# libwebp-base-1.5.0   | 420 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.7.0        | 420 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pixman-0.46.2        | 393 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-dejavu-sans | 388 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxcb-1.17.0        | 387 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libfreetype6-2.13.3  | 371 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# libglib-2.84.2       | 3.8 MB    | :  28% 0.27754985631086815/1 [00:00<00:00,  2.77it/s]
#
# icu-75.1             | 11.6 MB   | :   1% 0.00540315798160852/1 [00:00<00:19, 19.19s/it]
#
#
#
# pcre2-10.45          | 1.1 MB    | :  36% 0.35578481059176087/1 [00:00<00:00,  3.56it/s]
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | :   6% 0.06066260866989529/1 [00:00<00:01,  1.74s/it]
#
#
#
# pcre2-10.45          | 1.1 MB    | : 100% 1.0/1 [00:00<00:00,  3.56it/s]
#
#
#
#
# cairo-1.18.4         | 955 KB    | :   2% 0.016750603712859646/1 [00:00<00:09,  9.59s/it]
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | : 100% 1.0/1 [00:00<00:00,  1.74s/it]
#
#
#
#
# cairo-1.18.4         | 955 KB    | : 100% 1.0/1 [00:00<00:00,  9.59s/it]
# icu-75.1             | 11.6 MB   | :  35% 0.34580211082294526/1 [00:00<00:00,  1.99it/s]
#
#
#
#
#
#
# libiconv-1.18        | 696 KB    | :   2% 0.02297625525183569/1 [00:00<00:09,  9.60s/it]
#
#
#
#
#
# xorg-libx11-1.8.12   | 816 KB    | :   2% 0.019600524467158594/1 [00:00<00:11, 11.72s/it]
#
#
#
#
#
#
# libiconv-1.18        | 696 KB    | : 100% 1.0/1 [00:00<00:00,  9.60s/it]
#
#
#
#
#
# xorg-libx11-1.8.12   | 816 KB    | : 100% 1.0/1 [00:00<00:00, 11.72s/it]
#
# libstdcxx-15.1.0     | 3.7 MB    | : 100% 1.0/1 [00:00<00:00,  3.98it/s]
#
# libstdcxx-15.1.0     | 3.7 MB    | : 100% 1.0/1 [00:00<00:00,  3.98it/s]
# libglib-2.84.2       | 3.8 MB    | : 100% 1.0/1 [00:00<00:00,  5.34it/s]
#
#
#
#
#
#
#
# icu-75.1             | 11.6 MB   | :  73% 0.7321279065079545/1 [00:00<00:00,  2.84it/s]
#
#
#
#
#
#
#
#
#
# libjpeg-turbo-3.1.0  | 614 KB    | :   3% 0.026049889736337085/1 [00:00<00:11, 11.65s/it]
#
#
#
#
#
#
#
#
# libxml2-2.13.8       | 675 KB    | :   2% 0.02371523194145302/1 [00:00<00:12, 12.90s/it]
#
#
#
#
#
#
#
# font-ttf-source-code | 684 KB    | : 100% 1.0/1 [00:00<00:00, 12.10s/it]
#
#
#
#
#
#
#
#
#
#
# zstd-1.5.7           | 554 KB    | :   3% 0.02886651702497278/1 [00:00<00:10, 10.86s/it]
#
#
#
#
#
#
#
#
#
#
# zstd-1.5.7           | 554 KB    | : 100% 1.0/1 [00:00<00:00, 10.86s/it]
#
#
#
#
#
#
#
#
#
# libjpeg-turbo-3.1.0  | 614 KB    | : 100% 1.0/1 [00:00<00:00, 11.65s/it]
#
#
#
#
#
#
#
#
# libxml2-2.13.8       | 675 KB    | : 100% 1.0/1 [00:00<00:00, 12.90s/it]
#
#
#
#
#
#
#
#
#
#
#
# gdk-pixbuf-2.42.12   | 516 KB    | :   3% 0.031021548843224167/1 [00:00<00:10, 11.11s/it]
#
#
#
#
#
#
#
#
#
#
#
# gdk-pixbuf-2.42.12   | 516 KB    | : 100% 1.0/1 [00:00<00:00, 11.11s/it]
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | : 100% 1.0/1 [00:00<00:00,  2.88it/s]
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | : 100% 1.0/1 [00:00<00:00,  2.88it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# libwebp-base-1.5.0   | 420 KB    | :   4% 0.038104718203236014/1 [00:00<00:09,  9.56s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.7.0        | 420 KB    | :   4% 0.03814002211488099/1 [00:00<00:09,  9.62s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# libwebp-base-1.5.0   | 420 KB    | : 100% 1.0/1 [00:00<00:00,  9.56s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.7.0        | 420 KB    | : 100% 1.0/1 [00:00<00:00,  9.62s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-dejavu-sans | 388 KB    | :   4% 0.04123109444598234/1 [00:00<00:09,  9.40s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pixman-0.46.2        | 393 KB    | :   4% 0.040733724162278544/1 [00:00<00:09,  9.64s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-dejavu-sans | 388 KB    | : 100% 1.0/1 [00:00<00:00,  9.40s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pixman-0.46.2        | 393 KB    | : 100% 1.0/1 [00:00<00:00,  9.64s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxcb-1.17.0        | 387 KB    | :   4% 0.04138544234733056/1 [00:00<00:09,  9.84s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libfreetype6-2.13.3  | 371 KB    | :   4% 0.04310059084428123/1 [00:00<00:09,  9.56s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxcb-1.17.0        | 387 KB    | : 100% 1.0/1 [00:00<00:00,  9.84s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libfreetype6-2.13.3  | 371 KB    | : 100% 1.0/1 [00:00<00:00,  9.56s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
# cairo-1.18.4         | 955 KB    | : 100% 1.0/1 [00:00<00:00,  2.16it/s]
#
#
#
#
# icu-75.1             | 11.6 MB   | : 100% 1.0/1 [00:00<00:00,  2.84it/s]
#
#
#
# pcre2-10.45          | 1.1 MB    | : 100% 1.0/1 [00:00<00:00,  1.53it/s]
#
#
#
# pcre2-10.45          | 1.1 MB    | : 100% 1.0/1 [00:00<00:00,  1.53it/s]
#
#
#
#
#
#
# libiconv-1.18        | 696 KB    | : 100% 1.0/1 [00:00<00:00,  1.79it/s]
#
#
#
#
#
#
# libiconv-1.18        | 696 KB    | : 100% 1.0/1 [00:00<00:00,  1.79it/s]
#
#
#
#
#
# xorg-libx11-1.8.12   | 816 KB    | : 100% 1.0/1 [00:00<00:00,  1.49it/s]
#
#
#
#
#
# xorg-libx11-1.8.12   | 816 KB    | : 100% 1.0/1 [00:00<00:00,  1.49it/s]
#
# libstdcxx-15.1.0     | 3.7 MB    | : 100% 1.0/1 [00:00<00:00,  3.98it/s]
#
#
#
#
#
#
#
# font-ttf-source-code | 684 KB    | : 100% 1.0/1 [00:00<00:00,  1.12it/s]
#
#
#
#
#
#
#
# font-ttf-source-code | 684 KB    | : 100% 1.0/1 [00:00<00:00,  1.12it/s]
# libglib-2.84.2       | 3.8 MB    | : 100% 1.0/1 [00:00<00:00,  5.34it/s]
#
#
#
#
#
#
#
#
#
#
# zstd-1.5.7           | 554 KB    | : 100% 1.0/1 [00:01<00:00,  1.09it/s]
#
#
#
#
#
#
#
#
#
#
# zstd-1.5.7           | 554 KB    | : 100% 1.0/1 [00:01<00:00,  1.09it/s]
#
#
#
#
#
#
#
#
#
# libjpeg-turbo-3.1.0  | 614 KB    | : 100% 1.0/1 [00:01<00:00,  1.04it/s]
#
#
#
#
#
#
#
#
#
# libjpeg-turbo-3.1.0  | 614 KB    | : 100% 1.0/1 [00:01<00:00,  1.04it/s]
#
#
#
#
#
#
#
#
# libxml2-2.13.8       | 675 KB    | : 100% 1.0/1 [00:01<00:00,  1.02it/s]
#
#
#
#
#
#
#
#
# libxml2-2.13.8       | 675 KB    | : 100% 1.0/1 [00:01<00:00,  1.02it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# libwebp-base-1.5.0   | 420 KB    | : 100% 1.0/1 [00:01<00:00,  1.02s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# libwebp-base-1.5.0   | 420 KB    | : 100% 1.0/1 [00:01<00:00,  1.02s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.7.0        | 420 KB    | : 100% 1.0/1 [00:01<00:00,  1.06s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.7.0        | 420 KB    | : 100% 1.0/1 [00:01<00:00,  1.06s/it]
#
#
#
#
#
#
#
#
#
#
#
# gdk-pixbuf-2.42.12   | 516 KB    | : 100% 1.0/1 [00:01<00:00,  1.08s/it]
#
#
#
#
#
#
#
#
#
#
#
# gdk-pixbuf-2.42.12   | 516 KB    | : 100% 1.0/1 [00:01<00:00,  1.08s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pixman-0.46.2        | 393 KB    | : 100% 1.0/1 [00:01<00:00,  1.09s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pixman-0.46.2        | 393 KB    | : 100% 1.0/1 [00:01<00:00,  1.09s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-dejavu-sans | 388 KB    | : 100% 1.0/1 [00:01<00:00,  1.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-dejavu-sans | 388 KB    | : 100% 1.0/1 [00:01<00:00,  1.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxcb-1.17.0        | 387 KB    | : 100% 1.0/1 [00:01<00:00,  1.16s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxcb-1.17.0        | 387 KB    | : 100% 1.0/1 [00:01<00:00,  1.16s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libfreetype6-2.13.3  | 371 KB    | : 100% 1.0/1 [00:01<00:00,  1.16s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libfreetype6-2.13.3  | 371 KB    | : 100% 1.0/1 [00:01<00:00,  1.16s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-75.1             | 11.6 MB   | : 100% 1.0/1 [00:01<00:00,  2.84it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# -
# done
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# failed
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - openslide-tools
#   - libtiff-dev
#   - libopenslide0
#   - libjpeg-dev
#
# Current channels:
#
#   - https://conda.anaconda.org/conda-forge
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.2
#     latest version: 25.5.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/clam_latest
#
#   added / updated specs:
#     - future
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     future-1.0.0               |     pyhd8ed1ab_2         356 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         356 KB
#
# The following NEW packages will be INSTALLED:
#
#   future             conda-forge/noarch::future-1.0.0-pyhd8ed1ab_2
#
#
#
# Downloading and Extracting Packages:
#
# done
# done
# done
# Python 3.10.0
#
# Package                  Version
# ------------------------ -----------
# certifi                  2025.4.26
# charset-normalizer       3.4.2
# contourpy                1.3.2
# cycler                   0.12.1
# filelock                 3.18.0
# fonttools                4.58.4
# fsspec                   2025.5.1
# future                   1.0.0
# h5py                     3.14.0
# hf-xet                   1.1.3
# huggingface-hub          0.33.0
# idna                     3.10
# Jinja2                   3.1.6
# joblib                   1.5.1
# kiwisolver               1.4.8
# MarkupSafe               3.0.2
# matplotlib               3.10.3
# mpmath                   1.3.0
# networkx                 3.4.2
# numpy                    2.2.6
# nvidia-cublas-cu12       12.6.4.1
# nvidia-cuda-cupti-cu12   12.6.80
# nvidia-cuda-nvrtc-cu12   12.6.77
# nvidia-cuda-runtime-cu12 12.6.77
# nvidia-cudnn-cu12        9.5.1.17
# nvidia-cufft-cu12        11.3.0.4
# nvidia-cufile-cu12       1.11.1.6
# nvidia-curand-cu12       10.3.7.77
# nvidia-cusolver-cu12     11.7.1.2
# nvidia-cusparse-cu12     12.5.4.2
# nvidia-cusparselt-cu12   0.6.3
# nvidia-nccl-cu12         2.26.2
# nvidia-nvjitlink-cu12    12.6.85
# nvidia-nvtx-cu12         12.6.77
# opencv-python            4.11.0.86
# openslide-python         1.4.2
# packaging                25.0
# pandas                   2.3.0
# pillow                   11.2.1
# pip                      25.1.1
# protobuf                 6.31.1
# pyparsing                3.2.3
# python-dateutil          2.9.0.post0
# pytz                     2025.2
# PyYAML                   6.0.2
# requests                 2.32.4
# safetensors              0.5.3
# scikit-learn             1.7.0
# scipy                    1.15.3
# setuptools               80.9.0
# six                      1.17.0
# sympy                    1.14.0
# tensorboardX             2.6.4
# threadpoolctl            3.6.0
# timm                     0.9.8
# topk                     1.0
# torch                    2.7.1
# torchvision              0.22.1
# tqdm                     4.67.1
# triton                   3.3.1
# typing_extensions        4.14.0
# tzdata                   2025.2
# urllib3                  2.4.0
# wheel                    0.45.1
#
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,776 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,750 kB]
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,249 kB]
# Hit:11 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,296 kB]
# Hit:13 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,986 kB]
# Hit:15 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:16 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,037 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,556 kB]
# Fetched 23.0 MB in 2s (10.7 MB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libjpeg-dev is already the newest version (8c-2ubuntu10).
# libjpeg-dev set to manually installed.
# libtiff-dev is already the newest version (4.3.0-6ubuntu0.10).
# libtiff-dev set to manually installed.
# Suggested packages:
#   libtiff-tools
# The following NEW packages will be installed:
#   libopenslide0 openslide-tools
# 0 upgraded, 2 newly installed, 0 to remove and 35 not upgraded.
# Need to get 104 kB of archives.
# After this operation, 297 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenslide0 amd64 3.4.1+dfsg-5build1 [89.8 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 openslide-tools amd64 3.4.1+dfsg-5build1 [13.8 kB]
# Fetched 104 kB in 1s (123 kB/s)
# Selecting previously unselected package libopenslide0.
# (Reading database ... 126111 files and directories currently installed.)
# Preparing to unpack .../libopenslide0_3.4.1+dfsg-5build1_amd64.deb ...
# Unpacking libopenslide0 (3.4.1+dfsg-5build1) ...
# Selecting previously unselected package openslide-tools.
# Preparing to unpack .../openslide-tools_3.4.1+dfsg-5build1_amd64.deb ...
# Unpacking openslide-tools (3.4.1+dfsg-5build1) ...
# Setting up libopenslide0 (3.4.1+dfsg-5build1) ...
# Setting up openslide-tools (3.4.1+dfsg-5build1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/liblzma.so.5 is not a symbolic link

# %%
# !conda --version
# !which conda
# !conda config --show-sources
# !conda env update -n base -f MLIAProject/CLAM/env.yml
# Out:
# conda 24.11.2
# /usr/local/bin/conda
# ==> /usr/local/.condarc <==
# channels:
#   - conda-forge
# always_yes: True
#
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# failed
#
# SpecsConfigurationConflictError: Requested specs conflict with configured specs.
#   requested specs:
#     - pip
#     - python==3.10
#   pinned specs:
#     - cuda-version=12
#     - python=3.11
#     - python_abi=3.11[build=*cp311*]
# Use 'conda config --show-sources' to look for 'pinned_specs' and 'track_features'
# configuration parameters.  Pinned specs may also be defined in the file
# /usr/local/conda-meta/pinned.

# %%
import os
import zipfile

# URL for the dataset
url = "https://zenodo.org/records/15547611/files/datasetUnified_PT.zip?download=1"

# Download the file using wget
# !wget -O /content/Train.zip "$url"

# Define the extraction path
extract_path = './'

# Create the extraction directory if it doesn't exist
os.makedirs(extract_path, exist_ok=True)

# Extract the ZIP file
with zipfile.ZipFile('./Train.zip', 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# List the contents of the extracted folder
extracted_files = os.listdir(extract_path)
print("Extracted files:", extracted_files)
# Out:
# --2025-06-14 08:51:47--  https://zenodo.org/records/15547611/files/datasetUnified_PT.zip?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.48.194, 188.185.43.25, 188.185.45.92, ...
# Connecting to zenodo.org (zenodo.org)|188.185.48.194|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2005901570 (1.9G) [application/octet-stream]
# Saving to: ‘/content/Train.zip’
#
# /content/Train.zip  100%[===================>]   1.87G  19.9MB/s    in 97s
#
# 2025-06-14 08:53:25 (19.7 MB/s) - ‘/content/Train.zip’ saved [2005901570/2005901570]
#
# Extracted files: ['.config', 'condacolab_install.log', 'Train.zip', 'MLIAProject', 'results_features', 'sample_data']

# %%
# !MPLBACKEND=Agg conda run -n clam_latest python MLIAProject/CLAM/create_splits_seq.py --task MLIA_Project --seed 1 --k 1 --val_frac 0.2 --test_frac 0.2
# Out:
# label column: label
# label dictionary: {'B': 0, 'S': 1, 'E': 2}
# number of classes: 3
# slide-level counts:
#  label
# 0    9
# 1    5
# 2    8
# Name: count, dtype: int64
# Patient-LVL; Number of samples registered in class 0: 9
# Slide-LVL; Number of samples registered in class 0: 9
# Patient-LVL; Number of samples registered in class 1: 5
# Slide-LVL; Number of samples registered in class 1: 5
# Patient-LVL; Number of samples registered in class 2: 8
# Slide-LVL; Number of samples registered in class 2: 8
#
# number of training samples: 12
# number of samples in cls 0: 5
# number of samples in cls 1: 3
# number of samples in cls 2: 4
#
# number of val samples: 5
# number of samples in cls 0: 2
# number of samples in cls 1: 1
# number of samples in cls 2: 2
#
# number of test samples: 5
# number of samples in cls 0: 2
# number of samples in cls 1: 1
# number of samples in cls 2: 2

# %%
# !rm -rf results

# %%
# !MPLBACKEND=Agg CUDA_VISIBLE_DEVICES=0 conda run -n clam_latest python MLIAProject/CLAM/main.py --max_epoch 300 --drop_out 0.25 --lr 1e-4 --k 1 --exp_code MLIA_CLAM_50 --weighted_sample --bag_loss focal --inst_loss svm --task MLIA_Project --model_type clam_sb --log_data --subtyping --data_root_dir /content/results_features --embed_dim 1024
# Out:
# Load Dataset
# label column: label
# label dictionary: {'B': 0, 'S': 1, 'E': 2}
# number of classes: 3
# slide-level counts:
#  label
# 0    9
# 1    5
# 2    8
# Name: count, dtype: int64
# Patient-LVL; Number of samples registered in class 0: 9
# Slide-LVL; Number of samples registered in class 0: 9
# Patient-LVL; Number of samples registered in class 1: 5
# Slide-LVL; Number of samples registered in class 1: 5
# Patient-LVL; Number of samples registered in class 2: 8
# Slide-LVL; Number of samples registered in class 2: 8
# split_dir:  splits/MLIA_Project_100
# ################# Settings ###################
# num_splits:  1
# k_start:  -1
# k_end:  -1
# task:  MLIA_Project
# max_epochs:  300
# results_dir:  ./results
# lr:  0.0001
# experiment:  MLIA_CLAM_50
# reg:  1e-05
# label_frac:  1.0
# bag_loss:  focal
# seed:  1
# model_type:  clam_sb
# model_size:  small
# use_drop_out:  0.25
# weighted_sample:  True
# opt:  adam
# bag_weight:  0.7
# inst_loss:  svm
# B:  8
# split_dir:  splits/MLIA_Project_100
#
# Training Fold 0!
#
# Init train/val/test splits...
# Done!
# Training on 12 samples
# Validating on 5 samples
# Testing on 5 samples
#
# Init loss function... Done!
#
# Init Model... Setting tau to 1.0
# Done!
# CLAM_SB(
#   (attention_net): Sequential(
#     (0): Linear(in_features=1024, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Attn_Net_Gated(
#       (attention_a): Sequential(
#         (0): Linear(in_features=512, out_features=256, bias=True)
#         (1): Tanh()
#         (2): Dropout(p=0.25, inplace=False)
#       )
#       (attention_b): Sequential(
#         (0): Linear(in_features=512, out_features=256, bias=True)
#         (1): Sigmoid()
#         (2): Dropout(p=0.25, inplace=False)
#       )
#       (attention_c): Linear(in_features=256, out_features=1, bias=True)
#     )
#   )
#   (classifiers): Linear(in_features=512, out_features=3, bias=True)
#   (instance_classifiers): ModuleList(
#     (0-2): 3 x Linear(in_features=512, out_features=2, bias=True)
#   )
#   (instance_loss_fn): SmoothTop1SVM()
# )
# Total number of parameters: 792330
# Total number of trainable parameters: 792330
#
# Init optimizer ... Done!
#
# Init Loaders... Done!
#
# Setup EarlyStopping... Done!
#
#
#
#
# class 0 clustering acc 0.7986111111111112: correct 230/288
# class 1 clustering acc 0.20833333333333334: correct 20/96
# Epoch: 0, train_loss: 0.9889, train_clustering_loss:  1.2980, train_error: 0.6667
# class 0: acc 1.0, correct 4/4
# class 1: acc 0.0, correct 0/6
# class 2: acc 0.0, correct 0/2
#
# Val Set, val_loss: 0.9702, val_error: 0.6000, auc: 0.8611
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 1.0, correct 2/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.0, correct 0/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 1, train_loss: 0.9766, train_clustering_loss:  1.2607, train_error: 0.6667
# class 0: acc 1.0, correct 4/4
# class 1: acc 0.0, correct 0/4
# class 2: acc 0.0, correct 0/4
#
# Val Set, val_loss: 0.9737, val_error: 0.6000, auc: 0.7500
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 1.0, correct 2/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.0, correct 0/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 2, train_loss: 0.9848, train_clustering_loss:  1.2245, train_error: 0.7500
# class 0: acc 1.0, correct 3/3
# class 1: acc 0.0, correct 0/4
# class 2: acc 0.0, correct 0/5
#
# Val Set, val_loss: 0.9739, val_error: 0.6000, auc: 0.6944
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 1.0, correct 2/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.0, correct 0/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 3, train_loss: 0.9664, train_clustering_loss:  1.1777, train_error: 0.5000
# class 0: acc 1.0, correct 6/6
# class 1: acc 0.0, correct 0/2
# class 2: acc 0.0, correct 0/4
#
# Val Set, val_loss: 0.9679, val_error: 0.6000, auc: 0.4722
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 1.0, correct 2/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.0, correct 0/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 4, train_loss: 0.9579, train_clustering_loss:  1.1314, train_error: 0.5833
# class 0: acc 1.0, correct 5/5
# class 1: acc 0.0, correct 0/6
# class 2: acc 0.0, correct 0/1
#
# Val Set, val_loss: 0.9718, val_error: 0.6000, auc: 0.6944
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 1.0, correct 2/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.0, correct 0/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 5, train_loss: 0.9622, train_clustering_loss:  1.0752, train_error: 0.5833
# class 0: acc 1.0, correct 5/5
# class 1: acc 0.0, correct 0/4
# class 2: acc 0.0, correct 0/3
#
# Val Set, val_loss: 0.9792, val_error: 0.6000, auc: 0.7778
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 1.0, correct 2/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.0, correct 0/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 6, train_loss: 0.9587, train_clustering_loss:  1.0285, train_error: 0.7500
# class 0: acc 1.0, correct 3/3
# class 1: acc 0.0, correct 0/7
# class 2: acc 0.0, correct 0/2
#
# Val Set, val_loss: 0.9853, val_error: 0.6000, auc: 0.7778
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 1.0, correct 2/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.0, correct 0/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 7, train_loss: 0.9594, train_clustering_loss:  0.9665, train_error: 0.7500
# class 0: acc 0.25, correct 1/4
# class 1: acc 0.4, correct 2/5
# class 2: acc 0.0, correct 0/3
#
# Val Set, val_loss: 0.9990, val_error: 0.8000, auc: 0.7778
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.0, correct 0/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 8, train_loss: 0.9585, train_clustering_loss:  0.9238, train_error: 0.5833
# class 0: acc 0.0, correct 0/4
# class 1: acc 1.0, correct 5/5
# class 2: acc 0.0, correct 0/3
#
# Val Set, val_loss: 1.0105, val_error: 0.8000, auc: 0.7778
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.0, correct 0/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 9, train_loss: 1.0792, train_clustering_loss:  0.8972, train_error: 0.8333
# class 0: acc 0.0, correct 0/2
# class 1: acc 1.0, correct 2/2
# class 2: acc 0.0, correct 0/8
#
# Val Set, val_loss: 0.9950, val_error: 0.8000, auc: 0.8333
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.0, correct 0/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 10, train_loss: 0.9482, train_clustering_loss:  0.8658, train_error: 0.4167
# class 0: acc 0.0, correct 0/1
# class 1: acc 1.0, correct 7/7
# class 2: acc 0.0, correct 0/4
#
# Val Set, val_loss: 0.9905, val_error: 0.8000, auc: 0.7778
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.0, correct 0/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 11, train_loss: 0.9998, train_clustering_loss:  0.8317, train_error: 0.7500
# class 0: acc 0.0, correct 0/5
# class 1: acc 1.0, correct 3/3
# class 2: acc 0.0, correct 0/4
#
# Val Set, val_loss: 0.9973, val_error: 0.8000, auc: 0.7222
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.0, correct 0/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 12, train_loss: 0.9865, train_clustering_loss:  0.8118, train_error: 0.6667
# class 0: acc 0.0, correct 0/5
# class 1: acc 1.0, correct 4/4
# class 2: acc 0.0, correct 0/3
#
# Val Set, val_loss: 0.9819, val_error: 0.8000, auc: 0.7222
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.0, correct 0/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 13, train_loss: 0.9417, train_clustering_loss:  0.7994, train_error: 0.4167
# class 0: acc 0.0, correct 0/2
# class 1: acc 1.0, correct 7/7
# class 2: acc 0.0, correct 0/3
#
# Val Set, val_loss: 1.0004, val_error: 0.8000, auc: 0.7222
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.0, correct 0/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 14, train_loss: 0.9861, train_clustering_loss:  0.7918, train_error: 0.7500
# class 0: acc 0.0, correct 0/3
# class 1: acc 1.0, correct 3/3
# class 2: acc 0.0, correct 0/6
#
# Val Set, val_loss: 1.0024, val_error: 0.8000, auc: 0.7222
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.0, correct 0/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 15, train_loss: 0.9891, train_clustering_loss:  0.7688, train_error: 0.7500
# class 0: acc 0.0, correct 0/5
# class 1: acc 1.0, correct 3/3
# class 2: acc 0.0, correct 0/4
#
# Val Set, val_loss: 0.9922, val_error: 0.8000, auc: 0.7222
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.0, correct 0/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 16, train_loss: 0.9934, train_clustering_loss:  0.7577, train_error: 0.7500
# class 0: acc 0.0, correct 0/6
# class 1: acc 1.0, correct 3/3
# class 2: acc 0.0, correct 0/3
#
# Val Set, val_loss: 0.9730, val_error: 0.8000, auc: 0.6389
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.0, correct 0/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 17, train_loss: 0.9541, train_clustering_loss:  0.7446, train_error: 0.1667
# class 0: acc 0.6666666666666666, correct 2/3
# class 1: acc 1.0, correct 6/6
# class 2: acc 0.6666666666666666, correct 2/3
#
# Val Set, val_loss: 0.9742, val_error: 0.4000, auc: 0.6389
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 1.0, correct 2/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.0, correct 0/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 18, train_loss: 0.9442, train_clustering_loss:  0.7314, train_error: 0.4167
# class 0: acc 0.0, correct 0/3
# class 1: acc 1.0, correct 6/6
# class 2: acc 0.3333333333333333, correct 1/3
#
# Val Set, val_loss: 0.9896, val_error: 0.8000, auc: 0.6389
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.0, correct 0/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 19, train_loss: 0.9698, train_clustering_loss:  0.7348, train_error: 0.6667
# class 0: acc 0.0, correct 0/4
# class 1: acc 1.0, correct 4/4
# class 2: acc 0.0, correct 0/4
#
# Val Set, val_loss: 1.0047, val_error: 0.8000, auc: 0.6389
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.0, correct 0/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 20, train_loss: 0.9411, train_clustering_loss:  0.7330, train_error: 0.5833
# class 0: acc 0.0, correct 0/2
# class 1: acc 1.0, correct 5/5
# class 2: acc 0.0, correct 0/5
#
# Val Set, val_loss: 1.0028, val_error: 0.8000, auc: 0.6944
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.0, correct 0/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 21, train_loss: 0.9353, train_clustering_loss:  0.7237, train_error: 0.5833
# class 0: acc 0.0, correct 0/3
# class 1: acc 1.0, correct 5/5
# class 2: acc 0.0, correct 0/4
#
# Val Set, val_loss: 1.0029, val_error: 0.8000, auc: 0.7778
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.0, correct 0/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 22, train_loss: 0.9484, train_clustering_loss:  0.7296, train_error: 0.6667
# class 0: acc 0.0, correct 0/3
# class 1: acc 1.0, correct 4/4
# class 2: acc 0.0, correct 0/5
#
# Val Set, val_loss: 0.9940, val_error: 0.8000, auc: 0.6389
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.0, correct 0/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 23, train_loss: 0.9494, train_clustering_loss:  0.7388, train_error: 0.5000
# class 0: acc 0.0, correct 0/4
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.7142857142857143, correct 5/7
#
# Val Set, val_loss: 0.9813, val_error: 0.6000, auc: 0.5833
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 1.0, correct 2/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 24, train_loss: 0.9931, train_clustering_loss:  0.7380, train_error: 0.7500
# class 0: acc 0.0, correct 0/6
# class 1: acc 0.0, correct 0/3
# class 2: acc 1.0, correct 3/3
#
# Val Set, val_loss: 0.9612, val_error: 0.6000, auc: 0.5833
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 1.0, correct 2/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 25, train_loss: 0.9802, train_clustering_loss:  0.7240, train_error: 0.6667
# class 0: acc 0.0, correct 0/4
# class 1: acc 0.0, correct 0/4
# class 2: acc 1.0, correct 4/4
#
# Val Set, val_loss: 0.9467, val_error: 0.6000, auc: 0.5833
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 1.0, correct 2/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 26, train_loss: 0.9583, train_clustering_loss:  0.7082, train_error: 0.5833
# class 0: acc None, correct 0/0
# class 1: acc 0.0, correct 0/7
# class 2: acc 1.0, correct 5/5
#
# Val Set, val_loss: 0.9687, val_error: 0.6000, auc: 0.5833
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 1.0, correct 2/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 27, train_loss: 0.9300, train_clustering_loss:  0.7250, train_error: 0.5000
# class 0: acc 0.0, correct 0/3
# class 1: acc 0.0, correct 0/3
# class 2: acc 1.0, correct 6/6
#
# Val Set, val_loss: 0.9894, val_error: 0.6000, auc: 0.5833
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 1.0, correct 2/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 28, train_loss: 0.9422, train_clustering_loss:  0.7362, train_error: 0.5000
# class 0: acc 0.0, correct 0/5
# class 1: acc 0.0, correct 0/1
# class 2: acc 1.0, correct 6/6
#
# Val Set, val_loss: 0.9716, val_error: 0.6000, auc: 0.5278
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 1.0, correct 2/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 29, train_loss: 0.9707, train_clustering_loss:  0.7008, train_error: 0.6667
# class 0: acc 0.0, correct 0/3
# class 1: acc 0.0, correct 0/5
# class 2: acc 1.0, correct 4/4
#
# Val Set, val_loss: 0.9619, val_error: 0.6000, auc: 0.5278
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 1.0, correct 2/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 30, train_loss: 0.9366, train_clustering_loss:  0.7037, train_error: 0.6667
# class 0: acc 0.0, correct 0/3
# class 1: acc 0.0, correct 0/5
# class 2: acc 1.0, correct 4/4
#
# Val Set, val_loss: 0.9734, val_error: 0.6000, auc: 0.5833
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 1.0, correct 2/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 31, train_loss: 0.9428, train_clustering_loss:  0.7203, train_error: 0.6667
# class 0: acc 0.0, correct 0/5
# class 1: acc 0.0, correct 0/3
# class 2: acc 1.0, correct 4/4
#
# Val Set, val_loss: 0.9710, val_error: 0.6000, auc: 0.6389
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 1.0, correct 2/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 32, train_loss: 0.8196, train_clustering_loss:  0.7012, train_error: 0.2500
# class 0: acc 0.0, correct 0/1
# class 1: acc 0.0, correct 0/2
# class 2: acc 1.0, correct 9/9
#
# Val Set, val_loss: 0.9721, val_error: 0.6000, auc: 0.5278
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 1.0, correct 2/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 33, train_loss: 0.8136, train_clustering_loss:  0.6979, train_error: 0.4167
# class 0: acc 0.0, correct 0/2
# class 1: acc 0.0, correct 0/3
# class 2: acc 1.0, correct 7/7
#
# Val Set, val_loss: 0.9799, val_error: 0.6000, auc: 0.4722
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 1.0, correct 2/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 34, train_loss: 1.0022, train_clustering_loss:  0.6918, train_error: 0.8333
# class 0: acc 0.0, correct 0/2
# class 1: acc 0.0, correct 0/8
# class 2: acc 1.0, correct 2/2
#
# Val Set, val_loss: 0.9958, val_error: 0.6000, auc: 0.4722
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 1.0, correct 2/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 35, train_loss: 1.0230, train_clustering_loss:  0.7368, train_error: 0.7500
# class 0: acc 0.0, correct 0/6
# class 1: acc 0.0, correct 0/3
# class 2: acc 1.0, correct 3/3
#
# Val Set, val_loss: 1.0030, val_error: 0.8000, auc: 0.5278
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 36, train_loss: 0.8955, train_clustering_loss:  0.7059, train_error: 0.4167
# class 0: acc 0.0, correct 0/4
# class 1: acc 0.6666666666666666, correct 2/3
# class 2: acc 1.0, correct 5/5
#
# Val Set, val_loss: 0.9825, val_error: 0.6000, auc: 0.5278
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 1.0, correct 2/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 37, train_loss: 0.8593, train_clustering_loss:  0.6879, train_error: 0.3333
# class 0: acc 0.0, correct 0/3
# class 1: acc 0.75, correct 3/4
# class 2: acc 1.0, correct 5/5
#
# Val Set, val_loss: 0.9741, val_error: 0.6000, auc: 0.5833
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 1.0, correct 2/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 38, train_loss: 0.8392, train_clustering_loss:  0.6903, train_error: 0.3333
# class 0: acc 0.0, correct 0/3
# class 1: acc 0.6666666666666666, correct 2/3
# class 2: acc 1.0, correct 6/6
#
# Val Set, val_loss: 0.9718, val_error: 0.6000, auc: 0.6389
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 1.0, correct 2/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 39, train_loss: 0.9236, train_clustering_loss:  0.7174, train_error: 0.5833
# class 0: acc 0.0, correct 0/4
# class 1: acc 0.25, correct 1/4
# class 2: acc 1.0, correct 4/4
#
# Val Set, val_loss: 0.9721, val_error: 0.6000, auc: 0.6389
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 1.0, correct 2/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 40, train_loss: 0.8694, train_clustering_loss:  0.7039, train_error: 0.5000
# class 0: acc 0.0, correct 0/5
# class 1: acc 0.6666666666666666, correct 2/3
# class 2: acc 1.0, correct 4/4
#
# Val Set, val_loss: 0.9566, val_error: 0.6000, auc: 0.6389
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 1.0, correct 2/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 41, train_loss: 0.9269, train_clustering_loss:  0.7135, train_error: 0.6667
# class 0: acc 0.0, correct 0/5
# class 1: acc 0.25, correct 1/4
# class 2: acc 1.0, correct 3/3
#
# Val Set, val_loss: 0.9406, val_error: 0.6000, auc: 0.7778
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 1.0, correct 2/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 42, train_loss: 0.8020, train_clustering_loss:  0.6875, train_error: 0.4167
# class 0: acc 0.0, correct 0/4
# class 1: acc 0.6666666666666666, correct 2/3
# class 2: acc 1.0, correct 5/5
#
# Val Set, val_loss: 0.9318, val_error: 0.6000, auc: 0.7778
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 1.0, correct 2/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 43, train_loss: 0.8177, train_clustering_loss:  0.6719, train_error: 0.4167
# class 0: acc 0.0, correct 0/3
# class 1: acc 0.6, correct 3/5
# class 2: acc 1.0, correct 4/4
#
# Val Set, val_loss: 0.9326, val_error: 0.4000, auc: 0.7778
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 1.0, correct 2/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 44, train_loss: 0.7771, train_clustering_loss:  0.6633, train_error: 0.3333
# class 0: acc 0.0, correct 0/2
# class 1: acc 0.6, correct 3/5
# class 2: acc 1.0, correct 5/5
#
# Val Set, val_loss: 0.9353, val_error: 0.8000, auc: 0.7778
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.0, correct 0/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 45, train_loss: 0.7585, train_clustering_loss:  0.6740, train_error: 0.3333
# class 0: acc 0.0, correct 0/3
# class 1: acc 0.6666666666666666, correct 2/3
# class 2: acc 1.0, correct 6/6
#
# Val Set, val_loss: 0.9292, val_error: 0.4000, auc: 0.7778
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 1.0, correct 2/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 46, train_loss: 0.5893, train_clustering_loss:  0.5915, train_error: 0.2500
# class 0: acc 0.0, correct 0/2
# class 1: acc 0.875, correct 7/8
# class 2: acc 1.0, correct 2/2
#
# Val Set, val_loss: 0.9212, val_error: 0.4000, auc: 0.7778
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 1.0, correct 2/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 47, train_loss: 0.7689, train_clustering_loss:  0.6729, train_error: 0.5000
# class 0: acc 0.0, correct 0/5
# class 1: acc 0.75, correct 3/4
# class 2: acc 1.0, correct 3/3
#
# Val Set, val_loss: 0.9177, val_error: 0.8000, auc: 0.7778
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.0, correct 0/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 48, train_loss: 0.7422, train_clustering_loss:  0.7003, train_error: 0.3333
# class 0: acc 0.3333333333333333, correct 2/6
# class 1: acc 1.0, correct 2/2
# class 2: acc 1.0, correct 4/4
#
# Val Set, val_loss: 0.8768, val_error: 0.6000, auc: 0.7778
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.0, correct 0/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 49, train_loss: 0.7618, train_clustering_loss:  0.6783, train_error: 0.2500
# class 0: acc 0.8, correct 4/5
# class 1: acc 0.5, correct 2/4
# class 2: acc 1.0, correct 3/3
#
# Val Set, val_loss: 0.8594, val_error: 0.6000, auc: 0.7778
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.0, correct 0/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 50, train_loss: 0.5479, train_clustering_loss:  0.5977, train_error: 0.0833
# class 0: acc 1.0, correct 2/2
# class 1: acc 1.0, correct 5/5
# class 2: acc 0.8, correct 4/5
#
# Val Set, val_loss: 0.8386, val_error: 0.6000, auc: 0.7778
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.0, correct 0/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 51, train_loss: 0.8247, train_clustering_loss:  0.6824, train_error: 0.3333
# class 0: acc 0.75, correct 3/4
# class 1: acc 0.25, correct 1/4
# class 2: acc 1.0, correct 4/4
#
# Val Set, val_loss: 0.8283, val_error: 0.4000, auc: 0.7778
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 1.0, correct 2/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 52, train_loss: 0.7376, train_clustering_loss:  0.6239, train_error: 0.5000
# class 0: acc 0.0, correct 0/3
# class 1: acc 0.5, correct 3/6
# class 2: acc 1.0, correct 3/3
#
# Val Set, val_loss: 0.8378, val_error: 0.8000, auc: 0.7778
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.0, correct 0/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 53, train_loss: 0.7654, train_clustering_loss:  0.7078, train_error: 0.1667
# class 0: acc 1.0, correct 7/7
# class 1: acc 0.5, correct 1/2
# class 2: acc 0.6666666666666666, correct 2/3
#
# Val Set, val_loss: 0.8206, val_error: 0.6000, auc: 0.7778
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.0, correct 0/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 54, train_loss: 0.5930, train_clustering_loss:  0.5990, train_error: 0.3333
# class 0: acc 1.0, correct 3/3
# class 1: acc 0.8, correct 4/5
# class 2: acc 0.25, correct 1/4
#
# Val Set, val_loss: 0.7907, val_error: 0.6000, auc: 0.7778
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.0, correct 0/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 55, train_loss: 0.5978, train_clustering_loss:  0.6335, train_error: 0.0833
# class 0: acc 1.0, correct 5/5
# class 1: acc 0.75, correct 3/4
# class 2: acc 1.0, correct 3/3
#
# Val Set, val_loss: 0.7664, val_error: 0.6000, auc: 0.7778
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.0, correct 0/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 56, train_loss: 0.7174, train_clustering_loss:  0.6625, train_error: 0.4167
# class 0: acc 1.0, correct 5/5
# class 1: acc 0.25, correct 1/4
# class 2: acc 0.3333333333333333, correct 1/3
#
# Val Set, val_loss: 0.7593, val_error: 0.4000, auc: 0.7778
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 1.0, correct 2/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.0, correct 0/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.010416666666666666: correct 1/96
# Epoch: 57, train_loss: 0.4678, train_clustering_loss:  0.5837, train_error: 0.0000
# class 0: acc 1.0, correct 6/6
# class 1: acc 1.0, correct 5/5
# class 2: acc 1.0, correct 1/1
#
# Val Set, val_loss: 0.8021, val_error: 0.4000, auc: 0.7778
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 1.0, correct 2/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.0, correct 0/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.08333333333333333: correct 8/96
# Epoch: 58, train_loss: 0.5183, train_clustering_loss:  0.5872, train_error: 0.3333
# class 0: acc 1.0, correct 4/4
# class 1: acc 1.0, correct 4/4
# class 2: acc 0.0, correct 0/4
#
# Val Set, val_loss: 0.7683, val_error: 0.4000, auc: 0.7778
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 1.0, correct 2/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.0, correct 0/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.11458333333333333: correct 11/96
# Epoch: 59, train_loss: 0.4590, train_clustering_loss:  0.6018, train_error: 0.1667
# class 0: acc 0.8571428571428571, correct 6/7
# class 1: acc 1.0, correct 4/4
# class 2: acc 0.0, correct 0/1
#
# Val Set, val_loss: 0.7216, val_error: 0.4000, auc: 0.7778
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 1.0, correct 2/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.0, correct 0/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.15625: correct 15/96
# Epoch: 60, train_loss: 0.4346, train_clustering_loss:  0.5802, train_error: 0.2500
# class 0: acc 1.0, correct 5/5
# class 1: acc 1.0, correct 4/4
# class 2: acc 0.0, correct 0/3
#
# Val Set, val_loss: 0.7433, val_error: 0.4000, auc: 0.7778
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 1.0, correct 2/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.0, correct 0/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.14583333333333334: correct 14/96
# Epoch: 61, train_loss: 0.5439, train_clustering_loss:  0.5985, train_error: 0.3333
# class 0: acc 1.0, correct 5/5
# class 1: acc 0.6, correct 3/5
# class 2: acc 0.0, correct 0/2
#
# Val Set, val_loss: 0.7030, val_error: 0.4000, auc: 0.7222
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 1.0, correct 2/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.0, correct 0/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.07291666666666667: correct 7/96
# Epoch: 62, train_loss: 0.6220, train_clustering_loss:  0.6533, train_error: 0.3333
# class 0: acc 1.0, correct 5/5
# class 1: acc 0.75, correct 3/4
# class 2: acc 0.0, correct 0/3
#
# Val Set, val_loss: 0.6930, val_error: 0.4000, auc: 0.7778
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 1.0, correct 2/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.0, correct 0/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.23958333333333334: correct 23/96
# Epoch: 63, train_loss: 0.4421, train_clustering_loss:  0.5866, train_error: 0.1667
# class 0: acc 1.0, correct 6/6
# class 1: acc 1.0, correct 4/4
# class 2: acc 0.0, correct 0/2
#
# Val Set, val_loss: 0.6852, val_error: 0.4000, auc: 0.7778
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 1.0, correct 2/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.0, correct 0/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 64, train_loss: 0.7217, train_clustering_loss:  0.7140, train_error: 0.5833
# class 0: acc 1.0, correct 3/3
# class 1: acc 1.0, correct 2/2
# class 2: acc 0.0, correct 0/7
#
# Val Set, val_loss: 0.6440, val_error: 0.4000, auc: 0.7222
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 1.0, correct 2/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.0, correct 0/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.25: correct 24/96
# Epoch: 65, train_loss: 0.4681, train_clustering_loss:  0.6028, train_error: 0.0833
# class 0: acc 1.0, correct 4/4
# class 1: acc 1.0, correct 4/4
# class 2: acc 0.75, correct 3/4
#
# Val Set, val_loss: 0.6239, val_error: 0.4000, auc: 0.8889
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.0: correct 0/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.5, correct 1/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.3229166666666667: correct 31/96
# Epoch: 66, train_loss: 0.4235, train_clustering_loss:  0.5374, train_error: 0.0833
# class 0: acc 0.0, correct 0/1
# class 1: acc 1.0, correct 7/7
# class 2: acc 1.0, correct 4/4
#
# Val Set, val_loss: 0.6173, val_error: 0.2000, auc: 0.8333
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.025: correct 1/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 1.0, correct 2/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.3333333333333333: correct 32/96
# Epoch: 67, train_loss: 0.4447, train_clustering_loss:  0.5612, train_error: 0.1667
# class 0: acc 0.3333333333333333, correct 1/3
# class 1: acc 1.0, correct 5/5
# class 2: acc 1.0, correct 4/4
#
# Val Set, val_loss: 0.6182, val_error: 0.4000, auc: 0.8333
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.1: correct 4/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 1.0, correct 2/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.25: correct 24/96
# Epoch: 68, train_loss: 0.4790, train_clustering_loss:  0.6098, train_error: 0.3333
# class 0: acc 0.0, correct 0/4
# class 1: acc 1.0, correct 5/5
# class 2: acc 1.0, correct 3/3
#
# Val Set, val_loss: 0.6087, val_error: 0.4000, auc: 0.8333
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.075: correct 3/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 1.0, correct 2/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.0: correct 0/96
# Epoch: 69, train_loss: 0.5575, train_clustering_loss:  0.6867, train_error: 0.1667
# class 0: acc 0.6666666666666666, correct 4/6
# class 1: acc 1.0, correct 2/2
# class 2: acc 1.0, correct 4/4
#
# Val Set, val_loss: 0.6035, val_error: 0.4000, auc: 0.8333
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.075: correct 3/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.5, correct 1/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.25: correct 24/96
# Epoch: 70, train_loss: 0.4451, train_clustering_loss:  0.5504, train_error: 0.1667
# class 0: acc 0.0, correct 0/2
# class 1: acc 1.0, correct 3/3
# class 2: acc 1.0, correct 7/7
#
# Val Set, val_loss: 0.5950, val_error: 0.2000, auc: 0.8333
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.05: correct 2/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 1.0, correct 2/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.25: correct 24/96
# Epoch: 71, train_loss: 0.4121, train_clustering_loss:  0.5377, train_error: 0.1667
# class 0: acc 0.0, correct 0/2
# class 1: acc 1.0, correct 4/4
# class 2: acc 1.0, correct 6/6
#
# Val Set, val_loss: 0.5940, val_error: 0.4000, auc: 0.8333
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.05: correct 2/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 1.0, correct 2/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.16666666666666666: correct 16/96
# Epoch: 72, train_loss: 0.4690, train_clustering_loss:  0.5743, train_error: 0.2500
# class 0: acc 0.4, correct 2/5
# class 1: acc 1.0, correct 4/4
# class 2: acc 1.0, correct 3/3
#
# Val Set, val_loss: 0.5960, val_error: 0.4000, auc: 0.8333
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.15: correct 6/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.5, correct 1/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.4166666666666667: correct 40/96
# Epoch: 73, train_loss: 0.3308, train_clustering_loss:  0.4407, train_error: 0.0833
# class 0: acc 0.0, correct 0/1
# class 1: acc 1.0, correct 7/7
# class 2: acc 1.0, correct 4/4
#
# Val Set, val_loss: 0.5967, val_error: 0.2000, auc: 0.8333
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.2: correct 8/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 1.0, correct 2/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.25: correct 24/96
# Epoch: 74, train_loss: 0.3468, train_clustering_loss:  0.4974, train_error: 0.0000
# class 0: acc 1.0, correct 2/2
# class 1: acc 1.0, correct 4/4
# class 2: acc 1.0, correct 6/6
#
# Val Set, val_loss: 0.6507, val_error: 0.4000, auc: 0.8889
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.2: correct 8/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 1.0, correct 2/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.4166666666666667: correct 40/96
# Epoch: 75, train_loss: 0.4210, train_clustering_loss:  0.5442, train_error: 0.4167
# class 0: acc 0.0, correct 0/5
# class 1: acc 1.0, correct 6/6
# class 2: acc 1.0, correct 1/1
#
# Val Set, val_loss: 0.6268, val_error: 0.4000, auc: 0.8889
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.2: correct 8/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 1.0, correct 2/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.4166666666666667: correct 40/96
# Epoch: 76, train_loss: 0.3245, train_clustering_loss:  0.4645, train_error: 0.0000
# class 0: acc 1.0, correct 4/4
# class 1: acc 1.0, correct 7/7
# class 2: acc 1.0, correct 1/1
#
# Val Set, val_loss: 0.5866, val_error: 0.4000, auc: 0.8333
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.2: correct 8/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.5, correct 1/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.4166666666666667: correct 40/96
# Epoch: 77, train_loss: 0.2934, train_clustering_loss:  0.4796, train_error: 0.0000
# class 0: acc 1.0, correct 4/4
# class 1: acc 1.0, correct 6/6
# class 2: acc 1.0, correct 2/2
#
# Val Set, val_loss: 0.6265, val_error: 0.2000, auc: 0.8889
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.2: correct 8/40
# class 0: acc 1.0, correct 2/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.5, correct 1/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.16666666666666666: correct 16/96
# Epoch: 78, train_loss: 0.4454, train_clustering_loss:  0.5603, train_error: 0.1667
# class 0: acc 1.0, correct 4/4
# class 1: acc 1.0, correct 3/3
# class 2: acc 0.6, correct 3/5
#
# Val Set, val_loss: 0.6362, val_error: 0.4000, auc: 0.8889
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.2: correct 8/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.5, correct 1/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.16666666666666666: correct 16/96
# Epoch: 79, train_loss: 0.3469, train_clustering_loss:  0.5081, train_error: 0.0000
# class 0: acc 1.0, correct 4/4
# class 1: acc 1.0, correct 5/5
# class 2: acc 1.0, correct 3/3
#
# Val Set, val_loss: 0.6043, val_error: 0.4000, auc: 0.8889
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.2: correct 8/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.5, correct 1/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.08333333333333333: correct 8/96
# Epoch: 80, train_loss: 0.4369, train_clustering_loss:  0.5705, train_error: 0.0833
# class 0: acc 1.0, correct 3/3
# class 1: acc 1.0, correct 2/2
# class 2: acc 0.8571428571428571, correct 6/7
#
# Val Set, val_loss: 0.5851, val_error: 0.4000, auc: 0.8889
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.2: correct 8/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.5, correct 1/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.08333333333333333: correct 8/96
# Epoch: 81, train_loss: 0.3438, train_clustering_loss:  0.4813, train_error: 0.0833
# class 0: acc 0.0, correct 0/1
# class 1: acc 1.0, correct 4/4
# class 2: acc 1.0, correct 7/7
#
# Val Set, val_loss: 0.5816, val_error: 0.4000, auc: 0.8889
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.2: correct 8/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 1.0, correct 2/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.08333333333333333: correct 8/96
# Epoch: 82, train_loss: 0.5179, train_clustering_loss:  0.6445, train_error: 0.4167
# class 0: acc 0.2857142857142857, correct 2/7
# class 1: acc 1.0, correct 2/2
# class 2: acc 1.0, correct 3/3
#
# Val Set, val_loss: 0.5673, val_error: 0.4000, auc: 0.8889
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.2: correct 8/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 1.0, correct 2/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.6666666666666666: correct 64/96
# Epoch: 83, train_loss: 0.1600, train_clustering_loss:  0.2874, train_error: 0.0833
# class 0: acc 0.5, correct 1/2
# class 1: acc 1.0, correct 9/9
# class 2: acc 1.0, correct 1/1
#
# Val Set, val_loss: 0.5823, val_error: 0.4000, auc: 0.8889
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.2: correct 8/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.5, correct 1/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.4166666666666667: correct 40/96
# Epoch: 84, train_loss: 0.2758, train_clustering_loss:  0.3913, train_error: 0.1667
# class 0: acc 1.0, correct 3/3
# class 1: acc 1.0, correct 6/6
# class 2: acc 0.3333333333333333, correct 1/3
#
# Val Set, val_loss: 0.5685, val_error: 0.4000, auc: 0.8889
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.2: correct 8/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.5, correct 1/2
#
#
#
#
# class 0 clustering acc 0.9895833333333334: correct 285/288
# class 1 clustering acc 0.09375: correct 9/96
# Epoch: 85, train_loss: 0.4370, train_clustering_loss:  0.5516, train_error: 0.0833
# class 0: acc 1.0, correct 3/3
# class 1: acc 1.0, correct 3/3
# class 2: acc 0.8333333333333334, correct 5/6
#
# Val Set, val_loss: 0.5889, val_error: 0.4000, auc: 0.8889
# class 0 clustering acc 0.9916666666666667: correct 119/120
# class 1 clustering acc 0.2: correct 8/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 0.5, correct 1/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.08333333333333333: correct 8/96
# Epoch: 86, train_loss: 0.3668, train_clustering_loss:  0.5468, train_error: 0.0000
# class 0: acc 1.0, correct 5/5
# class 1: acc 1.0, correct 1/1
# class 2: acc 1.0, correct 6/6
#
# Val Set, val_loss: 0.8864, val_error: 0.4000, auc: 0.8333
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.2: correct 8/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 1.0, correct 2/2
#
#
#
#
# class 0 clustering acc 0.9965277777777778: correct 287/288
# class 1 clustering acc 0.25: correct 24/96
# Epoch: 87, train_loss: 0.3626, train_clustering_loss:  0.5040, train_error: 0.0833
# class 0: acc 0.8, correct 4/5
# class 1: acc 1.0, correct 4/4
# class 2: acc 1.0, correct 3/3
#
# Val Set, val_loss: 0.9188, val_error: 0.6000, auc: 0.8333
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.2: correct 8/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
#
#
# class 0 clustering acc 1.0: correct 288/288
# class 1 clustering acc 0.2604166666666667: correct 25/96
# Epoch: 88, train_loss: 0.3332, train_clustering_loss:  0.4242, train_error: 0.2500
# class 0: acc 1.0, correct 2/2
# class 1: acc 1.0, correct 5/5
# class 2: acc 0.4, correct 2/5
#
# Val Set, val_loss: 0.8130, val_error: 0.6000, auc: 0.8333
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.2: correct 8/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
#
#
# class 0 clustering acc 0.9965277777777778: correct 287/288
# class 1 clustering acc 0.25: correct 24/96
# Epoch: 89, train_loss: 0.3323, train_clustering_loss:  0.4786, train_error: 0.0833
# class 0: acc 0.75, correct 3/4
# class 1: acc 1.0, correct 4/4
# class 2: acc 1.0, correct 4/4
#
# Val Set, val_loss: 0.6063, val_error: 0.2000, auc: 0.8889
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.2: correct 8/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 1.0, correct 1/1
# class 2: acc 1.0, correct 2/2
#
#
#
#
# class 0 clustering acc 0.9756944444444444: correct 281/288
# class 1 clustering acc 0.2604166666666667: correct 25/96
# Epoch: 90, train_loss: 0.3108, train_clustering_loss:  0.5097, train_error: 0.0000
# class 0: acc 1.0, correct 5/5
# class 1: acc 1.0, correct 4/4
# class 2: acc 1.0, correct 3/3
#
# Val Set, val_loss: 0.5708, val_error: 0.4000, auc: 0.8889
# class 0 clustering acc 1.0: correct 120/120
# class 1 clustering acc 0.2: correct 8/40
# ...
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(

# %%
# !zip -r result_classifier.zip 'results/'
# Out:
#   adding: results/ (stored 0%)
#   adding: results/MLIA_CLAM_50_s1/ (stored 0%)
#   adding: results/MLIA_CLAM_50_s1/s_0_checkpoint.pt (deflated 7%)
#   adding: results/MLIA_CLAM_50_s1/splits_0.csv (deflated 44%)
#   adding: results/MLIA_CLAM_50_s1/experiment_MLIA_CLAM_50.txt (deflated 39%)
#   adding: results/MLIA_CLAM_50_s1/summary.csv (deflated 46%)
#   adding: results/MLIA_CLAM_50_s1/0/ (stored 0%)
#   adding: results/MLIA_CLAM_50_s1/0/events.out.tfevents.1749892465.0cacbe0e9ca4 (deflated 75%)
#   adding: results/MLIA_CLAM_50_s1/split_0_results.pkl (deflated 55%)

# %%
# !MPLBACKEND=Agg CUDA_VISIBLE_DEVICES=0 conda run -n clam_latest python MLIAProject/CLAM/eval.py --k 1 --models_exp_code MLIA_CLAM_50_s1 --save_exp_code MLIA_CLAM_eval --task MLIA_Project --model_type clam_sb --results_dir results --data_root_dir  /content/results_features --embed_dim 1024
# Out:
# Models directory: results/MLIA_CLAM_50_s1
# {'task': 'MLIA_Project', 'split': 'test', 'save_dir': './eval_results/EVAL_MLIA_CLAM_eval', 'models_dir': 'results/MLIA_CLAM_50_s1', 'model_type': 'clam_sb', 'drop_out': 0.25, 'model_size': 'small'}
# label column: label
# label dictionary: {'B': 0, 'S': 1, 'E': 2}
# number of classes: 3
# slide-level counts:
#  label
# 0    9
# 1    5
# 2    8
# Name: count, dtype: int64
# Patient-LVL; Number of samples registered in class 0: 9
# Slide-LVL; Number of samples registered in class 0: 9
# Patient-LVL; Number of samples registered in class 1: 5
# Slide-LVL; Number of samples registered in class 1: 5
# Patient-LVL; Number of samples registered in class 2: 8
# Slide-LVL; Number of samples registered in class 2: 8
# Init Model
# CLAM_SB(
#   (attention_net): Sequential(
#     (0): Linear(in_features=1024, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Attn_Net_Gated(
#       (attention_a): Sequential(
#         (0): Linear(in_features=512, out_features=256, bias=True)
#         (1): Tanh()
#         (2): Dropout(p=0.25, inplace=False)
#       )
#       (attention_b): Sequential(
#         (0): Linear(in_features=512, out_features=256, bias=True)
#         (1): Sigmoid()
#         (2): Dropout(p=0.25, inplace=False)
#       )
#       (attention_c): Linear(in_features=256, out_features=1, bias=True)
#     )
#   )
#   (classifiers): Linear(in_features=512, out_features=3, bias=True)
#   (instance_classifiers): ModuleList(
#     (0-2): 3 x Linear(in_features=512, out_features=2, bias=True)
#   )
#   (instance_loss_fn): CrossEntropyLoss()
# )
# Total number of parameters: 792330
# Total number of trainable parameters: 792330
# Init Loaders
# test_error:  0.6
# auc:  0.8333333333333334

# %%
# !zip -r result_evaluation.zip 'eval_results/'
# Out:
#   adding: eval_results/ (stored 0%)
#   adding: eval_results/EVAL_MLIA_CLAM_eval/ (stored 0%)
#   adding: eval_results/EVAL_MLIA_CLAM_eval/fold_0.csv (deflated 46%)
#   adding: eval_results/EVAL_MLIA_CLAM_eval/summary.csv (deflated 35%)
#   adding: eval_results/EVAL_MLIA_CLAM_eval/eval_experiment_MLIA_CLAM_eval.txt (deflated 31%)
