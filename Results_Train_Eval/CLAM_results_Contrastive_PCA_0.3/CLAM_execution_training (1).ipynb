# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from oauth2client.client import GoogleCredentials
import os
import matplotlib.pyplot as plt
import torch
# Out:
# WARNING:root:pydrive is deprecated and no longer maintained. We recommend that you migrate your projects to pydrive2, the maintained fork of pydrive

# %%
# !git clone https://github.com/LucaIanniello/MLIAProject.git
# Out:
# Cloning into 'MLIAProject'...
# remote: Enumerating objects: 380, done.
# remote: Counting objects: 100% (43/43), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 380 (delta 18), reused 34 (delta 13), pack-reused 337 (from 1)
# Receiving objects: 100% (380/380), 92.22 MiB | 20.53 MiB/s, done.
# Resolving deltas: 100% (162/162), done.

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()

# !conda env create -f MLIAProject/CLAM/env.yml
# !conda install -n clam_latest -c conda-forge openslide
# !conda install -n clam_latest -c conda-forge openslide-tools libopenslide0 libtiff-dev libjpeg-dev
# !conda install -n clam_latest -c conda-forge future
# !conda run -n clam_latest python --version
# !conda run -n clam_latest pip list

# !apt-get update
# !apt-get install -y openslide-tools libopenslide0 libtiff-dev libjpeg-dev
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:08
# 🔁 Restarting kernel...
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.2
#     latest version: 25.5.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# Downloading and Extracting Packages:
# python-3.10.0        | 29.8 MB   | :   0% 0/1 [00:00<?, ?it/s]
# tk-8.6.13            | 3.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
# openssl-3.5.0        | 3.0 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# pip-25.1.1           | 1.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# libsqlite-3.50.1     | 898 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# sqlite-3.50.1        | 878 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# ncurses-6.5          | 871 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# libgcc-15.1.0        | 810 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# setuptools-80.9.0    | 731 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 655 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# libgomp-15.1.0       | 442 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# liblzma-devel-5.8.1  | 430 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# readline-8.2         | 276 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 149 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2025b         | 120 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# liblzma-5.8.1        | 110 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xz-tools-5.8.1       | 94 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libffi-3.4.6         | 56 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-ng-15.1.0     | 34 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# tk-8.6.13            | 3.1 MB    | :   2% 0.019948837271597138/1 [00:00<00:05,  5.40s/it]
#
# python-3.10.0        | 29.8 MB   | :   0% 0.0020950271396738573/1 [00:00<00:54, 54.40s/it]
#
#
# pip-25.1.1           | 1.2 MB    | :   5% 0.05272426679109731/1 [00:00<00:01,  2.11s/it]
#
#
#
# libsqlite-3.50.1     | 898 KB    | :   7% 0.07124880003565918/1 [00:00<00:01,  1.55s/it]
#
#
#
# libsqlite-3.50.1     | 898 KB    | : 100% 1.0/1 [00:00<00:00,  1.55s/it]
#
#
# python-3.10.0        | 29.8 MB   | :  11% 0.11260770875746982/1 [00:00<00:01,  1.61s/it]
#
# openssl-3.5.0        | 3.0 MB    | :  99% 0.9880612431473563/1 [00:00<00:00,  5.46it/s]
#
#
#
#
# sqlite-3.50.1        | 878 KB    | :   2% 0.0182203163644775/1 [00:00<00:11, 11.42s/it]
# tk-8.6.13            | 3.1 MB    | :  95% 0.947569770400864/1 [00:00<00:00,  5.04it/s]
#
#
#
#
#
# ncurses-6.5          | 871 KB    | :   2% 0.018375108367605347/1 [00:00<00:11, 12.03s/it]
#
#
#
#
# sqlite-3.50.1        | 878 KB    | : 100% 1.0/1 [00:00<00:00, 11.42s/it]
#
#
#
#
#
# ncurses-6.5          | 871 KB    | : 100% 1.0/1 [00:00<00:00, 12.03s/it]
# tk-8.6.13            | 3.1 MB    | : 100% 1.0/1 [00:00<00:00,  5.04it/s]
#
# python-3.10.0        | 29.8 MB   | :  22% 0.219977849665755/1 [00:00<00:00,  1.26s/it]
#
#
#
#
#
#
# libgcc-15.1.0        | 810 KB    | :   2% 0.019760996154903825/1 [00:00<00:15, 15.88s/it]
#
#
#
#
#
#
# libgcc-15.1.0        | 810 KB    | : 100% 1.0/1 [00:00<00:00, 15.88s/it]
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 655 KB    | :   2% 0.02443057699046426/1 [00:00<00:13, 14.02s/it]
#
#
#
#
#
#
#
# setuptools-80.9.0    | 731 KB    | :   2% 0.021880692532465797/1 [00:00<00:15, 15.85s/it]
#
#
#
#
#
#
#
#
#
# libgomp-15.1.0       | 442 KB    | :   4% 0.03619693572083467/1 [00:00<00:09,  9.65s/it]
#
#
#
#
#
#
#
#
#
# libgomp-15.1.0       | 442 KB    | : 100% 1.0/1 [00:00<00:00,  9.65s/it]
#
#
#
# libsqlite-3.50.1     | 898 KB    | : 100% 1.0/1 [00:00<00:00,  2.93it/s]
#
#
#
# libsqlite-3.50.1     | 898 KB    | : 100% 1.0/1 [00:00<00:00,  2.93it/s]
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 655 KB    | : 100% 1.0/1 [00:00<00:00, 14.02s/it]
#
#
#
#
#
#
#
#
#
#
# liblzma-devel-5.8.1  | 430 KB    | :   4% 0.037247537897732955/1 [00:00<00:09,  9.94s/it]
#
#
#
#
#
#
#
# setuptools-80.9.0    | 731 KB    | : 100% 1.0/1 [00:00<00:00, 15.85s/it]
#
#
#
#
#
#
#
#
#
#
# liblzma-devel-5.8.1  | 430 KB    | : 100% 1.0/1 [00:00<00:00,  9.94s/it]
#
#
#
#
#
#
#
#
#
#
#
# readline-8.2         | 276 KB    | :   6% 0.05800056641178136/1 [00:00<00:06,  6.85s/it]
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.0        | 29.8 MB   | :  39% 0.39229383190392975/1 [00:00<00:00,  1.15it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 149 KB    | :  11% 0.10758915965669182/1 [00:00<00:03,  3.85s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2025b         | 120 KB    | :  13% 0.1332379155552664/1 [00:00<00:02,  3.12s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2025b         | 120 KB    | : 100% 1.0/1 [00:00<00:00,  3.12s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 149 KB    | : 100% 1.0/1 [00:00<00:00,  3.85s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# liblzma-5.8.1        | 110 KB    | :  15% 0.1451272875440679/1 [00:00<00:02,  2.94s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# liblzma-5.8.1        | 110 KB    | : 100% 1.0/1 [00:00<00:00,  2.94s/it]
#
#
#
#
# sqlite-3.50.1        | 878 KB    | : 100% 1.0/1 [00:00<00:00,  2.65it/s]
#
#
#
#
# sqlite-3.50.1        | 878 KB    | : 100% 1.0/1 [00:00<00:00,  2.65it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xz-tools-5.8.1       | 94 KB     | :  17% 0.1699003453174743/1 [00:00<00:02,  2.57s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xz-tools-5.8.1       | 94 KB     | : 100% 1.0/1 [00:00<00:00,  2.57s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libffi-3.4.6         | 56 KB     | :  29% 0.2852715337871955/1 [00:00<00:01,  1.60s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libffi-3.4.6         | 56 KB     | : 100% 1.0/1 [00:00<00:00,  1.60s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-ng-15.1.0     | 34 KB     | :  47% 0.47371768923842017/1 [00:00<00:00,  1.00it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.0        | 29.8 MB   | :  99% 0.9930428642054083/1 [00:00<00:00,  1.80it/s]
#
#
# pip-25.1.1           | 1.2 MB    | : 100% 1.0/1 [00:00<00:00,  1.19it/s]
#
#
# python-3.10.0        | 29.8 MB   | : 100% 1.0/1 [00:01<00:00,  1.80it/s]
# tk-8.6.13            | 3.1 MB    | : 100% 1.0/1 [00:01<00:00,  5.04it/s]
#
# openssl-3.5.0        | 3.0 MB    | : 100% 1.0/1 [00:01<00:00,  5.46it/s]
#
#
#
#
#
#
# libgcc-15.1.0        | 810 KB    | : 100% 1.0/1 [00:01<00:00,  1.61s/it]
#
#
#
#
#
#
# libgcc-15.1.0        | 810 KB    | : 100% 1.0/1 [00:01<00:00,  1.61s/it]
#
#
#
#
#
#
#
#
#
# libgomp-15.1.0       | 442 KB    | : 100% 1.0/1 [00:01<00:00,  1.65s/it]
#
#
#
#
#
#
#
#
#
# libgomp-15.1.0       | 442 KB    | : 100% 1.0/1 [00:01<00:00,  1.65s/it]
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 655 KB    | : 100% 1.0/1 [00:01<00:00,  1.70s/it]
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 655 KB    | : 100% 1.0/1 [00:01<00:00,  1.70s/it]
#
#
#
#
#
#
#
# setuptools-80.9.0    | 731 KB    | : 100% 1.0/1 [00:02<00:00,  2.05s/it]
#
#
#
#
#
#
#
# setuptools-80.9.0    | 731 KB    | : 100% 1.0/1 [00:02<00:00,  2.05s/it]
#
#
#
#
#
# ncurses-6.5          | 871 KB    | : 100% 1.0/1 [00:02<00:00,  2.16s/it]
#
#
#
#
#
# ncurses-6.5          | 871 KB    | : 100% 1.0/1 [00:02<00:00,  2.16s/it]
#
#
#
#
#
#
#
#
#
#
#
# readline-8.2         | 276 KB    | : 100% 1.0/1 [00:02<00:00,  2.16s/it]
#
#
#
#
#
#
#
#
#
#
#
# readline-8.2         | 276 KB    | : 100% 1.0/1 [00:02<00:00,  2.16s/it]
#
#
#
#
#
#
#
#
#
#
# liblzma-devel-5.8.1  | 430 KB    | : 100% 1.0/1 [00:02<00:00,  2.21s/it]
#
#
#
#
#
#
#
#
#
#
# liblzma-devel-5.8.1  | 430 KB    | : 100% 1.0/1 [00:02<00:00,  2.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 149 KB    | : 100% 1.0/1 [00:02<00:00,  2.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 149 KB    | : 100% 1.0/1 [00:02<00:00,  2.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# liblzma-5.8.1        | 110 KB    | : 100% 1.0/1 [00:02<00:00,  2.30s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# liblzma-5.8.1        | 110 KB    | : 100% 1.0/1 [00:02<00:00,  2.30s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xz-tools-5.8.1       | 94 KB     | : 100% 1.0/1 [00:02<00:00,  2.35s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# xz-tools-5.8.1       | 94 KB     | : 100% 1.0/1 [00:02<00:00,  2.35s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libffi-3.4.6         | 56 KB     | : 100% 1.0/1 [00:02<00:00,  2.45s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libffi-3.4.6         | 56 KB     | : 100% 1.0/1 [00:02<00:00,  2.45s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-ng-15.1.0     | 34 KB     | : 100% 1.0/1 [00:02<00:00,  2.69s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-ng-15.1.0     | 34 KB     | : 100% 1.0/1 [00:02<00:00,  2.69s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2025b         | 120 KB    | : 100% 1.0/1 [00:02<00:00,  2.54s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.0        | 29.8 MB   | : 100% 1.0/1 [00:07<00:00,  1.80it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done
# / Ran pip subprocess with arguments:
# ['/usr/local/envs/clam_latest/bin/python', '-m', 'pip', 'install', '-U', '-r', '/content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt', '--exists-action=b']
# Pip subprocess output:
# Collecting git+https://github.com/oval-group/smooth-topk.git (from -r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 13))
#   Cloning https://github.com/oval-group/smooth-topk.git to /tmp/pip-req-build-o7o2o0vw
#   Resolved https://github.com/oval-group/smooth-topk.git to commit 12c1645f187e2fa0c05f47bf1fe48864d4bd2707
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting timm==0.9.8 (from -r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 1))
#   Downloading timm-0.9.8-py3-none-any.whl.metadata (59 kB)
# Collecting torch (from -r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 2))
#   Downloading torch-2.7.1-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Collecting torchvision (from -r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 3))
#   Downloading torchvision-0.22.1-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Collecting h5py (from -r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 4))
#   Downloading h5py-3.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Collecting pandas (from -r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 5))
#   Downloading pandas-2.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (91 kB)
# Collecting PyYAML (from -r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 6))
#   Downloading PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting opencv-python (from -r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 7))
#   Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting matplotlib (from -r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 8))
#   Downloading matplotlib-3.10.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting scikit-learn (from -r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 9))
#   Downloading scikit_learn-1.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (17 kB)
# Collecting scipy (from -r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 10))
#   Downloading scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting tqdm (from -r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 11))
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting openslide-python (from -r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 12))
#   Downloading openslide_python-1.4.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (4.9 kB)
# Collecting tensorboardX (from -r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 14))
#   Downloading tensorboardx-2.6.4-py3-none-any.whl.metadata (6.2 kB)
# Collecting numpy (from topk==1.0->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 13))
#   Downloading numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting huggingface-hub (from timm==0.9.8->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 1))
#   Downloading huggingface_hub-0.33.0-py3-none-any.whl.metadata (14 kB)
# Collecting safetensors (from timm==0.9.8->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 1))
#   Downloading safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting filelock (from torch->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 2))
#   Downloading filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting typing-extensions>=4.10.0 (from torch->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 2))
#   Downloading typing_extensions-4.14.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting sympy>=1.13.3 (from torch->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 2))
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 2))
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 2))
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec (from torch->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 2))
#   Downloading fsspec-2025.5.1-py3-none-any.whl.metadata (11 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.6.77 (from torch->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 2))
#   Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.6.77 (from torch->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 2))
#   Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.6.80 (from torch->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 2))
#   Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.5.1.17 (from torch->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 2))
#   Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.6.4.1 (from torch->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 2))
#   Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.3.0.4 (from torch->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 2))
#   Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.7.77 (from torch->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 2))
#   Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.7.1.2 (from torch->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 2))
#   Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.5.4.2 (from torch->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 2))
#   Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.3 (from torch->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 2))
#   Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.26.2 (from torch->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 2))
#   Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvtx-cu12==12.6.77 (from torch->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 2))
#   Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nvjitlink-cu12==12.6.85 (from torch->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 2))
#   Downloading nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufile-cu12==1.11.1.6 (from torch->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 2))
#   Downloading nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.3.1 (from torch->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 2))
#   Downloading triton-3.3.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/envs/clam_latest/lib/python3.10/site-packages (from triton==3.3.1->torch->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 2)) (80.9.0)
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 3))
#   Downloading pillow-11.2.1-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (8.9 kB)
# Collecting python-dateutil>=2.8.2 (from pandas->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 5))
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 5))
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 5))
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 8))
#   Downloading contourpy-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 8))
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 8))
#   Downloading fonttools-4.58.4-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (106 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 8))
#   Downloading kiwisolver-1.4.8-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.2 kB)
# Collecting packaging>=20.0 (from matplotlib->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 8))
#   Downloading packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 8))
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Collecting joblib>=1.2.0 (from scikit-learn->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 9))
#   Downloading joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 9))
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting protobuf>=3.20 (from tensorboardX->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 14))
#   Downloading protobuf-6.31.1-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->pandas->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 5))
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 2))
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting requests (from huggingface-hub->timm==0.9.8->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 1))
#   Downloading requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Collecting hf-xet<2.0.0,>=1.1.2 (from huggingface-hub->timm==0.9.8->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 1))
#   Downloading hf_xet-1.1.3-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (879 bytes)
# Collecting MarkupSafe>=2.0 (from jinja2->torch->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 2))
#   Downloading MarkupSafe-3.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting charset_normalizer<4,>=2 (from requests->huggingface-hub->timm==0.9.8->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 1))
#   Downloading charset_normalizer-3.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (35 kB)
# Collecting idna<4,>=2.5 (from requests->huggingface-hub->timm==0.9.8->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 1))
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->huggingface-hub->timm==0.9.8->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 1))
#   Downloading urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests->huggingface-hub->timm==0.9.8->-r /content/MLIAProject/CLAM/condaenv.odd8vz3p.requirements.txt (line 1))
#   Downloading certifi-2025.4.26-py3-none-any.whl.metadata (2.5 kB)
# Downloading timm-0.9.8-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 67.4 MB/s eta 0:00:00
# Downloading torch-2.7.1-cp310-cp310-manylinux_2_28_x86_64.whl (821.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 821.2/821.2 MB 26.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.6.4.1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (393.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 MB 29.1 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.6.80-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 171.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.6.77-py3-none-manylinux2014_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 210.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (897 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.7/897.7 kB 55.5 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.5.1.17-py3-none-manylinux_2_28_x86_64.whl (571.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.0/571.0 MB 29.4 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.3.0.4-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (200.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.2/200.2 MB 74.0 MB/s eta 0:00:00
# Downloading nvidia_cufile_cu12-1.11.1.6-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 28.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.7.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 62.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.7.1.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (158.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.2/158.2 MB 68.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.5.4.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (216.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 216.6/216.6 MB 73.7 MB/s eta 0:00:00
# Downloading nvidia_cusparselt_cu12-0.6.3-py3-none-manylinux2014_x86_64.whl (156.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.8/156.8 MB 72.3 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.26.2-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (201.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.3/201.3 MB 74.6 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.6.85-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (19.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 192.0 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.6.77-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Downloading triton-3.3.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 MB 66.1 MB/s eta 0:00:00
# Downloading torchvision-0.22.1-cp310-cp310-manylinux_2_28_x86_64.whl (7.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 128.5 MB/s eta 0:00:00
# Downloading h5py-3.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 101.9 MB/s eta 0:00:00
# Downloading pandas-2.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 146.8 MB/s eta 0:00:00
# Downloading PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (751 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 751.2/751.2 kB 41.1 MB/s eta 0:00:00
# Downloading opencv_python-4.11.0.86-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (63.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.0/63.0 MB 56.4 MB/s eta 0:00:00
# Downloading matplotlib-3.10.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 167.2 MB/s eta 0:00:00
# Downloading scikit_learn-1.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 177.4 MB/s eta 0:00:00
# Downloading scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.7/37.7 MB 56.3 MB/s eta 0:00:00
# Downloading numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 168.2 MB/s eta 0:00:00
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading openslide_python-1.4.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.whl (40 kB)
# Downloading tensorboardx-2.6.4-py3-none-any.whl (87 kB)
# Downloading contourpy-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (325 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.58.4-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 144.2 MB/s eta 0:00:00
# Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
# Downloading kiwisolver-1.4.8-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 79.9 MB/s eta 0:00:00
# Downloading packaging-25.0-py3-none-any.whl (66 kB)
# Downloading pillow-11.2.1-cp310-cp310-manylinux_2_28_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 139.8 MB/s eta 0:00:00
# Downloading protobuf-6.31.1-cp39-abi3-manylinux2014_x86_64.whl (321 kB)
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 155.0 MB/s eta 0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 24.3 MB/s eta 0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading typing_extensions-4.14.0-py3-none-any.whl (43 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Downloading fsspec-2025.5.1-py3-none-any.whl (199 kB)
# Downloading huggingface_hub-0.33.0-py3-none-any.whl (514 kB)
# Downloading hf_xet-1.1.3-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 138.6 MB/s eta 0:00:00
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading MarkupSafe-3.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20 kB)
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 93.4 MB/s eta 0:00:00
# Downloading requests-2.32.4-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading urllib3-2.4.0-py3-none-any.whl (128 kB)
# Downloading certifi-2025.4.26-py3-none-any.whl (159 kB)
# Downloading safetensors-0.5.3-cp38-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (471 kB)
# Building wheels for collected packages: topk
#   Building wheel for topk (setup.py): started
#   Building wheel for topk (setup.py): finished with status 'done'
#   Created wheel for topk: filename=topk-1.0-py3-none-any.whl size=10041 sha256=cdb5c767d020c5c54cc7d0df01711ffefa2c50ac7bb7e5b7453a99aff130bd7e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-rxc20r3a/wheels/b5/e1/65/94fdd820e9a24c2f8520b542ddea5a1d05e88fb34fd768d536
# Successfully built topk
# Installing collected packages: pytz, nvidia-cusparselt-cu12, mpmath, urllib3, tzdata, typing-extensions, triton, tqdm, threadpoolctl, sympy, six, safetensors, PyYAML, pyparsing, protobuf, pillow, packaging, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, MarkupSafe, kiwisolver, joblib, idna, hf-xet, fsspec, fonttools, filelock, cycler, charset_normalizer, certifi, tensorboardX, scipy, requests, python-dateutil, openslide-python, opencv-python, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, jinja2, h5py, contourpy, scikit-learn, pandas, nvidia-cusolver-cu12, matplotlib, huggingface-hub, torch, torchvision, topk, timm
#
# Successfully installed MarkupSafe-3.0.2 PyYAML-6.0.2 certifi-2025.4.26 charset_normalizer-3.4.2 contourpy-1.3.2 cycler-0.12.1 filelock-3.18.0 fonttools-4.58.4 fsspec-2025.5.1 h5py-3.14.0 hf-xet-1.1.3 huggingface-hub-0.33.0 idna-3.10 jinja2-3.1.6 joblib-1.5.1 kiwisolver-1.4.8 matplotlib-3.10.3 mpmath-1.3.0 networkx-3.4.2 numpy-2.2.6 nvidia-cublas-cu12-12.6.4.1 nvidia-cuda-cupti-cu12-12.6.80 nvidia-cuda-nvrtc-cu12-12.6.77 nvidia-cuda-runtime-cu12-12.6.77 nvidia-cudnn-cu12-9.5.1.17 nvidia-cufft-cu12-11.3.0.4 nvidia-cufile-cu12-1.11.1.6 nvidia-curand-cu12-10.3.7.77 nvidia-cusolver-cu12-11.7.1.2 nvidia-cusparse-cu12-12.5.4.2 nvidia-cusparselt-cu12-0.6.3 nvidia-nccl-cu12-2.26.2 nvidia-nvjitlink-cu12-12.6.85 nvidia-nvtx-cu12-12.6.77 opencv-python-4.11.0.86 openslide-python-1.4.2 packaging-25.0 pandas-2.3.0 pillow-11.2.1 protobuf-6.31.1 pyparsing-3.2.3 python-dateutil-2.9.0.post0 pytz-2025.2 requests-2.32.4 safetensors-0.5.3 scikit-learn-1.7.0 scipy-1.15.3 six-1.17.0 sympy-1.14.0 tensorboardX-2.6.4 threadpoolctl-3.6.0 timm-0.9.8 topk-1.0 torch-2.7.1 torchvision-0.22.1 tqdm-4.67.1 triton-3.3.1 typing-extensions-4.14.0 tzdata-2025.2 urllib3-2.4.0
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate clam_latest
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.2
#     latest version: 25.5.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/clam_latest
#
#   added / updated specs:
#     - openslide
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cairo-1.18.4               |       h3394656_0         955 KB  conda-forge
#     font-ttf-dejavu-sans-mono-2.37|       hab24e00_0         388 KB  conda-forge
#     font-ttf-inconsolata-3.000 |       h77eed37_0          94 KB  conda-forge
#     font-ttf-source-code-pro-2.038|       h77eed37_0         684 KB  conda-forge
#     font-ttf-ubuntu-0.83       |       h77eed37_3         1.5 MB  conda-forge
#     fontconfig-2.15.0          |       h7e30c49_1         259 KB  conda-forge
#     fonts-conda-ecosystem-1    |                0           4 KB  conda-forge
#     fonts-conda-forge-1        |                0           4 KB  conda-forge
#     freetype-2.13.3            |       ha770c72_1         168 KB  conda-forge
#     gdk-pixbuf-2.42.12         |       hb9ae30d_0         516 KB  conda-forge
#     icu-75.1                   |       he02047a_0        11.6 MB  conda-forge
#     lerc-4.0.0                 |       h0aef613_1         258 KB  conda-forge
#     libdeflate-1.24            |       h86f0d12_0          71 KB  conda-forge
#     libdicom-1.0.5             |       hd590300_1          99 KB  conda-forge
#     libexpat-2.7.0             |       h5888daf_0          73 KB  conda-forge
#     libfreetype-2.13.3         |       ha770c72_1           8 KB  conda-forge
#     libfreetype6-2.13.3        |       h48d6fc4_1         371 KB  conda-forge
#     libglib-2.84.2             |       h3618099_0         3.8 MB  conda-forge
#     libiconv-1.18              |       h4ce23a2_1         696 KB  conda-forge
#     libjpeg-turbo-3.1.0        |       hb9d3cd8_0         614 KB  conda-forge
#     libpng-1.6.47              |       h943b412_0         282 KB  conda-forge
#     libstdcxx-15.1.0           |       h8f9b012_2         3.7 MB  conda-forge
#     libstdcxx-ng-15.1.0        |       h4852527_2          34 KB  conda-forge
#     libtiff-4.7.0              |       hf01ce69_5         420 KB  conda-forge
#     libwebp-base-1.5.0         |       h851e524_0         420 KB  conda-forge
#     libxcb-1.17.0              |       h8a09558_0         387 KB  conda-forge
#     libxml2-2.13.8             |       h4bc477f_0         675 KB  conda-forge
#     openjpeg-2.5.3             |       h5fbd93e_0         335 KB  conda-forge
#     openslide-4.0.0            |       h58ba908_1         139 KB  conda-forge
#     pcre2-10.45                |       hc749103_0         1.1 MB  conda-forge
#     pixman-0.46.2              |       h29eaf8c_0         393 KB  conda-forge
#     pthread-stubs-0.4          |    hb9d3cd8_1002           8 KB  conda-forge
#     xorg-libice-1.1.2          |       hb9d3cd8_0          57 KB  conda-forge
#     xorg-libsm-1.2.6           |       he73a12e_0          27 KB  conda-forge
#     xorg-libx11-1.8.12         |       h4f16b4b_0         816 KB  conda-forge
#     xorg-libxau-1.0.12         |       hb9d3cd8_0          14 KB  conda-forge
#     xorg-libxdmcp-1.1.5        |       hb9d3cd8_0          19 KB  conda-forge
#     xorg-libxext-1.3.6         |       hb9d3cd8_0          49 KB  conda-forge
#     xorg-libxrender-0.9.12     |       hb9d3cd8_0          32 KB  conda-forge
#     zstd-1.5.7                 |       hb8e6e7a_2         554 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        31.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   cairo              conda-forge/linux-64::cairo-1.18.4-h3394656_0
#   font-ttf-dejavu-s~ conda-forge/noarch::font-ttf-dejavu-sans-mono-2.37-hab24e00_0
#   font-ttf-inconsol~ conda-forge/noarch::font-ttf-inconsolata-3.000-h77eed37_0
#   font-ttf-source-c~ conda-forge/noarch::font-ttf-source-code-pro-2.038-h77eed37_0
#   font-ttf-ubuntu    conda-forge/noarch::font-ttf-ubuntu-0.83-h77eed37_3
#   fontconfig         conda-forge/linux-64::fontconfig-2.15.0-h7e30c49_1
#   fonts-conda-ecosy~ conda-forge/noarch::fonts-conda-ecosystem-1-0
#   fonts-conda-forge  conda-forge/noarch::fonts-conda-forge-1-0
#   freetype           conda-forge/linux-64::freetype-2.13.3-ha770c72_1
#   gdk-pixbuf         conda-forge/linux-64::gdk-pixbuf-2.42.12-hb9ae30d_0
#   icu                conda-forge/linux-64::icu-75.1-he02047a_0
#   lerc               conda-forge/linux-64::lerc-4.0.0-h0aef613_1
#   libdeflate         conda-forge/linux-64::libdeflate-1.24-h86f0d12_0
#   libdicom           conda-forge/linux-64::libdicom-1.0.5-hd590300_1
#   libexpat           conda-forge/linux-64::libexpat-2.7.0-h5888daf_0
#   libfreetype        conda-forge/linux-64::libfreetype-2.13.3-ha770c72_1
#   libfreetype6       conda-forge/linux-64::libfreetype6-2.13.3-h48d6fc4_1
#   libglib            conda-forge/linux-64::libglib-2.84.2-h3618099_0
#   libiconv           conda-forge/linux-64::libiconv-1.18-h4ce23a2_1
#   libjpeg-turbo      conda-forge/linux-64::libjpeg-turbo-3.1.0-hb9d3cd8_0
#   libpng             conda-forge/linux-64::libpng-1.6.47-h943b412_0
#   libstdcxx          conda-forge/linux-64::libstdcxx-15.1.0-h8f9b012_2
#   libstdcxx-ng       conda-forge/linux-64::libstdcxx-ng-15.1.0-h4852527_2
#   libtiff            conda-forge/linux-64::libtiff-4.7.0-hf01ce69_5
#   libwebp-base       conda-forge/linux-64::libwebp-base-1.5.0-h851e524_0
#   libxcb             conda-forge/linux-64::libxcb-1.17.0-h8a09558_0
#   libxml2            conda-forge/linux-64::libxml2-2.13.8-h4bc477f_0
#   openjpeg           conda-forge/linux-64::openjpeg-2.5.3-h5fbd93e_0
#   openslide          conda-forge/linux-64::openslide-4.0.0-h58ba908_1
#   pcre2              conda-forge/linux-64::pcre2-10.45-hc749103_0
#   pixman             conda-forge/linux-64::pixman-0.46.2-h29eaf8c_0
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-hb9d3cd8_1002
#   xorg-libice        conda-forge/linux-64::xorg-libice-1.1.2-hb9d3cd8_0
#   xorg-libsm         conda-forge/linux-64::xorg-libsm-1.2.6-he73a12e_0
#   xorg-libx11        conda-forge/linux-64::xorg-libx11-1.8.12-h4f16b4b_0
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.12-hb9d3cd8_0
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.5-hb9d3cd8_0
#   xorg-libxext       conda-forge/linux-64::xorg-libxext-1.3.6-hb9d3cd8_0
#   xorg-libxrender    conda-forge/linux-64::xorg-libxrender-0.9.12-hb9d3cd8_0
#   zstd               conda-forge/linux-64::zstd-1.5.7-hb8e6e7a_2
#
#
#
# Downloading and Extracting Packages:
# icu-75.1             | 11.6 MB   | :   0% 0/1 [00:00<?, ?it/s]
# libglib-2.84.2       | 3.8 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
# libstdcxx-15.1.0     | 3.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# pcre2-10.45          | 1.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# cairo-1.18.4         | 955 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# xorg-libx11-1.8.12   | 816 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# libiconv-1.18        | 696 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# font-ttf-source-code | 684 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# libxml2-2.13.8       | 675 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# libjpeg-turbo-3.1.0  | 614 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# zstd-1.5.7           | 554 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# gdk-pixbuf-2.42.12   | 516 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# libwebp-base-1.5.0   | 420 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.7.0        | 420 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pixman-0.46.2        | 393 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-dejavu-sans | 388 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxcb-1.17.0        | 387 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libfreetype6-2.13.3  | 371 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# libstdcxx-15.1.0     | 3.7 MB    | :   0% 0.004198490398746398/1 [00:00<00:23, 23.83s/it]
#
#
#
# pcre2-10.45          | 1.1 MB    | :   1% 0.013684031176606187/1 [00:00<00:07,  7.53s/it]
# libglib-2.84.2       | 3.8 MB    | :   1% 0.008285070337637855/1 [00:00<00:13, 13.61s/it]
#
#
# icu-75.1             | 11.6 MB   | :   0% 0.00135078949540213/1 [00:00<01:31, 91.44s/it]
#
#
#
# pcre2-10.45          | 1.1 MB    | : 100% 1.0/1 [00:00<00:00,  7.53s/it]
#
# libstdcxx-15.1.0     | 3.7 MB    | :  65% 0.6549645022044381/1 [00:00<00:00,  3.82it/s]
#
#
# icu-75.1             | 11.6 MB   | :  15% 0.15263921298044067/1 [00:00<00:01,  1.23s/it]
#
#
#
#
# cairo-1.18.4         | 955 KB    | :   2% 0.016750603712859646/1 [00:00<00:13, 13.83s/it]
#
#
#
#
#
# xorg-libx11-1.8.12   | 816 KB    | :   2% 0.019600524467158594/1 [00:00<00:12, 12.42s/it]
#
#
#
#
# cairo-1.18.4         | 955 KB    | : 100% 1.0/1 [00:00<00:00, 13.83s/it]
#
#
#
#
#
# xorg-libx11-1.8.12   | 816 KB    | : 100% 1.0/1 [00:00<00:00, 12.42s/it]
# libglib-2.84.2       | 3.8 MB    | : 100% 1.0/1 [00:00<00:00,  3.55it/s]
# libglib-2.84.2       | 3.8 MB    | : 100% 1.0/1 [00:00<00:00,  3.55it/s]
#
# libstdcxx-15.1.0     | 3.7 MB    | : 100% 1.0/1 [00:00<00:00,  3.82it/s]
#
#
#
#
#
#
# icu-75.1             | 11.6 MB   | :  48% 0.47547790238154974/1 [00:00<00:00,  1.86it/s]
#
#
#
#
#
#
#
# font-ttf-source-code | 684 KB    | :   2% 0.02337852839697837/1 [00:00<00:13, 13.39s/it]
#
#
#
#
#
#
#
# font-ttf-source-code | 684 KB    | : 100% 1.0/1 [00:00<00:00, 13.39s/it]
#
#
#
#
#
#
# libiconv-1.18        | 696 KB    | : 100% 1.0/1 [00:00<00:00, 13.61s/it]
#
#
#
#
#
#
#
#
# libxml2-2.13.8       | 675 KB    | :   2% 0.02371523194145302/1 [00:00<00:14, 14.56s/it]
#
#
#
#
#
#
#
#
#
# libjpeg-turbo-3.1.0  | 614 KB    | :   3% 0.026049889736337085/1 [00:00<00:12, 13.29s/it]
#
#
#
#
#
#
#
#
#
# libjpeg-turbo-3.1.0  | 614 KB    | : 100% 1.0/1 [00:00<00:00, 13.29s/it]
#
#
#
#
#
#
#
#
# libxml2-2.13.8       | 675 KB    | : 100% 1.0/1 [00:00<00:00, 14.56s/it]
#
#
#
#
#
#
#
#
#
#
# zstd-1.5.7           | 554 KB    | :   3% 0.02886651702497278/1 [00:00<00:12, 13.05s/it]
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | : 100% 1.0/1 [00:00<00:00,  2.81it/s]
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | : 100% 1.0/1 [00:00<00:00,  2.81it/s]
#
#
#
#
#
#
#
#
#
#
#
# gdk-pixbuf-2.42.12   | 516 KB    | :   3% 0.031021548843224167/1 [00:00<00:12, 12.51s/it]
#
#
#
#
#
#
#
#
#
#
# zstd-1.5.7           | 554 KB    | : 100% 1.0/1 [00:00<00:00, 13.05s/it]
#
#
#
#
#
#
#
#
#
#
#
# gdk-pixbuf-2.42.12   | 516 KB    | : 100% 1.0/1 [00:00<00:00, 12.51s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# libwebp-base-1.5.0   | 420 KB    | :   4% 0.038104718203236014/1 [00:00<00:10, 10.71s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-75.1             | 11.6 MB   | :  72% 0.7172692220585309/1 [00:00<00:00,  2.07it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# libwebp-base-1.5.0   | 420 KB    | : 100% 1.0/1 [00:00<00:00, 10.71s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pixman-0.46.2        | 393 KB    | :   4% 0.040733724162278544/1 [00:00<00:10, 10.73s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.7.0        | 420 KB    | : 100% 1.0/1 [00:00<00:00, 10.70s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pixman-0.46.2        | 393 KB    | : 100% 1.0/1 [00:00<00:00, 10.73s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxcb-1.17.0        | 387 KB    | :   4% 0.04138544234733056/1 [00:00<00:10, 11.04s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-dejavu-sans | 388 KB    | :   4% 0.04123109444598234/1 [00:00<00:10, 11.11s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxcb-1.17.0        | 387 KB    | : 100% 1.0/1 [00:00<00:00, 11.04s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libfreetype6-2.13.3  | 371 KB    | :   4% 0.04310059084428123/1 [00:00<00:10, 11.14s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-dejavu-sans | 388 KB    | : 100% 1.0/1 [00:00<00:00, 11.11s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libfreetype6-2.13.3  | 371 KB    | : 100% 1.0/1 [00:00<00:00, 11.14s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-75.1             | 11.6 MB   | :  93% 0.9306939623320675/1 [00:00<00:00,  1.98it/s]
#
#
#
# pcre2-10.45          | 1.1 MB    | : 100% 1.0/1 [00:00<00:00,  1.46it/s]
#
#
#
# icu-75.1             | 11.6 MB   | : 100% 1.0/1 [00:00<00:00,  1.98it/s]
#
#
#
#
#
# xorg-libx11-1.8.12   | 816 KB    | : 100% 1.0/1 [00:00<00:00,  1.50it/s]
#
#
#
#
#
# xorg-libx11-1.8.12   | 816 KB    | : 100% 1.0/1 [00:00<00:00,  1.50it/s]
#
#
#
#
# cairo-1.18.4         | 955 KB    | : 100% 1.0/1 [00:00<00:00,  1.40it/s]
#
#
#
#
# cairo-1.18.4         | 955 KB    | : 100% 1.0/1 [00:00<00:00,  1.40it/s]
#
# libstdcxx-15.1.0     | 3.7 MB    | : 100% 1.0/1 [00:00<00:00,  3.82it/s]
# libglib-2.84.2       | 3.8 MB    | : 100% 1.0/1 [00:01<00:00,  3.55it/s]
#
#
#
#
#
#
# libiconv-1.18        | 696 KB    | : 100% 1.0/1 [00:01<00:00,  1.04it/s]
#
#
#
#
#
#
# libiconv-1.18        | 696 KB    | : 100% 1.0/1 [00:01<00:00,  1.04it/s]
#
#
#
#
#
#
#
# font-ttf-source-code | 684 KB    | : 100% 1.0/1 [00:01<00:00,  1.01it/s]
#
#
#
#
#
#
#
# font-ttf-source-code | 684 KB    | : 100% 1.0/1 [00:01<00:00,  1.01it/s]
#
#
#
#
#
#
#
#
#
# libjpeg-turbo-3.1.0  | 614 KB    | : 100% 1.0/1 [00:01<00:00,  1.01s/it]
#
#
#
#
#
#
#
#
#
# libjpeg-turbo-3.1.0  | 614 KB    | : 100% 1.0/1 [00:01<00:00,  1.01s/it]
#
#
#
#
#
#
#
#
# libxml2-2.13.8       | 675 KB    | : 100% 1.0/1 [00:01<00:00,  1.04s/it]
#
#
#
#
#
#
#
#
# libxml2-2.13.8       | 675 KB    | : 100% 1.0/1 [00:01<00:00,  1.04s/it]
#
#
#
#
#
#
#
#
#
#
# zstd-1.5.7           | 554 KB    | : 100% 1.0/1 [00:01<00:00,  1.04s/it]
#
#
#
#
#
#
#
#
#
#
# zstd-1.5.7           | 554 KB    | : 100% 1.0/1 [00:01<00:00,  1.04s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# libwebp-base-1.5.0   | 420 KB    | : 100% 1.0/1 [00:01<00:00,  1.08s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# libwebp-base-1.5.0   | 420 KB    | : 100% 1.0/1 [00:01<00:00,  1.08s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.7.0        | 420 KB    | : 100% 1.0/1 [00:01<00:00,  1.12s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libtiff-4.7.0        | 420 KB    | : 100% 1.0/1 [00:01<00:00,  1.12s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pixman-0.46.2        | 393 KB    | : 100% 1.0/1 [00:01<00:00,  1.14s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pixman-0.46.2        | 393 KB    | : 100% 1.0/1 [00:01<00:00,  1.14s/it]
#
#
#
#
#
#
#
#
#
#
#
# gdk-pixbuf-2.42.12   | 516 KB    | : 100% 1.0/1 [00:01<00:00,  1.16s/it]
#
#
#
#
#
#
#
#
#
#
#
# gdk-pixbuf-2.42.12   | 516 KB    | : 100% 1.0/1 [00:01<00:00,  1.16s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxcb-1.17.0        | 387 KB    | : 100% 1.0/1 [00:01<00:00,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libxcb-1.17.0        | 387 KB    | : 100% 1.0/1 [00:01<00:00,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libfreetype6-2.13.3  | 371 KB    | : 100% 1.0/1 [00:01<00:00,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libfreetype6-2.13.3  | 371 KB    | : 100% 1.0/1 [00:01<00:00,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-dejavu-sans | 388 KB    | : 100% 1.0/1 [00:01<00:00,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-dejavu-sans | 388 KB    | : 100% 1.0/1 [00:01<00:00,  1.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# icu-75.1             | 11.6 MB   | : 100% 1.0/1 [00:01<00:00,  1.98it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# \
# done
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# failed
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - openslide-tools
#   - libtiff-dev
#   - libopenslide0
#   - libjpeg-dev
#
# Current channels:
#
#   - https://conda.anaconda.org/conda-forge
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
#
#
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.2
#     latest version: 25.5.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/clam_latest
#
#   added / updated specs:
#     - future
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     future-1.0.0               |     pyhd8ed1ab_2         356 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         356 KB
#
# The following NEW packages will be INSTALLED:
#
#   future             conda-forge/noarch::future-1.0.0-pyhd8ed1ab_2
#
#
#
# Downloading and Extracting Packages:
#
# done
# done
# done
# Python 3.10.0
#
# Package                  Version
# ------------------------ -----------
# certifi                  2025.4.26
# charset-normalizer       3.4.2
# contourpy                1.3.2
# cycler                   0.12.1
# filelock                 3.18.0
# fonttools                4.58.4
# fsspec                   2025.5.1
# future                   1.0.0
# h5py                     3.14.0
# hf-xet                   1.1.3
# huggingface-hub          0.33.0
# idna                     3.10
# Jinja2                   3.1.6
# joblib                   1.5.1
# kiwisolver               1.4.8
# MarkupSafe               3.0.2
# matplotlib               3.10.3
# mpmath                   1.3.0
# networkx                 3.4.2
# numpy                    2.2.6
# nvidia-cublas-cu12       12.6.4.1
# nvidia-cuda-cupti-cu12   12.6.80
# nvidia-cuda-nvrtc-cu12   12.6.77
# nvidia-cuda-runtime-cu12 12.6.77
# nvidia-cudnn-cu12        9.5.1.17
# nvidia-cufft-cu12        11.3.0.4
# nvidia-cufile-cu12       1.11.1.6
# nvidia-curand-cu12       10.3.7.77
# nvidia-cusolver-cu12     11.7.1.2
# nvidia-cusparse-cu12     12.5.4.2
# nvidia-cusparselt-cu12   0.6.3
# nvidia-nccl-cu12         2.26.2
# nvidia-nvjitlink-cu12    12.6.85
# nvidia-nvtx-cu12         12.6.77
# opencv-python            4.11.0.86
# openslide-python         1.4.2
# packaging                25.0
# pandas                   2.3.0
# pillow                   11.2.1
# pip                      25.1.1
# protobuf                 6.31.1
# pyparsing                3.2.3
# python-dateutil          2.9.0.post0
# pytz                     2025.2
# PyYAML                   6.0.2
# requests                 2.32.4
# safetensors              0.5.3
# scikit-learn             1.7.0
# scipy                    1.15.3
# setuptools               80.9.0
# six                      1.17.0
# sympy                    1.14.0
# tensorboardX             2.6.4
# threadpoolctl            3.6.0
# timm                     0.9.8
# topk                     1.0
# torch                    2.7.1
# torchvision              0.22.1
# tqdm                     4.67.1
# triton                   3.3.1
# typing_extensions        4.14.0
# tzdata                   2025.2
# urllib3                  2.4.0
# wheel                    0.45.1
#
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:2 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,776 kB]
# Get:8 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,750 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,556 kB]
# Hit:12 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:13 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,296 kB]
# Get:15 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [9,037 kB]
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,986 kB]
# Get:17 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,249 kB]
# Fetched 23.0 MB in 2s (10.4 MB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libjpeg-dev is already the newest version (8c-2ubuntu10).
# libjpeg-dev set to manually installed.
# libtiff-dev is already the newest version (4.3.0-6ubuntu0.10).
# libtiff-dev set to manually installed.
# Suggested packages:
#   libtiff-tools
# The following NEW packages will be installed:
#   libopenslide0 openslide-tools
# 0 upgraded, 2 newly installed, 0 to remove and 35 not upgraded.
# Need to get 104 kB of archives.
# After this operation, 297 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenslide0 amd64 3.4.1+dfsg-5build1 [89.8 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 openslide-tools amd64 3.4.1+dfsg-5build1 [13.8 kB]
# Fetched 104 kB in 1s (120 kB/s)
# Selecting previously unselected package libopenslide0.
# (Reading database ... 126111 files and directories currently installed.)
# Preparing to unpack .../libopenslide0_3.4.1+dfsg-5build1_amd64.deb ...
# Unpacking libopenslide0 (3.4.1+dfsg-5build1) ...
# Selecting previously unselected package openslide-tools.
# Preparing to unpack .../openslide-tools_3.4.1+dfsg-5build1_amd64.deb ...
# Unpacking openslide-tools (3.4.1+dfsg-5build1) ...
# Setting up libopenslide0 (3.4.1+dfsg-5build1) ...
# Setting up openslide-tools (3.4.1+dfsg-5build1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/liblzma.so.5 is not a symbolic link

# %%
# !conda --version
# !which conda
# !conda config --show-sources
# !conda env update -n base -f MLIAProject/CLAM/env.yml
# Out:
# conda 24.11.2
# /usr/local/bin/conda
# ==> /usr/local/.condarc <==
# channels:
#   - conda-forge
# always_yes: True
#
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# failed
#
# SpecsConfigurationConflictError: Requested specs conflict with configured specs.
#   requested specs:
#     - pip
#     - python==3.10
#   pinned specs:
#     - cuda-version=12
#     - python=3.11
#     - python_abi=3.11[build=*cp311*]
# Use 'conda config --show-sources' to look for 'pinned_specs' and 'track_features'
# configuration parameters.  Pinned specs may also be defined in the file
# /usr/local/conda-meta/pinned.

# %%
import os
import zipfile

# URL for the dataset
url = "https://zenodo.org/records/15547611/files/datasetUnified_PT.zip?download=1"

# Download the file using wget
# !wget -O /content/Train.zip "$url"

# Define the extraction path
extract_path = './'

# Create the extraction directory if it doesn't exist
os.makedirs(extract_path, exist_ok=True)

# Extract the ZIP file
with zipfile.ZipFile('./Train.zip', 'r') as zip_ref:
    zip_ref.extractall(extract_path)

# List the contents of the extracted folder
extracted_files = os.listdir(extract_path)
print("Extracted files:", extracted_files)
# Out:
# --2025-06-14 08:24:14--  https://zenodo.org/records/15547611/files/datasetUnified_PT.zip?download=1
# Resolving zenodo.org (zenodo.org)... 188.185.48.194, 188.185.45.92, 188.185.43.25, ...
# Connecting to zenodo.org (zenodo.org)|188.185.48.194|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2005901570 (1.9G) [application/octet-stream]
# Saving to: ‘/content/Train.zip’
#
# /content/Train.zip  100%[===================>]   1.87G  22.0MB/s    in 92s
#
# 2025-06-14 08:25:47 (20.8 MB/s) - ‘/content/Train.zip’ saved [2005901570/2005901570]
#
# Extracted files: ['.config', 'condacolab_install.log', 'Train.zip', 'MLIAProject', 'results_features', 'sample_data']

# %%
## PCA TO REDUCE DIMENSIONALITY
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import numpy as np
import torch
import os

# Load all features
feature_dir = '/content/results_features/pt_files'
features = []

for fname in os.listdir(feature_dir):
    if fname.endswith('.pt'):
        data = torch.load(os.path.join(feature_dir, fname))
        features.append(data.numpy())

print(len(features))

all_features = np.vstack(features)

# Fit PCA
pca = PCA(n_components=min(512, all_features.shape[1]))
pca.fit(all_features)

# Plot explained variance
plt.figure(figsize=(10, 5))

# 1. Explained variance per component
plt.subplot(1, 2, 1)
plt.plot(pca.explained_variance_ratio_, marker='o')
plt.title("Explained Variance Ratio")
plt.xlabel("Principal Component")
plt.ylabel("Explained Variance")

# 2. Cumulative explained variance
plt.subplot(1, 2, 2)
plt.plot(np.cumsum(pca.explained_variance_ratio_), marker='o')
plt.title("Cumulative Explained Variance")
plt.xlabel("Number of Components")
plt.ylabel("Cumulative Variance Explained")

plt.tight_layout()
plt.show()
# Out:
# 22

# %%
import os
import numpy as np
import torch
from sklearn.decomposition import PCA
from tqdm import tqdm

# Set paths
input_dir = '/content/results_features/pt_files'         # original features
output_dir = '/content/results_features_pca100/pt_files' # reduced features
os.makedirs(output_dir, exist_ok=True)

# Collect all features
features = []
file_paths = []

print("Loading features...")
for fname in os.listdir(input_dir):
    if fname.endswith('.pt'):
        fpath = os.path.join(input_dir, fname)
        data = torch.load(fpath)
        features.append(data.numpy())
        file_paths.append(fname)

features = np.vstack(features)

# Apply PCA
print("Fitting PCA...")
pca = PCA(n_components=100)
pca.fit(features)

# Transform and save
print("Transforming and saving reduced features...")
start = 0
for i, fname in tqdm(enumerate(file_paths), total=len(file_paths)):
    original = torch.load(os.path.join(input_dir, fname)).numpy()
    reduced = pca.transform(original)
    torch.save(torch.tensor(reduced), os.path.join(output_dir, fname))

print(f"Saved PCA-reduced features to: {output_dir}")
# Out:
# Loading features...
# Fitting PCA...
# Transforming and saving reduced features...
# 100%|██████████| 22/22 [00:01<00:00, 11.29it/s]
# Saved PCA-reduced features to: /content/results_features_pca100/pt_files

# %%
import shutil
import os

original_dir = '/content/results_features'
pca_dir = '/content/results_features_pca100'

for fname in os.listdir(original_dir):
    if fname.endswith('.h5'):
        shutil.copy(os.path.join(original_dir, fname), os.path.join(pca_dir, fname))

print("Copied .h5 files to PCA directory.")
# Out:
# Copied .h5 files to PCA directory.

# %%
# !MPLBACKEND=Agg conda run -n clam_latest python MLIAProject/CLAM/create_splits_seq.py --task MLIA_Project --seed 1 --k 1 --val_frac 0.2 --test_frac 0.2
# Out:
# label column: label
# label dictionary: {'B': 0, 'S': 1, 'E': 2}
# number of classes: 3
# slide-level counts:
#  label
# 0    9
# 1    5
# 2    8
# Name: count, dtype: int64
# Patient-LVL; Number of samples registered in class 0: 9
# Slide-LVL; Number of samples registered in class 0: 9
# Patient-LVL; Number of samples registered in class 1: 5
# Slide-LVL; Number of samples registered in class 1: 5
# Patient-LVL; Number of samples registered in class 2: 8
# Slide-LVL; Number of samples registered in class 2: 8
#
# number of training samples: 12
# number of samples in cls 0: 5
# number of samples in cls 1: 3
# number of samples in cls 2: 4
#
# number of val samples: 5
# number of samples in cls 0: 2
# number of samples in cls 1: 1
# number of samples in cls 2: 2
#
# number of test samples: 5
# number of samples in cls 0: 2
# number of samples in cls 1: 1
# number of samples in cls 2: 2

# %%
# !MPLBACKEND=Agg CUDA_VISIBLE_DEVICES=0 conda run -n clam_latest python MLIAProject/CLAM/main.py --max_epoch 300 --drop_out 0.25 --lr 1e-4 --k 1 --exp_code MLIA_CLAM_50 --weighted_sample --bag_loss ce --inst_loss svm --task MLIA_Project --model_type clam_sb --log_data --subtyping --data_root_dir /content/results_features_pca100 --embed_dim 100
# Out:
# Load Dataset
# label column: label
# label dictionary: {'B': 0, 'S': 1, 'E': 2}
# number of classes: 3
# slide-level counts:
#  label
# 0    9
# 1    5
# 2    8
# Name: count, dtype: int64
# Patient-LVL; Number of samples registered in class 0: 9
# Slide-LVL; Number of samples registered in class 0: 9
# Patient-LVL; Number of samples registered in class 1: 5
# Slide-LVL; Number of samples registered in class 1: 5
# Patient-LVL; Number of samples registered in class 2: 8
# Slide-LVL; Number of samples registered in class 2: 8
# split_dir:  splits/MLIA_Project_100
# ################# Settings ###################
# num_splits:  1
# k_start:  -1
# k_end:  -1
# task:  MLIA_Project
# max_epochs:  300
# results_dir:  ./results
# lr:  0.0001
# experiment:  MLIA_CLAM_50
# reg:  1e-05
# label_frac:  1.0
# bag_loss:  ce
# seed:  1
# model_type:  clam_sb
# model_size:  small
# use_drop_out:  0.25
# weighted_sample:  True
# opt:  adam
# bag_weight:  0.7
# inst_loss:  svm
# B:  8
# split_dir:  splits/MLIA_Project_100
#
# Training Fold 0!
#
# Init train/val/test splits...
# Done!
# Training on 12 samples
# Validating on 5 samples
# Testing on 5 samples
#
# Init loss function... Done!
#
# Init Model... Setting tau to 1.0
# Done!
# CLAM_SB(
#   (attention_net): Sequential(
#     (0): Linear(in_features=100, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Attn_Net_Gated(
#       (attention_a): Sequential(
#         (0): Linear(in_features=512, out_features=256, bias=True)
#         (1): Tanh()
#         (2): Dropout(p=0.25, inplace=False)
#       )
#       (attention_b): Sequential(
#         (0): Linear(in_features=512, out_features=256, bias=True)
#         (1): Sigmoid()
#         (2): Dropout(p=0.25, inplace=False)
#       )
#       (attention_c): Linear(in_features=256, out_features=1, bias=True)
#     )
#   )
#   (classifiers): Linear(in_features=512, out_features=3, bias=True)
#   (instance_classifiers): ModuleList(
#     (0-2): 3 x Linear(in_features=512, out_features=2, bias=True)
#   )
#   (instance_loss_fn): SmoothTop1SVM()
# )
# Total number of parameters: 319242
# Total number of trainable parameters: 319242
#
# Init optimizer ... Done!
#
# Init Loaders... Done!
#
# Setup EarlyStopping... Done!
#
#
# 19866
# 19757
# 19810
# 19752
# 19836
# 19827
# 19741
# 19725
# 19808
# 19741
# 19849
# 19872
#
#
# class 0 clustering acc 0.5069444444444444: correct 146/288
# class 1 clustering acc 0.3541666666666667: correct 34/96
# Epoch: 0, train_loss: 1.0949, train_clustering_loss:  1.3202, train_error: 0.5833
# class 0: acc 1.0, correct 5/5
# class 1: acc 0.0, correct 0/3
# class 2: acc 0.0, correct 0/4
#
# Val Set, val_loss: 1.0869, val_error: 0.4000, auc: 0.8889
# class 0 clustering acc 0.6583333333333333: correct 79/120
# class 1 clustering acc 0.275: correct 11/40
# class 0: acc 1.0, correct 2/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
# 19833
# 19864
# 19701
# 19827
# 19745
# 19725
# 19677
# 19724
# 19736
# 19773
# 19816
# 19843
#
#
# class 0 clustering acc 0.5694444444444444: correct 164/288
# class 1 clustering acc 0.4583333333333333: correct 44/96
# Epoch: 1, train_loss: 1.0909, train_clustering_loss:  1.3176, train_error: 0.5000
# class 0: acc 1.0, correct 6/6
# class 1: acc 0.0, correct 0/4
# class 2: acc 0.0, correct 0/2
#
# Val Set, val_loss: 1.0871, val_error: 0.6000, auc: 0.8889
# class 0 clustering acc 0.6583333333333333: correct 79/120
# class 1 clustering acc 0.275: correct 11/40
# class 0: acc 1.0, correct 2/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.0, correct 0/2
#
#
# 19873
# 19701
# 19830
# 19827
# 19846
# 19828
# 19865
# 19830
# 19752
# 19810
# 19824
# 19843
#
#
# class 0 clustering acc 0.5868055555555556: correct 169/288
# class 1 clustering acc 0.5833333333333334: correct 56/96
# Epoch: 2, train_loss: 1.0947, train_clustering_loss:  1.3131, train_error: 0.6667
# class 0: acc 1.0, correct 4/4
# class 1: acc 0.0, correct 0/6
# class 2: acc 0.0, correct 0/2
#
# Val Set, val_loss: 1.0880, val_error: 0.6000, auc: 0.8889
# class 0 clustering acc 0.6666666666666666: correct 80/120
# class 1 clustering acc 0.2: correct 8/40
# class 0: acc 1.0, correct 2/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.0, correct 0/2
#
#
# 19702
# 19807
# 19800
# 19859
# 19872
# 19807
# 19748
# 19727
# 19834
# 19855
# 19869
# 19858
#
#
# class 0 clustering acc 0.5555555555555556: correct 160/288
# class 1 clustering acc 0.22916666666666666: correct 22/96
# Epoch: 3, train_loss: 1.0995, train_clustering_loss:  1.3255, train_error: 0.6667
# class 0: acc 1.0, correct 4/4
# class 1: acc 0.0, correct 0/2
# class 2: acc 0.0, correct 0/6
#
# Val Set, val_loss: 1.0885, val_error: 0.6000, auc: 0.8889
# class 0 clustering acc 0.6666666666666666: correct 80/120
# class 1 clustering acc 0.225: correct 9/40
# class 0: acc 1.0, correct 2/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.0, correct 0/2
#
#
# 19873
# 19749
# 19848
# 19832
# 19824
# 19847
# 19854
# 19827
# 19850
# 19827
# 19693
# 19847
#
#
# class 0 clustering acc 0.5555555555555556: correct 160/288
# class 1 clustering acc 0.4375: correct 42/96
# Epoch: 4, train_loss: 1.1028, train_clustering_loss:  1.3159, train_error: 0.8333
# class 0: acc 1.0, correct 2/2
# class 1: acc 0.0, correct 0/5
# class 2: acc 0.0, correct 0/5
#
# Val Set, val_loss: 1.0877, val_error: 0.6000, auc: 0.8889
# class 0 clustering acc 0.6666666666666666: correct 80/120
# class 1 clustering acc 0.25: correct 10/40
# class 0: acc 1.0, correct 2/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.0, correct 0/2
#
#
# 19873
# 19807
# 19839
# 19828
# 19824
# 19800
# 19859
# 19760
# 19727
# 19807
# 19846
# 19756
#
#
# class 0 clustering acc 0.5833333333333334: correct 168/288
# class 1 clustering acc 0.3541666666666667: correct 34/96
# Epoch: 5, train_loss: 1.0831, train_clustering_loss:  1.3203, train_error: 0.4167
# class 0: acc 1.0, correct 7/7
# class 1: acc 0.0, correct 0/3
# class 2: acc 0.0, correct 0/2
#
# Val Set, val_loss: 1.0878, val_error: 0.6000, auc: 0.8333
# class 0 clustering acc 0.6666666666666666: correct 80/120
# class 1 clustering acc 0.25: correct 10/40
# class 0: acc 1.0, correct 2/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.0, correct 0/2
#
#
# 19833
# 19694
# 19783
# 19818
# 19822
# 19850
# 19869
# 19872
# 19701
# 19806
# 19752
# 19850
#
#
# class 0 clustering acc 0.5763888888888888: correct 166/288
# class 1 clustering acc 0.53125: correct 51/96
# Epoch: 6, train_loss: 1.1007, train_clustering_loss:  1.3110, train_error: 0.8333
# class 0: acc 1.0, correct 2/2
# class 1: acc 0.0, correct 0/6
# class 2: acc 0.0, correct 0/4
#
# Val Set, val_loss: 1.0888, val_error: 0.6000, auc: 0.8333
# class 0 clustering acc 0.6666666666666666: correct 80/120
# class 1 clustering acc 0.225: correct 9/40
# class 0: acc 1.0, correct 2/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.0, correct 0/2
#
#
# 19796
# 19734
# 19771
# 19817
# 19824
# 19741
# 19831
# 19827
# 19864
# 19832
# 19741
# 19834
#
#
# class 0 clustering acc 0.5972222222222222: correct 172/288
# class 1 clustering acc 0.375: correct 36/96
# Epoch: 7, train_loss: 1.0955, train_clustering_loss:  1.3162, train_error: 0.6667
# class 0: acc 1.0, correct 4/4
# class 1: acc 0.0, correct 0/4
# class 2: acc 0.0, correct 0/4
#
# Val Set, val_loss: 1.0892, val_error: 0.6000, auc: 0.8333
# class 0 clustering acc 0.6666666666666666: correct 80/120
# class 1 clustering acc 0.225: correct 9/40
# class 0: acc 1.0, correct 2/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.0, correct 0/2
#
#
# 19832
# 19800
# 19795
# 19748
# 19786
# 19688
# 19783
# 19818
# 19822
# 19693
# 19770
# 19816
#
#
# class 0 clustering acc 0.6180555555555556: correct 178/288
# class 1 clustering acc 0.5520833333333334: correct 53/96
# Epoch: 8, train_loss: 1.0902, train_clustering_loss:  1.3079, train_error: 0.5833
# class 0: acc 1.0, correct 5/5
# class 1: acc 0.0, correct 0/6
# class 2: acc 0.0, correct 0/1
#
# Val Set, val_loss: 1.0900, val_error: 0.6000, auc: 0.8333
# class 0 clustering acc 0.6666666666666666: correct 80/120
# class 1 clustering acc 0.225: correct 9/40
# class 0: acc 1.0, correct 2/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.0, correct 0/2
#
#
# 19873
# 19851
# 19847
# 19854
# 19757
# 19773
# 19839
# 19868
# 19795
# 19857
# 19858
# 19869
#
#
# class 0 clustering acc 0.5486111111111112: correct 158/288
# class 1 clustering acc 0.14583333333333334: correct 14/96
# Epoch: 9, train_loss: 1.0999, train_clustering_loss:  1.3286, train_error: 0.6667
# class 0: acc 1.0, correct 4/4
# class 1: acc None, correct 0/0
# class 2: acc 0.0, correct 0/8
#
# Val Set, val_loss: 1.0892, val_error: 0.6000, auc: 0.8333
# class 0 clustering acc 0.6666666666666666: correct 80/120
# class 1 clustering acc 0.25: correct 10/40
# class 0: acc 1.0, correct 2/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.0, correct 0/2
#
#
# 19859
# 19804
# 19737
# 19808
# 19865
# 19851
# 19854
# 19829
# 19694
# 19847
# 19832
# 19824
#
#
# class 0 clustering acc 0.5729166666666666: correct 165/288
# class 1 clustering acc 0.46875: correct 45/96
# Epoch: 10, train_loss: 1.0927, train_clustering_loss:  1.3122, train_error: 0.7500
# class 0: acc 1.0, correct 3/3
# class 1: acc 0.0, correct 0/5
# class 2: acc 0.0, correct 0/4
#
# Val Set, val_loss: 1.0877, val_error: 0.6000, auc: 0.8333
# class 0 clustering acc 0.6666666666666666: correct 80/120
# class 1 clustering acc 0.225: correct 9/40
# class 0: acc 1.0, correct 2/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.0, correct 0/2
#
#
# 19852
# 19828
# 19865
# 19858
# 19848
# 19850
# 19756
# 19851
# 19872
# 19701
# 19848
# 19749
#
#
# class 0 clustering acc 0.5972222222222222: correct 172/288
# class 1 clustering acc 0.3333333333333333: correct 32/96
# Epoch: 11, train_loss: 1.0824, train_clustering_loss:  1.3185, train_error: 0.5833
# class 0: acc 1.0, correct 5/5
# class 1: acc 0.0, correct 0/2
# class 2: acc 0.0, correct 0/5
#
# Val Set, val_loss: 1.0873, val_error: 0.4000, auc: 0.8333
# class 0 clustering acc 0.6666666666666666: correct 80/120
# class 1 clustering acc 0.225: correct 9/40
# class 0: acc 1.0, correct 2/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
# 19809
# 19845
# 19869
# 19830
# 19800
# 19859
# 19795
# 19817
# 19800
# 19818
# 19800
# 19688
#
#
# class 0 clustering acc 0.5659722222222222: correct 163/288
# class 1 clustering acc 0.5: correct 48/96
# Epoch: 12, train_loss: 1.0924, train_clustering_loss:  1.3159, train_error: 0.6667
# class 0: acc 1.0, correct 4/4
# class 1: acc 0.0, correct 0/4
# class 2: acc 0.0, correct 0/4
#
# Val Set, val_loss: 1.0862, val_error: 0.6000, auc: 0.8333
# class 0 clustering acc 0.6666666666666666: correct 80/120
# class 1 clustering acc 0.225: correct 9/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
# 19852
# 19868
# 19851
# 19745
# 19834
# 19829
# 19824
# 19865
# 19701
# 19833
# 19848
# 19697
#
#
# class 0 clustering acc 0.5868055555555556: correct 169/288
# class 1 clustering acc 0.5208333333333334: correct 50/96
# Epoch: 13, train_loss: 1.0836, train_clustering_loss:  1.3131, train_error: 0.5833
# class 0: acc 1.0, correct 4/4
# class 1: acc 0.0, correct 0/4
# class 2: acc 0.25, correct 1/4
#
# Val Set, val_loss: 1.0861, val_error: 0.6000, auc: 0.8333
# class 0 clustering acc 0.6666666666666666: correct 80/120
# class 1 clustering acc 0.25: correct 10/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
# 19873
# 19854
# 19868
# 19872
# 19872
# 19872
# 19749
# 19771
# 19734
# 19848
# 19807
# 19819
#
#
# class 0 clustering acc 0.5416666666666666: correct 156/288
# class 1 clustering acc 0.16666666666666666: correct 16/96
# Epoch: 14, train_loss: 1.0836, train_clustering_loss:  1.3250, train_error: 0.5833
# class 0: acc 1.0, correct 4/4
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.14285714285714285, correct 1/7
#
# Val Set, val_loss: 1.0850, val_error: 0.6000, auc: 0.7778
# class 0 clustering acc 0.6666666666666666: correct 80/120
# class 1 clustering acc 0.25: correct 10/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
# 19702
# 19806
# 19846
# 19869
# 19832
# 19850
# 19869
# 19857
# 19869
# 19872
# 19701
# 19827
#
#
# class 0 clustering acc 0.5173611111111112: correct 149/288
# class 1 clustering acc 0.4583333333333333: correct 44/96
# Epoch: 15, train_loss: 1.0809, train_clustering_loss:  1.3170, train_error: 0.3333
# class 0: acc 1.0, correct 2/2
# class 1: acc 0.0, correct 0/4
# class 2: acc 1.0, correct 6/6
#
# Val Set, val_loss: 1.0846, val_error: 0.6000, auc: 0.7778
# class 0 clustering acc 0.6666666666666666: correct 80/120
# class 1 clustering acc 0.25: correct 10/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
# 19873
# 19807
# 19748
# 19680
# 19677
# 19807
# 19864
# 19832
# 19822
# 19692
# 19807
# 19824
#
#
# class 0 clustering acc 0.5868055555555556: correct 169/288
# class 1 clustering acc 0.7395833333333334: correct 71/96
# Epoch: 16, train_loss: 1.0987, train_clustering_loss:  1.3066, train_error: 0.6667
# class 0: acc 1.0, correct 2/2
# class 1: acc 0.0, correct 0/8
# class 2: acc 1.0, correct 2/2
#
# Val Set, val_loss: 1.0853, val_error: 0.6000, auc: 0.7778
# class 0 clustering acc 0.6666666666666666: correct 80/120
# class 1 clustering acc 0.25: correct 10/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
# 19809
# 19782
# 19836
# 19790
# 19836
# 19867
# 19857
# 19698
# 19807
# 19865
# 19830
# 19800
#
#
# class 0 clustering acc 0.5729166666666666: correct 165/288
# class 1 clustering acc 0.5104166666666666: correct 49/96
# Epoch: 17, train_loss: 1.0820, train_clustering_loss:  1.3153, train_error: 0.5000
# class 0: acc 0.75, correct 3/4
# class 1: acc 0.0, correct 0/3
# class 2: acc 0.6, correct 3/5
#
# Val Set, val_loss: 1.0863, val_error: 0.6000, auc: 0.7778
# class 0 clustering acc 0.6583333333333333: correct 79/120
# class 1 clustering acc 0.25: correct 10/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
# 19855
# 19828
# 19824
# 19800
# 19839
# 19850
# 19851
# 19854
# 19869
# 19858
# 19829
# 19847
#
#
# class 0 clustering acc 0.5694444444444444: correct 164/288
# class 1 clustering acc 0.3958333333333333: correct 38/96
# Epoch: 18, train_loss: 1.0735, train_clustering_loss:  1.3169, train_error: 0.3333
# class 0: acc 0.8333333333333334, correct 5/6
# class 1: acc 0.0, correct 0/3
# class 2: acc 1.0, correct 3/3
#
# Val Set, val_loss: 1.0867, val_error: 0.6000, auc: 0.7222
# class 0 clustering acc 0.6583333333333333: correct 79/120
# class 1 clustering acc 0.25: correct 10/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
# 19796
# 19745
# 19850
# 19760
# 19773
# 19816
# 19864
# 19760
# 19810
# 19847
# 19848
# 19868
#
#
# class 0 clustering acc 0.5833333333333334: correct 168/288
# class 1 clustering acc 0.3333333333333333: correct 32/96
# Epoch: 19, train_loss: 1.0750, train_clustering_loss:  1.3178, train_error: 0.3333
# class 0: acc 1.0, correct 5/5
# class 1: acc 0.0, correct 0/2
# class 2: acc 0.6, correct 3/5
#
# Val Set, val_loss: 1.0854, val_error: 0.6000, auc: 0.7222
# class 0 clustering acc 0.6583333333333333: correct 79/120
# class 1 clustering acc 0.25: correct 10/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
# 19761
# 19850
# 19851
# 19827
# 19850
# 19827
# 19843
# 19847
# 19756
# 19773
# 19843
# 19805
#
#
# class 0 clustering acc 0.59375: correct 171/288
# class 1 clustering acc 0.4270833333333333: correct 41/96
# Epoch: 20, train_loss: 1.0725, train_clustering_loss:  1.3175, train_error: 0.2500
# class 0: acc 1.0, correct 6/6
# class 1: acc 0.0, correct 0/2
# class 2: acc 0.75, correct 3/4
#
# Val Set, val_loss: 1.0839, val_error: 0.6000, auc: 0.7222
# class 0 clustering acc 0.6583333333333333: correct 79/120
# class 1 clustering acc 0.25: correct 10/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
# 19833
# 19753
# 19786
# 19859
# 19807
# 19688
# 19806
# 19800
# 19795
# 19688
# 19847
# 19857
#
#
# class 0 clustering acc 0.59375: correct 171/288
# class 1 clustering acc 0.5520833333333334: correct 53/96
# Epoch: 21, train_loss: 1.0821, train_clustering_loss:  1.3148, train_error: 0.3333
# class 0: acc 1.0, correct 5/5
# class 1: acc 0.0, correct 0/4
# class 2: acc 1.0, correct 3/3
#
# Val Set, val_loss: 1.0832, val_error: 0.6000, auc: 0.7222
# class 0 clustering acc 0.6583333333333333: correct 79/120
# class 1 clustering acc 0.25: correct 10/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
# 19852
# 19827
# 19864
# 19807
# 19860
# 19854
# 19854
# 19746
# 19677
# 19848
# 19872
# 19871
#
#
# class 0 clustering acc 0.5798611111111112: correct 167/288
# class 1 clustering acc 0.28125: correct 27/96
# Epoch: 22, train_loss: 1.0611, train_clustering_loss:  1.3178, train_error: 0.1667
# class 0: acc 1.0, correct 4/4
# class 1: acc 0.0, correct 0/2
# class 2: acc 1.0, correct 6/6
#
# Val Set, val_loss: 1.0822, val_error: 0.6000, auc: 0.7222
# class 0 clustering acc 0.6583333333333333: correct 79/120
# class 1 clustering acc 0.25: correct 10/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
# 19761
# 19680
# 19807
# 19822
# 19741
# 19771
# 19836
# 19867
# 19854
# 19868
# 19872
# 19795
#
#
# class 0 clustering acc 0.5972222222222222: correct 172/288
# class 1 clustering acc 0.3645833333333333: correct 35/96
# Epoch: 23, train_loss: 1.0705, train_clustering_loss:  1.3159, train_error: 0.4167
# class 0: acc 1.0, correct 4/4
# class 1: acc 0.0, correct 0/3
# class 2: acc 0.6, correct 3/5
#
# Val Set, val_loss: 1.0815, val_error: 0.6000, auc: 0.6667
# class 0 clustering acc 0.6666666666666666: correct 80/120
# class 1 clustering acc 0.25: correct 10/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
# 19833
# 19850
# 19827
# 19752
# 19680
# 19735
# 19851
# 19749
# 19784
# 19859
# 19830
# 19693
#
#
# class 0 clustering acc 0.5868055555555556: correct 169/288
# class 1 clustering acc 0.53125: correct 51/96
# Epoch: 24, train_loss: 1.0808, train_clustering_loss:  1.3134, train_error: 0.4167
# class 0: acc 1.0, correct 4/4
# class 1: acc 0.0, correct 0/5
# class 2: acc 1.0, correct 3/3
#
# Val Set, val_loss: 1.0808, val_error: 0.6000, auc: 0.6667
# class 0 clustering acc 0.6666666666666666: correct 80/120
# class 1 clustering acc 0.25: correct 10/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
# 19833
# 19850
# 19869
# 19854
# 19869
# 19807
# 19860
# 19830
# 19843
# 19854
# 19829
# 19850
#
#
# class 0 clustering acc 0.5763888888888888: correct 166/288
# class 1 clustering acc 0.3645833333333333: correct 35/96
# Epoch: 25, train_loss: 1.0540, train_clustering_loss:  1.3163, train_error: 0.2500
# class 0: acc 1.0, correct 3/3
# class 1: acc 0.0, correct 0/3
# class 2: acc 1.0, correct 6/6
#
# Val Set, val_loss: 1.0805, val_error: 0.6000, auc: 0.6667
# class 0 clustering acc 0.6666666666666666: correct 80/120
# class 1 clustering acc 0.25: correct 10/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
# 19796
# 19780
# 19817
# 19847
# 19698
# 19807
# 19694
# 19770
# 19843
# 19855
# 19855
# 19698
#
#
# class 0 clustering acc 0.5833333333333334: correct 168/288
# class 1 clustering acc 0.5416666666666666: correct 52/96
# Epoch: 26, train_loss: 1.0746, train_clustering_loss:  1.3128, train_error: 0.4167
# class 0: acc 1.0, correct 1/1
# class 1: acc 0.0, correct 0/5
# class 2: acc 1.0, correct 6/6
#
# Val Set, val_loss: 1.0806, val_error: 0.4000, auc: 0.6667
# class 0 clustering acc 0.6666666666666666: correct 80/120
# class 1 clustering acc 0.25: correct 10/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 1.0, correct 2/2
#
#
# 19833
# 19822
# 19822
# 19822
# 19843
# 19827
# 19787
# 19816
# 19800
# 19819
# 19843
# 19850
#
#
# class 0 clustering acc 0.5520833333333334: correct 159/288
# class 1 clustering acc 0.75: correct 72/96
# Epoch: 27, train_loss: 1.0972, train_clustering_loss:  1.3106, train_error: 0.6667
# class 0: acc 0.75, correct 3/4
# class 1: acc 0.0, correct 0/7
# class 2: acc 1.0, correct 1/1
#
# Val Set, val_loss: 1.0827, val_error: 0.4000, auc: 0.6667
# class 0 clustering acc 0.6666666666666666: correct 80/120
# class 1 clustering acc 0.25: correct 10/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 1.0, correct 2/2
#
#
# 19873
# 19872
# 19701
# 19724
# 19834
# 19698
# 19735
# 19830
# 19828
# 19824
# 19741
# 19828
#
#
# class 0 clustering acc 0.5902777777777778: correct 170/288
# class 1 clustering acc 0.5625: correct 54/96
# Epoch: 28, train_loss: 1.0694, train_clustering_loss:  1.3134, train_error: 0.5000
# class 0: acc 0.6, correct 3/5
# class 1: acc 0.0, correct 0/4
# class 2: acc 1.0, correct 3/3
#
# Val Set, val_loss: 1.0834, val_error: 0.4000, auc: 0.6667
# class 0 clustering acc 0.6666666666666666: correct 80/120
# class 1 clustering acc 0.25: correct 10/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 1.0, correct 2/2
#
#
# 19809
# 19748
# 19786
# 19839
# 19868
# 19701
# 19833
# 19698
# 19806
# 19864
# 19749
# 19828
#
#
# class 0 clustering acc 0.5972222222222222: correct 172/288
# class 1 clustering acc 0.46875: correct 45/96
# Epoch: 29, train_loss: 1.0691, train_clustering_loss:  1.3146, train_error: 0.5000
# class 0: acc 0.5, correct 3/6
# class 1: acc 0.0, correct 0/3
# class 2: acc 1.0, correct 3/3
#
# Val Set, val_loss: 1.0833, val_error: 0.6000, auc: 0.6667
# class 0 clustering acc 0.6666666666666666: correct 80/120
# class 1 clustering acc 0.25: correct 10/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
# 19796
# 19817
# 19822
# 19822
# 19864
# 19872
# 19807
# 19819
# 19741
# 19771
# 19817
# 19800
#
#
# class 0 clustering acc 0.5729166666666666: correct 165/288
# class 1 clustering acc 0.5625: correct 54/96
# Epoch: 30, train_loss: 1.0746, train_clustering_loss:  1.3131, train_error: 0.5000
# class 0: acc 0.6666666666666666, correct 2/3
# class 1: acc 0.0, correct 0/5
# class 2: acc 1.0, correct 4/4
#
# Val Set, val_loss: 1.0838, val_error: 0.6000, auc: 0.6667
# class 0 clustering acc 0.6666666666666666: correct 80/120
# class 1 clustering acc 0.25: correct 10/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
# 19761
# 19833
# 19828
# 19753
# 19850
# 19795
# 19793
# 19688
# 19677
# 19770
# 19780
# 19816
#
#
# class 0 clustering acc 0.5868055555555556: correct 169/288
# class 1 clustering acc 0.3958333333333333: correct 38/96
# Epoch: 31, train_loss: 1.0717, train_clustering_loss:  1.3138, train_error: 0.3333
# class 0: acc 1.0, correct 4/4
# class 1: acc 0.0, correct 0/4
# class 2: acc 1.0, correct 4/4
#
# Val Set, val_loss: 1.0838, val_error: 0.6000, auc: 0.6667
# class 0 clustering acc 0.6666666666666666: correct 80/120
# class 1 clustering acc 0.225: correct 9/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
# 19873
# 19830
# 19864
# 19872
# 19832
# 19824
# 19823
# 19787
# 19817
# 19753
# 19851
# 19749
#
#
# class 0 clustering acc 0.5798611111111112: correct 167/288
# class 1 clustering acc 0.5208333333333334: correct 50/96
# Epoch: 32, train_loss: 1.0577, train_clustering_loss:  1.3136, train_error: 0.3333
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.4, correct 2/5
# class 2: acc 1.0, correct 5/5
#
# Val Set, val_loss: 1.0848, val_error: 0.4000, auc: 0.6667
# class 0 clustering acc 0.6666666666666666: correct 80/120
# class 1 clustering acc 0.225: correct 9/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 1.0, correct 2/2
#
#
# 19859
# 19698
# 19806
# 19822
# 19799
# 19819
# 19864
# 19851
# 19854
# 19869
# 19872
# 19854
#
#
# class 0 clustering acc 0.5729166666666666: correct 165/288
# class 1 clustering acc 0.46875: correct 45/96
# Epoch: 33, train_loss: 1.0492, train_clustering_loss:  1.3137, train_error: 0.2500
# class 0: acc 1.0, correct 3/3
# class 1: acc 0.25, correct 1/4
# class 2: acc 1.0, correct 5/5
#
# Val Set, val_loss: 1.0855, val_error: 0.4000, auc: 0.6667
# class 0 clustering acc 0.6666666666666666: correct 80/120
# class 1 clustering acc 0.2: correct 8/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 1.0, correct 2/2
#
#
# 19832
# 19843
# 19847
# 19847
# 19850
# 19828
# 19864
# 19854
# 19869
# 19807
# 19737
# 19831
#
#
# class 0 clustering acc 0.59375: correct 171/288
# class 1 clustering acc 0.2916666666666667: correct 28/96
# Epoch: 34, train_loss: 1.0589, train_clustering_loss:  1.3150, train_error: 0.0833
# class 0: acc 0.875, correct 7/8
# class 1: acc 1.0, correct 2/2
# class 2: acc 1.0, correct 2/2
#
# Val Set, val_loss: 1.0847, val_error: 0.4000, auc: 0.6667
# class 0 clustering acc 0.6666666666666666: correct 80/120
# class 1 clustering acc 0.2: correct 8/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 1.0, correct 2/2
#
#
# 19832
# 19846
# 19756
# 19810
# 19741
# 19784
# 19818
# 19822
# 19800
# 19747
# 19830
# 19756
#
#
# class 0 clustering acc 0.6284722222222222: correct 181/288
# class 1 clustering acc 0.46875: correct 45/96
# Epoch: 35, train_loss: 1.0702, train_clustering_loss:  1.3131, train_error: 0.2500
# class 0: acc 1.0, correct 8/8
# class 1: acc 0.25, correct 1/4
# class 2: acc None, correct 0/0
#
# Val Set, val_loss: 1.0842, val_error: 0.6000, auc: 0.6667
# class 0 clustering acc 0.6666666666666666: correct 80/120
# class 1 clustering acc 0.2: correct 8/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
# 19702
# 19847
# 19872
# 19872
# 19795
# 19836
# 19826
# 19787
# 19745
# 19727
# 19725
# 19807
#
#
# class 0 clustering acc 0.59375: correct 171/288
# class 1 clustering acc 0.40625: correct 39/96
# Epoch: 36, train_loss: 1.0504, train_clustering_loss:  1.3142, train_error: 0.2500
# class 0: acc 1.0, correct 4/4
# class 1: acc 0.0, correct 0/3
# class 2: acc 1.0, correct 5/5
#
# Val Set, val_loss: 1.0831, val_error: 0.6000, auc: 0.6667
# class 0 clustering acc 0.6666666666666666: correct 80/120
# class 1 clustering acc 0.2: correct 8/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
# 19796
# 19857
# 19830
# 19787
# 19734
# 19834
# 19829
# 19694
# 19848
# 19830
# 19864
# 19854
#
#
# class 0 clustering acc 0.5833333333333334: correct 168/288
# class 1 clustering acc 0.5729166666666666: correct 55/96
# Epoch: 37, train_loss: 1.0402, train_clustering_loss:  1.3128, train_error: 0.3333
# class 0: acc 1.0, correct 2/2
# class 1: acc 0.0, correct 0/4
# class 2: acc 1.0, correct 6/6
#
# Val Set, val_loss: 1.0824, val_error: 0.6000, auc: 0.6667
# class 0 clustering acc 0.65: correct 78/120
# class 1 clustering acc 0.2: correct 8/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
# 19873
# 19701
# 19847
# 19832
# 19822
# 19787
# 19857
# 19701
# 19833
# 19804
# 19845
# 19792
#
#
# class 0 clustering acc 0.5833333333333334: correct 168/288
# class 1 clustering acc 0.59375: correct 57/96
# Epoch: 38, train_loss: 1.0373, train_clustering_loss:  1.3132, train_error: 0.3333
# class 0: acc 1.0, correct 1/1
# class 1: acc 0.0, correct 0/4
# class 2: acc 1.0, correct 7/7
#
# Val Set, val_loss: 1.0825, val_error: 0.6000, auc: 0.6667
# class 0 clustering acc 0.65: correct 78/120
# class 1 clustering acc 0.25: correct 10/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
# 19702
# 19735
# 19836
# 19869
# 19701
# 19807
# 19864
# 19701
# 19783
# 19795
# 19860
# 19795
#
#
# class 0 clustering acc 0.6145833333333334: correct 177/288
# class 1 clustering acc 0.59375: correct 57/96
# Epoch: 39, train_loss: 1.0388, train_clustering_loss:  1.3128, train_error: 0.2500
# class 0: acc 1.0, correct 3/3
# class 1: acc 0.25, correct 1/4
# class 2: acc 1.0, correct 5/5
#
# Val Set, val_loss: 1.0823, val_error: 0.6000, auc: 0.6667
# class 0 clustering acc 0.6416666666666667: correct 77/120
# class 1 clustering acc 0.25: correct 10/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
# 19873
# 19795
# 19793
# 19748
# 19680
# 19833
# 19698
# 19735
# 19833
# 19848
# 19697
# 19735
#
#
# class 0 clustering acc 0.6076388888888888: correct 175/288
# class 1 clustering acc 0.4479166666666667: correct 43/96
# Epoch: 40, train_loss: 1.0473, train_clustering_loss:  1.3139, train_error: 0.2500
# class 0: acc 1.0, correct 6/6
# class 1: acc 0.0, correct 0/3
# class 2: acc 1.0, correct 3/3
#
# Val Set, val_loss: 1.0813, val_error: 0.4000, auc: 0.6667
# class 0 clustering acc 0.6333333333333333: correct 76/120
# class 1 clustering acc 0.275: correct 11/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 1.0, correct 2/2
#
#
# 19832
# 19843
# 19868
# 19832
# 19787
# 19780
# 19816
# 19850
# 19792
# 19857
# 19701
# 19783
#
#
# class 0 clustering acc 0.6215277777777778: correct 179/288
# class 1 clustering acc 0.625: correct 60/96
# Epoch: 41, train_loss: 1.0153, train_clustering_loss:  1.3121, train_error: 0.2500
# class 0: acc 1.0, correct 2/2
# class 1: acc 0.25, correct 1/4
# class 2: acc 1.0, correct 6/6
#
# Val Set, val_loss: 1.0807, val_error: 0.4000, auc: 0.6667
# class 0 clustering acc 0.625: correct 75/120
# class 1 clustering acc 0.275: correct 11/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 1.0, correct 2/2
#
#
# 19873
# 19858
# 19804
# 19818
# 19823
# 19741
# 19807
# 19800
# 19688
# 19806
# 19843
# 19756
#
#
# class 0 clustering acc 0.6388888888888888: correct 184/288
# class 1 clustering acc 0.6354166666666666: correct 61/96
# Epoch: 42, train_loss: 1.0509, train_clustering_loss:  1.3125, train_error: 0.4167
# class 0: acc 0.8, correct 4/5
# class 1: acc 0.2, correct 1/5
# class 2: acc 1.0, correct 2/2
#
# Val Set, val_loss: 1.0805, val_error: 0.4000, auc: 0.6667
# class 0 clustering acc 0.6166666666666667: correct 74/120
# class 1 clustering acc 0.275: correct 11/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 1.0, correct 2/2
#
#
# 19873
# 19872
# 19857
# 19848
# 19828
# 19846
# 19828
# 19865
# 19854
# 19804
# 19748
# 19809
#
#
# class 0 clustering acc 0.6145833333333334: correct 177/288
# class 1 clustering acc 0.5: correct 48/96
# Epoch: 43, train_loss: 1.0102, train_clustering_loss:  1.3131, train_error: 0.0833
# class 0: acc 1.0, correct 5/5
# class 1: acc 0.6666666666666666, correct 2/3
# class 2: acc 1.0, correct 4/4
#
# Val Set, val_loss: 1.0796, val_error: 0.4000, auc: 0.6667
# class 0 clustering acc 0.6083333333333333: correct 73/120
# class 1 clustering acc 0.275: correct 11/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 1.0, correct 2/2
#
#
# 19809
# 19819
# 19864
# 19832
# 19865
# 19749
# 19808
# 19865
# 19807
# 19845
# 19804
# 19748
#
#
# class 0 clustering acc 0.6284722222222222: correct 181/288
# class 1 clustering acc 0.53125: correct 51/96
# Epoch: 44, train_loss: 1.0127, train_clustering_loss:  1.3129, train_error: 0.0000
# class 0: acc 1.0, correct 5/5
# class 1: acc 1.0, correct 3/3
# class 2: acc 1.0, correct 4/4
#
# Val Set, val_loss: 1.0787, val_error: 0.6000, auc: 0.6667
# class 0 clustering acc 0.6083333333333333: correct 73/120
# class 1 clustering acc 0.3: correct 12/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
# 19833
# 19824
# 19865
# 19795
# 19686
# 19847
# 19701
# 19806
# 19693
# 19807
# 19787
# 19816
#
#
# class 0 clustering acc 0.6006944444444444: correct 173/288
# class 1 clustering acc 0.8333333333333334: correct 80/96
# Epoch: 45, train_loss: 1.0260, train_clustering_loss:  1.3112, train_error: 0.3333
# class 0: acc None, correct 0/0
# class 1: acc 0.5, correct 4/8
# class 2: acc 1.0, correct 4/4
#
# Val Set, val_loss: 1.0782, val_error: 0.6000, auc: 0.6667
# class 0 clustering acc 0.5916666666666667: correct 71/120
# class 1 clustering acc 0.375: correct 15/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
# 19859
# 19698
# 19847
# 19749
# 19725
# 19808
# 19753
# 19773
# 19857
# 19749
# 19677
# 19827
#
#
# class 0 clustering acc 0.6006944444444444: correct 173/288
# class 1 clustering acc 0.4895833333333333: correct 47/96
# Epoch: 46, train_loss: 1.0108, train_clustering_loss:  1.3130, train_error: 0.0833
# class 0: acc 1.0, correct 5/5
# class 1: acc 0.6666666666666666, correct 2/3
# class 2: acc 1.0, correct 4/4
#
# Val Set, val_loss: 1.0763, val_error: 0.4000, auc: 0.6667
# class 0 clustering acc 0.5916666666666667: correct 71/120
# class 1 clustering acc 0.4: correct 16/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 1.0, correct 2/2
#
#
# 19702
# 19847
# 19830
# 19787
# 19857
# 19851
# 19756
# 19786
# 19860
# 19760
# 19810
# 19694
#
#
# class 0 clustering acc 0.5902777777777778: correct 170/288
# class 1 clustering acc 0.5520833333333334: correct 53/96
# Epoch: 47, train_loss: 1.0039, train_clustering_loss:  1.3132, train_error: 0.0000
# class 0: acc 1.0, correct 4/4
# class 1: acc 1.0, correct 4/4
# class 2: acc 1.0, correct 4/4
#
# Val Set, val_loss: 1.0722, val_error: 0.4000, auc: 0.6667
# class 0 clustering acc 0.5833333333333334: correct 70/120
# class 1 clustering acc 0.475: correct 19/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 1.0, correct 2/2
#
#
# 19702
# 19848
# 19872
# 19749
# 19828
# 19854
# 19869
# 19795
# 19816
# 19693
# 19806
# 19822
#
#
# class 0 clustering acc 0.6145833333333334: correct 177/288
# class 1 clustering acc 0.6770833333333334: correct 65/96
# Epoch: 48, train_loss: 0.9758, train_clustering_loss:  1.3125, train_error: 0.0000
# class 0: acc 1.0, correct 2/2
# class 1: acc 1.0, correct 5/5
# class 2: acc 1.0, correct 5/5
#
# Val Set, val_loss: 1.0600, val_error: 0.4000, auc: 0.6667
# class 0 clustering acc 0.5833333333333334: correct 70/120
# class 1 clustering acc 0.55: correct 22/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 1.0, correct 2/2
#
#
# 19702
# 19724
# 19808
# 19864
# 19832
# 19850
# 19855
# 19757
# 19836
# 19869
# 19832
# 19694
#
#
# class 0 clustering acc 0.5590277777777778: correct 161/288
# class 1 clustering acc 0.7291666666666666: correct 70/96
# Epoch: 49, train_loss: 0.9393, train_clustering_loss:  1.3126, train_error: 0.0000
# class 0: acc 1.0, correct 2/2
# class 1: acc 1.0, correct 5/5
# class 2: acc 1.0, correct 5/5
#
# Val Set, val_loss: 1.0349, val_error: 0.4000, auc: 0.7222
# class 0 clustering acc 0.5333333333333333: correct 64/120
# class 1 clustering acc 0.6: correct 24/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 1.0, correct 2/2
#
#
# 19859
# 19698
# 19847
# 19832
# 19800
# 19859
# 19795
# 19793
# 19845
# 19792
# 19843
# 19792
#
#
# class 0 clustering acc 0.6111111111111112: correct 176/288
# class 1 clustering acc 0.7291666666666666: correct 70/96
# Epoch: 50, train_loss: 0.8186, train_clustering_loss:  1.3124, train_error: 0.0000
# class 0: acc 1.0, correct 2/2
# class 1: acc 1.0, correct 2/2
# class 2: acc 1.0, correct 8/8
#
# Val Set, val_loss: 1.0038, val_error: 0.4000, auc: 0.7778
# class 0 clustering acc 0.5083333333333333: correct 61/120
# class 1 clustering acc 0.6: correct 24/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 1.0, correct 2/2
#
#
# 19859
# 19829
# 19847
# 19868
# 19832
# 19865
# 19872
# 19872
# 19760
# 19851
# 19858
# 19855
#
#
# class 0 clustering acc 0.6215277777777778: correct 179/288
# class 1 clustering acc 0.75: correct 72/96
# Epoch: 51, train_loss: 0.6883, train_clustering_loss:  1.3124, train_error: 0.0000
# class 0: acc 1.0, correct 2/2
# class 1: acc 1.0, correct 2/2
# class 2: acc 1.0, correct 8/8
#
# Val Set, val_loss: 0.9858, val_error: 0.6000, auc: 0.7778
# class 0 clustering acc 0.49166666666666664: correct 59/120
# class 1 clustering acc 0.6: correct 24/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 1.0, correct 2/2
#
#
# 19855
# 19827
# 19693
# 19724
# 19771
# 19793
# 19845
# 19855
# 19698
# 19806
# 19864
# 19854
#
#
# class 0 clustering acc 0.5555555555555556: correct 160/288
# class 1 clustering acc 0.625: correct 60/96
# Epoch: 52, train_loss: 0.8797, train_clustering_loss:  1.3129, train_error: 0.2500
# class 0: acc 0.75, correct 3/4
# class 1: acc 0.5, correct 2/4
# class 2: acc 1.0, correct 4/4
#
# Val Set, val_loss: 0.9796, val_error: 0.6000, auc: 0.8333
# class 0 clustering acc 0.5: correct 60/120
# class 1 clustering acc 0.6: correct 24/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 1.0, correct 2/2
#
#
# 19873
# 19858
# 19869
# 19872
# 19807
# 19782
# 19793
# 19748
# 19809
# 19741
# 19771
# 19836
#
#
# class 0 clustering acc 0.6180555555555556: correct 178/288
# class 1 clustering acc 0.46875: correct 45/96
# Epoch: 53, train_loss: 0.8362, train_clustering_loss:  1.3132, train_error: 0.3333
# class 0: acc 0.2, correct 1/5
# class 1: acc 1.0, correct 1/1
# class 2: acc 1.0, correct 6/6
#
# Val Set, val_loss: 0.9779, val_error: 0.6000, auc: 0.8333
# class 0 clustering acc 0.5: correct 60/120
# class 1 clustering acc 0.6: correct 24/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 1.0, correct 2/2
#
#
# 19832
# 19843
# 19756
# 19850
# 19701
# 19783
# 19860
# 19854
# 19792
# 19816
# 19741
# 19736
#
#
# class 0 clustering acc 0.6041666666666666: correct 174/288
# class 1 clustering acc 0.4895833333333333: correct 47/96
# Epoch: 54, train_loss: 0.9277, train_clustering_loss:  1.3133, train_error: 0.1667
# class 0: acc 0.8333333333333334, correct 5/6
# class 1: acc 0.6666666666666666, correct 2/3
# class 2: acc 1.0, correct 3/3
#
# Val Set, val_loss: 0.9771, val_error: 0.6000, auc: 0.8333
# class 0 clustering acc 0.5166666666666667: correct 62/120
# class 1 clustering acc 0.6: correct 24/40
# class 0: acc 0.0, correct 0/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 1.0, correct 2/2
#
#
# 19873
# 19854
# 19868
# 19832
# 19844
# 19850
# 19792
# 19817
# 19822
# 19864
# 19701
# 19806
#
#
# class 0 clustering acc 0.59375: correct 171/288
# class 1 clustering acc 0.6875: correct 66/96
# Epoch: 55, train_loss: 0.9021, train_clustering_loss:  1.3127, train_error: 0.1667
# class 0: acc 0.6666666666666666, correct 2/3
# class 1: acc 0.8, correct 4/5
# class 2: acc 1.0, correct 4/4
#
# Val Set, val_loss: 0.9785, val_error: 0.4000, auc: 0.8333
# class 0 clustering acc 0.5166666666666667: correct 62/120
# class 1 clustering acc 0.6: correct 24/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 1.0, correct 2/2
#
#
# 19873
# 19795
# 19745
# 19836
# 19698
# 19827
# 19827
# 19846
# 19698
# 19827
# 19745
# 19849
#
#
# class 0 clustering acc 0.5868055555555556: correct 169/288
# class 1 clustering acc 0.5729166666666666: correct 55/96
# Epoch: 56, train_loss: 0.8425, train_clustering_loss:  1.3131, train_error: 0.1667
# class 0: acc 1.0, correct 5/5
# class 1: acc 0.3333333333333333, correct 1/3
# class 2: acc 1.0, correct 4/4
#
# Val Set, val_loss: 0.9816, val_error: 0.4000, auc: 0.7778
# class 0 clustering acc 0.5333333333333333: correct 64/120
# class 1 clustering acc 0.6: correct 24/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 1.0, correct 2/2
#
#
# 19750
# 19849
# 19760
# 19851
# 19749
# 19677
# 19827
# 19827
# 19846
# 19828
# 19753
# 19680
#
#
# class 0 clustering acc 0.5659722222222222: correct 163/288
# class 1 clustering acc 0.53125: correct 51/96
# Epoch: 57, train_loss: 0.8640, train_clustering_loss:  1.3132, train_error: 0.1667
# class 0: acc 1.0, correct 6/6
# class 1: acc 0.5, correct 2/4
# class 2: acc 1.0, correct 2/2
#
# Val Set, val_loss: 0.9950, val_error: 0.4000, auc: 0.8333
# class 0 clustering acc 0.5666666666666667: correct 68/120
# class 1 clustering acc 0.5: correct 20/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 1.0, correct 2/2
#
#
# 19761
# 19773
# 19843
# 19869
# 19851
# 19847
# 19756
# 19738
# 19809
# 19824
# 19822
# 19850
#
#
# class 0 clustering acc 0.5694444444444444: correct 164/288
# class 1 clustering acc 0.53125: correct 51/96
# Epoch: 58, train_loss: 0.7861, train_clustering_loss:  1.3132, train_error: 0.0833
# class 0: acc 1.0, correct 5/5
# class 1: acc 0.6666666666666666, correct 2/3
# class 2: acc 1.0, correct 4/4
#
# Val Set, val_loss: 1.0060, val_error: 0.6000, auc: 0.8333
# class 0 clustering acc 0.5916666666666667: correct 71/120
# class 1 clustering acc 0.475: correct 19/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
# 19832
# 19824
# 19844
# 19697
# 19677
# 19783
# 19845
# 19746
# 19677
# 19827
# 19804
# 19688
#
#
# class 0 clustering acc 0.5694444444444444: correct 164/288
# class 1 clustering acc 0.6041666666666666: correct 58/96
# Epoch: 59, train_loss: 0.9356, train_clustering_loss:  1.3129, train_error: 0.4167
# class 0: acc 1.0, correct 5/5
# class 1: acc 0.16666666666666666, correct 1/6
# class 2: acc 1.0, correct 1/1
#
# Val Set, val_loss: 1.0166, val_error: 0.6000, auc: 0.7778
# class 0 clustering acc 0.5916666666666667: correct 71/120
# class 1 clustering acc 0.475: correct 19/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
# 19809
# 19842
# 19804
# 19859
# 19795
# 19816
# 19752
# 19786
# 19782
# 19817
# 19787
# 19857
#
#
# class 0 clustering acc 0.5729166666666666: correct 165/288
# class 1 clustering acc 0.5104166666666666: correct 49/96
# Epoch: 60, train_loss: 0.8033, train_clustering_loss:  1.3133, train_error: 0.0833
# class 0: acc 1.0, correct 5/5
# class 1: acc 0.5, correct 1/2
# class 2: acc 1.0, correct 5/5
#
# Val Set, val_loss: 1.0238, val_error: 0.6000, auc: 0.7778
# class 0 clustering acc 0.5916666666666667: correct 71/120
# class 1 clustering acc 0.45: correct 18/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
# 19832
# 19741
# 19807
# 19822
# 19850
# 19855
# 19829
# 19822
# 19741
# 19807
# 19850
# 19757
#
#
# class 0 clustering acc 0.5868055555555556: correct 169/288
# class 1 clustering acc 0.7395833333333334: correct 71/96
# Epoch: 61, train_loss: 0.6762, train_clustering_loss:  1.3128, train_error: 0.0833
# class 0: acc 1.0, correct 3/3
# class 1: acc 0.8333333333333334, correct 5/6
# class 2: acc 1.0, correct 3/3
#
# Val Set, val_loss: 1.0270, val_error: 0.6000, auc: 0.7778
# class 0 clustering acc 0.5916666666666667: correct 71/120
# class 1 clustering acc 0.475: correct 19/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
# 19855
# 19828
# 19787
# 19817
# 19865
# 19701
# 19807
# 19865
# 19795
# 19843
# 19852
# 19848
#
#
# class 0 clustering acc 0.6111111111111112: correct 176/288
# class 1 clustering acc 0.6770833333333334: correct 65/96
# Epoch: 62, train_loss: 0.7146, train_clustering_loss:  1.3126, train_error: 0.4167
# class 0: acc 0.6666666666666666, correct 2/3
# class 1: acc 0.0, correct 0/4
# class 2: acc 1.0, correct 5/5
#
# Val Set, val_loss: 1.0329, val_error: 0.6000, auc: 0.7778
# class 0 clustering acc 0.5916666666666667: correct 71/120
# class 1 clustering acc 0.475: correct 19/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
# 19833
# 19822
# 19822
# 19787
# 19857
# 19701
# 19827
# 19697
# 19724
# 19808
# 19864
# 19857
#
#
# class 0 clustering acc 0.6180555555555556: correct 178/288
# class 1 clustering acc 0.8020833333333334: correct 77/96
# Epoch: 63, train_loss: 0.7653, train_clustering_loss:  1.3126, train_error: 0.0833
# class 0: acc 0.5, correct 1/2
# class 1: acc 1.0, correct 6/6
# class 2: acc 1.0, correct 4/4
#
# Val Set, val_loss: 1.0383, val_error: 0.6000, auc: 0.7778
# class 0 clustering acc 0.5916666666666667: correct 71/120
# class 1 clustering acc 0.45: correct 18/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
# 19702
# 19724
# 19834
# 19855
# 19827
# 19693
# 19783
# 19819
# 19822
# 19864
# 19872
# 19854
#
#
# class 0 clustering acc 0.6041666666666666: correct 174/288
# class 1 clustering acc 0.7395833333333334: correct 71/96
# Epoch: 64, train_loss: 0.6610, train_clustering_loss:  1.3127, train_error: 0.0000
# class 0: acc 1.0, correct 3/3
# class 1: acc 1.0, correct 5/5
# class 2: acc 1.0, correct 4/4
#
# Val Set, val_loss: 1.0470, val_error: 0.6000, auc: 0.7778
# class 0 clustering acc 0.5916666666666667: correct 71/120
# class 1 clustering acc 0.45: correct 18/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
# 19855
# 19869
# 19854
# 19869
# 19854
# 19792
# 19686
# 19724
# 19834
# 19792
# 19686
# 19806
#
#
# class 0 clustering acc 0.5902777777777778: correct 170/288
# class 1 clustering acc 0.6458333333333334: correct 62/96
# Epoch: 65, train_loss: 0.6332, train_clustering_loss:  1.3129, train_error: 0.0000
# class 0: acc 1.0, correct 4/4
# class 1: acc 1.0, correct 3/3
# class 2: acc 1.0, correct 5/5
#
# Val Set, val_loss: 1.0571, val_error: 0.6000, auc: 0.7778
# class 0 clustering acc 0.5916666666666667: correct 71/120
# class 1 clustering acc 0.475: correct 19/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
# 19859
# 19804
# 19859
# 19872
# 19854
# 19854
# 19829
# 19787
# 19857
# 19701
# 19847
# 19851
#
#
# class 0 clustering acc 0.6319444444444444: correct 182/288
# class 1 clustering acc 0.5833333333333334: correct 56/96
# Epoch: 66, train_loss: 0.6812, train_clustering_loss:  1.3129, train_error: 0.0833
# class 0: acc 0.6666666666666666, correct 2/3
# class 1: acc 1.0, correct 2/2
# class 2: acc 1.0, correct 7/7
#
# Val Set, val_loss: 1.0645, val_error: 0.6000, auc: 0.7778
# class 0 clustering acc 0.5916666666666667: correct 71/120
# class 1 clustering acc 0.475: correct 19/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
# 19796
# 19780
# 19843
# 19699
# 19807
# 19800
# 19818
# 19741
# 19807
# 19741
# 19848
# 19857
#
#
# class 0 clustering acc 0.6041666666666666: correct 174/288
# class 1 clustering acc 0.7291666666666666: correct 70/96
# Epoch: 67, train_loss: 0.6278, train_clustering_loss:  1.3129, train_error: 0.0000
# class 0: acc 1.0, correct 3/3
# class 1: acc 1.0, correct 4/4
# class 2: acc 1.0, correct 5/5
#
# Val Set, val_loss: 1.0686, val_error: 0.6000, auc: 0.7778
# class 0 clustering acc 0.5916666666666667: correct 71/120
# class 1 clustering acc 0.475: correct 19/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
# 19809
# 19688
# 19735
# 19830
# 19790
# 19857
# 19872
# 19701
# 19807
# 19694
# 19847
# 19854
#
#
# class 0 clustering acc 0.6319444444444444: correct 182/288
# class 1 clustering acc 0.5729166666666666: correct 55/96
# Epoch: 68, train_loss: 0.8055, train_clustering_loss:  1.3130, train_error: 0.0833
# class 0: acc 0.75, correct 3/4
# class 1: acc 1.0, correct 4/4
# class 2: acc 1.0, correct 4/4
#
# Val Set, val_loss: 1.0807, val_error: 0.6000, auc: 0.7778
# class 0 clustering acc 0.5916666666666667: correct 71/120
# class 1 clustering acc 0.475: correct 19/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
# 19761
# 19680
# 19830
# 19828
# 19824
# 19787
# 19734
# 19831
# 19869
# 19830
# 19800
# 19860
#
#
# class 0 clustering acc 0.5798611111111112: correct 167/288
# class 1 clustering acc 0.53125: correct 51/96
# Epoch: 69, train_loss: 0.6856, train_clustering_loss:  1.3131, train_error: 0.0000
# class 0: acc 1.0, correct 5/5
# class 1: acc 1.0, correct 4/4
# class 2: acc 1.0, correct 3/3
#
# Val Set, val_loss: 1.0960, val_error: 0.6000, auc: 0.7222
# class 0 clustering acc 0.5916666666666667: correct 71/120
# class 1 clustering acc 0.475: correct 19/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
# 19833
# 19865
# 19851
# 19745
# 19848
# 19854
# 19828
# 19850
# 19869
# 19872
# 19749
# 19784
#
#
# class 0 clustering acc 0.625: correct 180/288
# class 1 clustering acc 0.5: correct 48/96
# Epoch: 70, train_loss: 0.6329, train_clustering_loss:  1.3132, train_error: 0.1667
# class 0: acc 0.8, correct 4/5
# class 1: acc 0.5, correct 1/2
# class 2: acc 1.0, correct 5/5
#
# Val Set, val_loss: 1.1096, val_error: 0.6000, auc: 0.7222
# class 0 clustering acc 0.5916666666666667: correct 71/120
# class 1 clustering acc 0.5: correct 20/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
# 19833
# 19694
# 19724
# 19771
# 19686
# 19677
# 19807
# 19850
# 19869
# 19857
# 19804
# 19819
#
#
# class 0 clustering acc 0.6180555555555556: correct 178/288
# class 1 clustering acc 0.8020833333333334: correct 77/96
# Epoch: 71, train_loss: 0.7000, train_clustering_loss:  1.3129, train_error: 0.0000
# class 0: acc 1.0, correct 2/2
# class 1: acc 1.0, correct 6/6
# class 2: acc 1.0, correct 4/4
#
# Val Set, val_loss: 1.1191, val_error: 0.6000, auc: 0.7222
# class 0 clustering acc 0.5916666666666667: correct 71/120
# class 1 clustering acc 0.5: correct 20/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
# 19873
# 19872
# 19857
# 19829
# 19864
# 19851
# 19827
# 19846
# 19827
# 19693
# 19783
# 19795
#
#
# class 0 clustering acc 0.6319444444444444: correct 182/288
# class 1 clustering acc 0.6354166666666666: correct 61/96
# Epoch: 72, train_loss: 0.6825, train_clustering_loss:  1.3130, train_error: 0.0833
# class 0: acc 0.75, correct 3/4
# class 1: acc 1.0, correct 4/4
# class 2: acc 1.0, correct 4/4
#
# Val Set, val_loss: 1.1284, val_error: 0.6000, auc: 0.7222
# class 0 clustering acc 0.6: correct 72/120
# class 1 clustering acc 0.475: correct 19/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
# 19855
# 19854
# 19869
# 19830
# 19752
# 19830
# 19790
# 19745
# 19786
# 19859
# 19857
# 19792
#
#
# class 0 clustering acc 0.5833333333333334: correct 168/288
# class 1 clustering acc 0.46875: correct 45/96
# Epoch: 73, train_loss: 0.5901, train_clustering_loss:  1.3132, train_error: 0.0833
# class 0: acc 0.8, correct 4/5
# class 1: acc 1.0, correct 1/1
# class 2: acc 1.0, correct 6/6
#
# Val Set, val_loss: 1.1428, val_error: 0.6000, auc: 0.7222
# class 0 clustering acc 0.6: correct 72/120
# class 1 clustering acc 0.475: correct 19/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
# 19873
# 19851
# 19854
# 19699
# 19806
# 19822
# 19752
# 19727
# 19725
# 19828
# 19850
# 19756
#
#
# class 0 clustering acc 0.59375: correct 171/288
# class 1 clustering acc 0.4583333333333333: correct 44/96
# Epoch: 74, train_loss: 0.6046, train_clustering_loss:  1.3132, train_error: 0.1667
# class 0: acc 0.7142857142857143, correct 5/7
# class 1: acc 1.0, correct 3/3
# class 2: acc 1.0, correct 2/2
#
# Val Set, val_loss: 1.1577, val_error: 0.6000, auc: 0.7222
# class 0 clustering acc 0.6083333333333333: correct 73/120
# class 1 clustering acc 0.475: correct 19/40
# class 0: acc 0.5, correct 1/2
# class 1: acc 0.0, correct 0/1
# class 2: acc 0.5, correct 1/2
#
#
# 19702
# 19848
# 19795
# 19793
# 19842
# ...
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/envs/clam_latest/lib/python3.10/site-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(

# %%
# !zip -r result_classifier.zip 'results/'
# Out:
# updating: results/ (stored 0%)
# updating: results/MLIA_CLAM_50_s1/ (stored 0%)
# updating: results/MLIA_CLAM_50_s1/s_0_checkpoint.pt (deflated 9%)
# updating: results/MLIA_CLAM_50_s1/splits_0.csv (deflated 44%)
# updating: results/MLIA_CLAM_50_s1/experiment_MLIA_CLAM_50.txt (deflated 40%)
# updating: results/MLIA_CLAM_50_s1/summary.csv (deflated 44%)
# updating: results/MLIA_CLAM_50_s1/0/ (stored 0%)
# updating: results/MLIA_CLAM_50_s1/0/events.out.tfevents.1749890751.38ca1ddf4b36 (deflated 42%)
# updating: results/MLIA_CLAM_50_s1/0/events.out.tfevents.1749890795.38ca1ddf4b36 (deflated 42%)
# updating: results/MLIA_CLAM_50_s1/0/events.out.tfevents.1749890821.38ca1ddf4b36 (deflated 42%)
# updating: results/MLIA_CLAM_50_s1/0/events.out.tfevents.1749890210.38ca1ddf4b36 (deflated 75%)
# updating: results/MLIA_CLAM_50_s1/0/events.out.tfevents.1749890531.38ca1ddf4b36 (deflated 5%)
# updating: results/MLIA_CLAM_50_s1/0/events.out.tfevents.1749889766.38ca1ddf4b36 (deflated 42%)
# updating: results/MLIA_CLAM_50_s1/0/events.out.tfevents.1749890507.38ca1ddf4b36 (deflated 66%)
# updating: results/MLIA_CLAM_50_s1/0/events.out.tfevents.1749890701.38ca1ddf4b36 (deflated 73%)
# updating: results/MLIA_CLAM_50_s1/0/events.out.tfevents.1749890845.38ca1ddf4b36 (deflated 75%)
# updating: results/MLIA_CLAM_50_s1/split_0_results.pkl (deflated 55%)
#   adding: results/MLIA_CLAM_50_s1/0/events.out.tfevents.1749893019.38ca1ddf4b36 (deflated 76%)

# %%
# !MPLBACKEND=Agg CUDA_VISIBLE_DEVICES=0 conda run -n clam_latest python MLIAProject/CLAM/eval.py --k 1 --models_exp_code MLIA_CLAM_50_s1 --save_exp_code MLIA_CLAM_eval --task MLIA_Project --model_type clam_sb --results_dir results --data_root_dir  /content/results_features_pca100 --embed_dim 100
# Out:
# Models directory: results/MLIA_CLAM_50_s1
# {'task': 'MLIA_Project', 'split': 'test', 'save_dir': './eval_results/EVAL_MLIA_CLAM_eval', 'models_dir': 'results/MLIA_CLAM_50_s1', 'model_type': 'clam_sb', 'drop_out': 0.25, 'model_size': 'small'}
# label column: label
# label dictionary: {'B': 0, 'S': 1, 'E': 2}
# number of classes: 3
# slide-level counts:
#  label
# 0    9
# 1    5
# 2    8
# Name: count, dtype: int64
# Patient-LVL; Number of samples registered in class 0: 9
# Slide-LVL; Number of samples registered in class 0: 9
# Patient-LVL; Number of samples registered in class 1: 5
# Slide-LVL; Number of samples registered in class 1: 5
# Patient-LVL; Number of samples registered in class 2: 8
# Slide-LVL; Number of samples registered in class 2: 8
# Init Model
# CLAM_SB(
#   (attention_net): Sequential(
#     (0): Linear(in_features=100, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.25, inplace=False)
#     (3): Attn_Net_Gated(
#       (attention_a): Sequential(
#         (0): Linear(in_features=512, out_features=256, bias=True)
#         (1): Tanh()
#         (2): Dropout(p=0.25, inplace=False)
#       )
#       (attention_b): Sequential(
#         (0): Linear(in_features=512, out_features=256, bias=True)
#         (1): Sigmoid()
#         (2): Dropout(p=0.25, inplace=False)
#       )
#       (attention_c): Linear(in_features=256, out_features=1, bias=True)
#     )
#   )
#   (classifiers): Linear(in_features=512, out_features=3, bias=True)
#   (instance_classifiers): ModuleList(
#     (0-2): 3 x Linear(in_features=512, out_features=2, bias=True)
#   )
#   (instance_loss_fn): CrossEntropyLoss()
# )
# Total number of parameters: 319242
# Total number of trainable parameters: 319242
# Init Loaders
# test_error:  0.2
# auc:  0.8611111111111112

# %%
# !zip -r result_evaluation.zip 'eval_results/'
# Out:
# updating: eval_results/ (stored 0%)
# updating: eval_results/EVAL_MLIA_CLAM_eval/ (stored 0%)
# updating: eval_results/EVAL_MLIA_CLAM_eval/fold_0.csv (deflated 45%)
# updating: eval_results/EVAL_MLIA_CLAM_eval/summary.csv (deflated 35%)
# updating: eval_results/EVAL_MLIA_CLAM_eval/eval_experiment_MLIA_CLAM_eval.txt (deflated 31%)
